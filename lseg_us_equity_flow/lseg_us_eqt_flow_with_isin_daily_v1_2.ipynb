# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\kiwitech\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="lseg_us_eqt_flow_with_isin_daily_v1_2", asof_date='2024-01-18', limit=10)
display(df)
# Out:
#          date                timestamp            asof_datetime  \
# 0  2007-04-11  2007-04-11 17:08:00.000  2007-04-11 20:00:03.000
# 1  2007-04-11  2007-04-11 17:44:00.000  2007-04-11 20:00:03.000
# 2  2007-04-11  2007-04-11 16:00:00.000  2007-04-11 20:00:03.000
# 3  2007-04-11  2007-04-11 15:29:00.000  2007-04-11 20:00:03.000
# 4  2007-04-11  2007-04-11 16:01:00.000  2007-04-11 20:00:03.000
# 5  2007-04-11  2007-04-11 15:58:00.000  2007-04-11 20:00:03.000
# 6  2007-04-11  2007-04-11 17:08:00.000  2007-04-11 20:00:03.000
# 7  2007-04-11  2007-04-11 16:00:00.000  2007-04-11 20:00:03.000
# 8  2007-04-11  2007-04-11 15:59:00.000  2007-04-11 20:00:03.000
# 9  2007-04-11  2007-04-11 16:04:00.000  2007-04-11 20:00:03.000
#
#    includes_extended_hours  ticker          isin  trade_count  dollar_volume  \
# 0                        1       A  US00846U1016         8888   9.031479e+07
# 1                        1      AA  US0138171014        50483   5.891779e+08
# ...

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_with_isin_daily_v1_2', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2024-01-22  2024-01-22 19:01:00.000  2024-01-22 20:00:03.000
# 1   2024-01-22  2024-01-22 19:56:00.000  2024-01-22 20:00:03.000
# 2   2024-01-22  2024-01-22 20:01:00.000  2024-01-22 20:00:03.000
# 3   2024-01-22  2024-01-22 20:00:00.000  2024-01-22 20:00:03.000
# 4   2024-01-22  2024-01-22 19:07:00.000  2024-01-22 20:00:03.000
# ..         ...                      ...                      ...
# 95  2024-01-22  2024-01-22 16:01:00.000  2024-01-22 20:00:03.000
# 96  2024-01-22  2024-01-22 20:00:00.000  2024-01-22 20:00:03.000
# 97  2024-01-22  2024-01-22 14:26:00.000  2024-01-22 20:00:03.000
# 98  2024-01-22  2024-01-22 19:14:00.000  2024-01-22 20:00:03.000
# 99  2024-01-22  2024-01-22 19:57:00.000  2024-01-22 20:00:03.000
#
#     includes_extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                         1      A  US00846U1016        24845   1.562852e+08
# ...

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_with_isin_daily_v1_2',key='AAPL', asof_date='2024-01-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2007-02-08  2007-02-08 20:00:00.000  2007-02-08 20:00:03.000
# 1   2007-01-11  2007-01-11 20:00:00.000  2007-01-11 20:00:03.000
# 2   2007-02-05  2007-02-05 20:00:00.000  2007-02-05 20:00:03.000
# 3   2007-02-26  2007-02-26 20:00:00.000  2007-02-26 20:00:03.000
# 4   2007-02-13  2007-02-13 19:59:00.000  2007-02-13 20:00:03.000
# ..         ...                      ...                      ...
# 95  2007-06-19  2007-06-19 20:00:00.000  2007-06-19 20:00:03.000
# 96  2007-06-20  2007-06-20 20:00:00.000  2007-06-20 20:00:03.000
# 97  2007-06-28  2007-06-28 20:00:00.000  2007-06-28 20:00:03.000
# 98  2007-04-27  2007-04-27 19:59:00.000  2007-04-27 20:00:03.000
# 99  2007-06-15  2007-06-15 20:00:00.000  2007-06-15 20:00:03.000
#
#     includes_extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                         1   AAPL  US0378331005       112598   2.032911e+09
# ...

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_with_isin_daily_v1_2',key='AAPL', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2024-01-11  2024-01-11 20:00:00.000  2024-01-11 20:00:03.000
# 1   2024-01-03  2024-01-03 20:00:00.000  2024-01-03 20:00:03.000
# 2   2024-01-08  2024-01-08 20:00:00.000  2024-01-08 20:00:03.000
# 3   2024-01-16  2024-01-16 20:00:00.000  2024-01-16 20:00:03.000
# 4   2024-01-19  2024-01-19 20:00:00.000  2024-01-19 20:00:03.000
# 5   2024-01-17  2024-01-17 20:00:00.000  2024-01-17 20:00:03.000
# 6   2024-01-24  2024-01-24 20:00:00.000  2024-01-24 20:00:03.000
# 7   2024-01-04  2024-01-04 20:00:00.000  2024-01-04 20:00:03.000
# 8   2024-01-25  2024-01-25 20:00:00.000  2024-01-25 20:00:03.000
# 9   2024-01-31  2024-01-31 20:00:00.000  2024-01-31 20:00:03.000
# 10  2024-01-12  2024-01-12 20:00:00.000  2024-01-12 20:00:03.000
# 11  2024-01-09  2024-01-09 20:00:00.000  2024-01-09 20:00:03.000
# 12  2024-01-23  2024-01-23 20:00:00.000  2024-01-23 20:00:03.000
# ...

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_eqt_flow_with_isin_daily_v1_2", target_location="./data", asof_date='2026-01-12')
# Out:
# Starting native python replication for lseg_us_eqt_flow_with_isin_daily_v1_2 (parallel)...
# Found 1 files to download.
# Native replication completed for lseg_us_eqt_flow_with_isin_daily_v1_2. Downloaded 1 files.
