# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="lseg_us_eqt_flow_r3k_1min_v1_2_1_trial", asof_date='2024-01-18', limit=10)
display(df)
# Out:
#          date                timestamp            asof_datetime  \
# 0  2007-01-16  2007-01-16 04:16:00.000  2007-01-16 04:16:03.000
# 1  2007-01-16  2007-01-16 04:16:00.000  2007-01-16 04:16:03.000
# 2  2007-01-16  2007-01-16 04:17:00.000  2007-01-16 04:17:03.000
# 3  2007-01-16  2007-01-16 04:20:00.000  2007-01-16 04:20:03.000
# 4  2007-01-16  2007-01-16 04:22:00.000  2007-01-16 04:22:03.000
# 5  2007-01-16  2007-01-16 04:26:00.000  2007-01-16 04:26:03.000
# 6  2007-01-16  2007-01-16 04:56:00.000  2007-01-16 04:56:03.000
# 7  2007-01-16  2007-01-16 05:06:00.000  2007-01-16 05:06:03.000
# 8  2007-01-16  2007-01-16 05:11:00.000  2007-01-16 05:11:03.000
# 9  2007-01-16  2007-01-16 05:12:00.000  2007-01-16 05:12:03.000
#
#    extended_hours ticker  trade_count  dollar_volume  method1_inst_buy  \
# 0               1   AAPL            1       38208.00          19104.00
# 1               1   CSCO           21      516982.89         135400.28
# ...

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_r3k_1min_v1_2_1_trial', back_to='2024-01-31', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 1   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 2   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 3   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 4   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# ..         ...                      ...                      ...
# 95  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 96  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 97  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 98  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 99  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
#
#     extended_hours ticker  trade_count  dollar_volume  method1_inst_buy  \
# 0                1   AADI            1        40.7100             20.36
# ...

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_r3k_1min_v1_2_1_trial',key='AAPL', asof_date='2024-01-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2007-03-23  2007-03-23 07:59:00.000  2007-03-23 07:59:03.000
# 1   2007-03-23  2007-03-23 08:01:00.000  2007-03-23 08:01:03.000
# 2   2007-03-23  2007-03-23 08:03:00.000  2007-03-23 08:03:03.000
# 3   2007-03-23  2007-03-23 08:04:00.000  2007-03-23 08:04:03.000
# 4   2007-03-23  2007-03-23 08:05:00.000  2007-03-23 08:05:03.000
# ..         ...                      ...                      ...
# 95  2007-03-23  2007-03-23 09:38:00.000  2007-03-23 09:38:03.000
# 96  2007-03-23  2007-03-23 09:39:00.000  2007-03-23 09:39:03.000
# 97  2007-03-23  2007-03-23 09:40:00.000  2007-03-23 09:40:03.000
# 98  2007-03-23  2007-03-23 09:41:00.000  2007-03-23 09:41:03.000
# 99  2007-03-23  2007-03-23 09:42:00.000  2007-03-23 09:42:03.000
#
#     extended_hours ticker  trade_count  dollar_volume  method1_inst_buy  \
# 0                1   AAPL            1   9.390000e+03           4695.00
# ...

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_r3k_1min_v1_2_1_trial',key='AAPL', back_to='2019-01-01', up_to='2024-06-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2019-02-20  2019-02-20 04:01:00.000  2019-02-20 04:01:03.000
# 1   2019-02-20  2019-02-20 04:29:00.000  2019-02-20 04:29:03.000
# 2   2019-02-20  2019-02-20 04:36:00.000  2019-02-20 04:36:03.000
# 3   2019-02-20  2019-02-20 04:38:00.000  2019-02-20 04:38:03.000
# 4   2019-02-20  2019-02-20 04:47:00.000  2019-02-20 04:47:03.000
# ..         ...                      ...                      ...
# 95  2019-02-20  2019-02-20 08:32:00.000  2019-02-20 08:32:03.000
# 96  2019-02-20  2019-02-20 08:33:00.000  2019-02-20 08:33:03.000
# 97  2019-02-20  2019-02-20 08:34:00.000  2019-02-20 08:34:03.000
# 98  2019-02-20  2019-02-20 08:36:00.000  2019-02-20 08:36:03.000
# 99  2019-02-20  2019-02-20 08:37:00.000  2019-02-20 08:37:03.000
#
#     extended_hours ticker  trade_count  dollar_volume  method1_inst_buy  \
# 0                1   AAPL            1         342.00            171.00
# ...

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_eqt_flow_r3k_1min_v1_2_1_trial", target_location="./data", asof_date='2025-01-17')
# Out:
# Starting native python replication for lseg_us_eqt_flow_r3k_1min_v1_2_1_trial (parallel)...
# Found 1 files to download.
# Native replication completed for lseg_us_eqt_flow_r3k_1min_v1_2_1_trial. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="lseg_us_eqt_flow_r3k_1min_v1_2_1_trial", target_location="./data")
