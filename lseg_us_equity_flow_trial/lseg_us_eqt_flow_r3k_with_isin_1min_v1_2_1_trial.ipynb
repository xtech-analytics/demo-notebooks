# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\kiwitech\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="lseg_us_eqt_flow_r3k_with_isin_1min_v1_2_1_trial", asof_date='2024-01-18', limit=10)
display(df)
# Out:
#          date                timestamp            asof_datetime  \
# 0  2007-01-09  2007-01-09 04:30:00.000  2007-01-09 04:30:03.000
# 1  2007-01-09  2007-01-09 04:41:00.000  2007-01-09 04:41:03.000
# 2  2007-01-09  2007-01-09 05:00:00.000  2007-01-09 05:00:03.000
# 3  2007-01-09  2007-01-09 05:14:00.000  2007-01-09 05:14:03.000
# 4  2007-01-09  2007-01-09 05:22:00.000  2007-01-09 05:22:03.000
# 5  2007-01-09  2007-01-09 05:28:00.000  2007-01-09 05:28:03.000
# 6  2007-01-09  2007-01-09 05:54:00.000  2007-01-09 05:54:03.000
# 7  2007-01-09  2007-01-09 05:58:00.000  2007-01-09 05:58:03.000
# 8  2007-01-09  2007-01-09 06:01:00.000  2007-01-09 06:01:03.000
# 9  2007-01-09  2007-01-09 06:02:00.000  2007-01-09 06:02:03.000
#
#    extended_hours ticker  isin  trade_count  dollar_volume  method1_inst_buy  \
# 0               1   AAPL  None            1        77400.0           38700.0
# 1               1   AAPL  None            1        17240.0           17240.0
# ...

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_r3k_with_isin_1min_v1_2_1_trial', back_to='2024-01-31', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 1   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 2   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 3   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 4   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# ..         ...                      ...                      ...
# 95  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 96  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 97  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 98  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 99  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
#
#     extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                1   AADI  US00032Q1040            1        40.7100
# ...

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_r3k_with_isin_1min_v1_2_1_trial',key='AAPL', asof_date='2024-01-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2007-03-13  2007-03-13 07:18:00.000  2007-03-13 07:18:03.000
# 1   2007-03-13  2007-03-13 07:46:00.000  2007-03-13 07:46:03.000
# 2   2007-03-13  2007-03-13 07:49:00.000  2007-03-13 07:49:03.000
# 3   2007-03-13  2007-03-13 07:50:00.000  2007-03-13 07:50:03.000
# 4   2007-03-13  2007-03-13 07:51:00.000  2007-03-13 07:51:03.000
# ..         ...                      ...                      ...
# 95  2007-03-13  2007-03-13 09:52:00.000  2007-03-13 09:52:03.000
# 96  2007-03-13  2007-03-13 09:53:00.000  2007-03-13 09:53:03.000
# 97  2007-03-13  2007-03-13 09:54:00.000  2007-03-13 09:54:03.000
# 98  2007-03-13  2007-03-13 09:55:00.000  2007-03-13 09:55:03.000
# 99  2007-03-13  2007-03-13 09:56:00.000  2007-03-13 09:56:03.000
#
#     extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                1   AAPL  US0378331005            4   6.289100e+04
# ...

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_r3k_with_isin_1min_v1_2_1_trial',key='AAPL', back_to='2019-01-01', up_to='2024-06-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2019-04-10  2019-04-10 04:01:00.000  2019-04-10 04:01:03.000
# 1   2019-04-10  2019-04-10 04:02:00.000  2019-04-10 04:02:03.000
# 2   2019-04-10  2019-04-10 04:03:00.000  2019-04-10 04:03:03.000
# 3   2019-04-10  2019-04-10 04:04:00.000  2019-04-10 04:04:03.000
# 4   2019-04-10  2019-04-10 04:05:00.000  2019-04-10 04:05:03.000
# ..         ...                      ...                      ...
# 95  2019-04-10  2019-04-10 06:32:00.000  2019-04-10 06:32:03.000
# 96  2019-04-10  2019-04-10 06:33:00.000  2019-04-10 06:33:03.000
# 97  2019-04-10  2019-04-10 06:34:00.000  2019-04-10 06:34:03.000
# 98  2019-04-10  2019-04-10 06:36:00.000  2019-04-10 06:36:03.000
# 99  2019-04-10  2019-04-10 06:37:00.000  2019-04-10 06:37:03.000
#
#     extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                1   AAPL  US0378331005           56     1414020.15
# ...

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_eqt_flow_r3k_with_isin_1min_v1_2_1_trial", target_location="./data", asof_date='2025-01-17')
# Out:
# Starting native python replication for lseg_us_eqt_flow_r3k_with_isin_1min_v1_2_1_trial (parallel)...
# Found 1 files to download.
# Native replication completed for lseg_us_eqt_flow_r3k_with_isin_1min_v1_2_1_trial. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="lseg_us_eqt_flow_r3k_with_isin_1min_v1_2_1_trial", target_location="./data")
