# %%
import os
from IPython.display import display

# %%
pip install unifier

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Futures Reference Table

# %%
df =  Unifier.get_dataframe(name="xtech_futures_flow_forecasts_ident")
display(df)
# Out:
#    identifier       sector             name  contract_multiplier   asof_date
# 0          CC  Agriculture            Cocoa                 10.0  2026-06-09
# 1          CT  Agriculture     Cotton No. 2                500.0  2026-06-09
# 2          DC  Agriculture   Class III Milk               2000.0  2026-06-09
# 3          GF  Agriculture    Feeder Cattle                500.0  2026-06-09
# 4          HE  Agriculture        Lean Hogs                400.0  2026-06-09
# ..        ...          ...              ...                  ...         ...
# 79         UB   Treasuries    US Ultra Bond               1000.0  2026-06-09
# 80         ZB   Treasuries  US 30-Year Bond               1000.0  2026-06-09
# 81         ZF   Treasuries   US 5-Year Note               1000.0  2026-06-09
# 82         ZN   Treasuries  US 10-Year Note               1000.0  2026-06-09
# 83         ZT   Treasuries   US 2-Year Note               2000.0  2026-06-09
#
# [84 rows x 5 columns]

# %% [markdown]
# ## XTech Global Futures Flow Forecasts

# %%
df =  Unifier.get_dataframe(name="xtech_futures_flow_forecasts_scenarios",  back_to='2025-11-18', limit=10)
display(df)
# Out:
#              asof_datetime                timestamp identifier  \
# 0  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 1  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 2  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 3  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 4  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 5  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 6  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 7  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 8  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 9  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
#
#   active_delivery_month  is_continuous_roll_date       xt_group scenario_type  \
# 0                202512                    False  managed_money     reference
# 1                202512                    False  managed_money     reference
# ...

# %%
df = Unifier.get_dataframe(name="xtech_futures_flow_forecasts_scenarios", back_to='2024-01-11', up_to='2024-02-01', limit=10)
display(df)
# Out:
#              asof_datetime                timestamp identifier  \
# 0  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 1  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 2  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 3  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 4  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 5  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 6  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 7  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 8  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
# 9  2024-01-26 07:00:00.000  2024-01-25 00:00:00.000         6A
#
#   active_delivery_month  is_continuous_roll_date       xt_group scenario_type  \
# 0                202403                    False  managed_money     reference
# 1                202403                    False  managed_money     reference
# ...

# %%
df =  Unifier.get_dataframe(name="xtech_futures_flow_forecasts_scenarios", key="6A", back_to='2025-11-18', limit=10)
display(df)
# Out:
#              asof_datetime                timestamp identifier  \
# 0  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 1  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 2  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 3  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 4  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 5  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 6  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 7  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 8  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
# 9  2025-11-19 07:00:00.000  2025-11-18 00:00:00.000         6A
#
#   active_delivery_month  is_continuous_roll_date       xt_group scenario_type  \
# 0                202512                    False  managed_money     reference
# 1                202512                    False  managed_money     reference
# ...
