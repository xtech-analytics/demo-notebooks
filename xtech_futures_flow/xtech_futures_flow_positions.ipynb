# %%
import os
from IPython.display import display

# %%
pip install unifier

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Futures Reference Table

# %%
df =  Unifier.get_dataframe(name="xtech_futures_flow_forecasts_ident")
display(df)
# Out:
#    identifier       sector                 name  contract_multiplier  \
# 0          CC  Agriculture                Cocoa                 10.0
# 1          CT  Agriculture         Cotton No. 2                500.0
# 2          DC  Agriculture       Class III Milk               2000.0
# 3          GF  Agriculture        Feeder Cattle                500.0
# 4          HE  Agriculture            Lean Hogs                400.0
# 5          KC  Agriculture             Coffee C                375.0
# 6          KE  Agriculture         KC HRW Wheat                 50.0
# 7         LBR  Agriculture               Lumber                 27.5
# 8         LCC  Agriculture         London Cocoa                 10.0
# 9          LE  Agriculture          Live Cattle                400.0
# 10        LRC  Agriculture       Robusta Coffee                 10.0
# 11        LSU  Agriculture          White Sugar                 50.0
# 12        MWE  Agriculture           MGEX Wheat                 50.0
# ...

# %% [markdown]
# ## XTech Global Futures Flow Position

# %%
df =  Unifier.get_dataframe(name="xtech_futures_flow_forecasts_positions",  back_to='2025-11-18', limit=10)
display(df)
# Out:
#              asof_datetime                timestamp identifier  \
# 0  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000        BRN
# 1  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000         CC
# 2  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000         CL
# 3  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000         CT
# 4  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000         DC
# 5  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000        GAS
# 6  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000         GC
# 7  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000         GF
# 8  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000         HE
# 9  2025-12-17 07:00:00.000  2025-12-16 00:00:00.000         HG
#
#   active_delivery_month  is_continuous_roll_date           xt_group  \
# 0                202602                    False  producer_merchant
# 1                202603                    False  producer_merchant
# ...

# %%
df = Unifier.get_dataframe(name="xtech_futures_flow_forecasts_positions", back_to='2024-01-11', up_to='2024-02-01', limit=10)
display(df)
# Out:
#              asof_datetime                timestamp identifier  \
# 0  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000         6A
# 1  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000         6B
# 2  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000         6C
# 3  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000         6E
# 4  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000         6J
# 5  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000         6M
# 6  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000         6N
# 7  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000         6S
# 8  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000        AHD
# 9  2024-01-13 07:00:00.000  2024-01-12 00:00:00.000        BRN
#
#   active_delivery_month is_continuous_roll_date       xt_group  \
# 0                202403                   False  managed_money
# 1                202403                   False  managed_money
# 2                202403                   False  managed_money
# ...

# %%
df =  Unifier.get_dataframe(name="xtech_futures_flow_forecasts_positions", key="JOBY", back_to='2025-11-18', limit=10)
display(df)
# Out:
#          date            asof_datetime                timestamp ident okey_at  \
# 0  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 15:36:36.466  JOBY     EQT
# 1  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 15:36:43.530  JOBY     EQT
# 2  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 15:36:43.695  JOBY     EQT
# 3  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 15:36:46.159  JOBY     EQT
# 4  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 17:44:13.733  JOBY     EQT
# 5  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 17:44:14.434  JOBY     EQT
# 6  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 17:44:16.843  JOBY     EQT
# 7  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 17:44:16.963  JOBY     EQT
# 8  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 17:44:20.457  JOBY     EQT
# 9  2026-01-09  2026-01-09 23:30:00.000  2026-01-09 17:44:24.367  JOBY     EQT
#
#   okey_ts okey_tk  okey_yr  okey_mn  okey_dy  ...   svolm10   sopxm10  \
# ...
