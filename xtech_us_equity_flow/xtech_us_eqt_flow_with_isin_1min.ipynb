# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\kiwitech\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'demo'
Unifier.token ='qZy7KpE+L5Fg2MmjFqC/1xmweo7pgnnACCcK3JNEAec='
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="xtech_us_eqt_flow_with_isin_1min", asof_date='2024-01-18', limit=10)
display(df)
# Out:
#          date                timestamp            asof_datetime  \
# 0  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 1  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 2  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 3  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 4  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 5  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 6  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 7  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 8  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
# 9  2024-01-09  2024-01-09 15:56:00.000  2024-01-09 15:56:03.000
#
#    extended_hours ticker          isin  trade_count  dollar_volume  \
# 0               0   ASRT  US04546C2052           52   1.509365e+04
# 1               0   ASTS  US00217D1000           46   1.533579e+04
# ...

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='xtech_us_eqt_flow_with_isin_1min', back_to='2024-01-31', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2024-01-31  2024-01-31 15:58:00.000  2024-01-31 15:58:03.000
# 1   2024-01-31  2024-01-31 15:58:00.000  2024-01-31 15:58:03.000
# 2   2024-01-31  2024-01-31 15:58:00.000  2024-01-31 15:58:03.000
# 3   2024-01-31  2024-01-31 15:58:00.000  2024-01-31 15:58:03.000
# 4   2024-01-31  2024-01-31 15:58:00.000  2024-01-31 15:58:03.000
# ..         ...                      ...                      ...
# 95  2024-01-31  2024-01-31 15:59:00.000  2024-01-31 15:59:03.000
# 96  2024-01-31  2024-01-31 15:59:00.000  2024-01-31 15:59:03.000
# 97  2024-01-31  2024-01-31 15:59:00.000  2024-01-31 15:59:03.000
# 98  2024-01-31  2024-01-31 15:59:00.000  2024-01-31 15:59:03.000
# 99  2024-01-31  2024-01-31 15:59:00.000  2024-01-31 15:59:03.000
#
#     extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                0   RYTM  US76243J1051          171   2.710691e+05
# ...

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='xtech_us_eqt_flow_with_isin_1min',key='AAPL', asof_date='2024-01-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2013-05-13  2013-05-13 05:53:00.000  2013-05-13 05:53:03.000
# 1   2013-05-13  2013-05-13 06:06:00.000  2013-05-13 06:06:03.000
# 2   2013-05-13  2013-05-13 06:10:00.000  2013-05-13 06:10:03.000
# 3   2013-05-13  2013-05-13 06:47:00.000  2013-05-13 06:47:03.000
# 4   2013-05-13  2013-05-13 07:19:00.000  2013-05-13 07:19:03.000
# ..         ...                      ...                      ...
# 95  2013-05-13  2013-05-13 09:30:00.000  2013-05-13 09:30:03.000
# 96  2013-05-13  2013-05-13 09:31:00.000  2013-05-13 09:31:03.000
# 97  2013-05-13  2013-05-13 09:33:00.000  2013-05-13 09:33:03.000
# 98  2013-05-13  2013-05-13 09:32:00.000  2013-05-13 09:32:03.000
# 99  2013-05-13  2013-05-13 09:37:00.000  2013-05-13 09:37:03.000
#
#     extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                1   AAPL  US0378331005            1   4.507000e+04
# ...

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='xtech_us_eqt_flow_with_isin_1min',key='AAPL', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2024-01-30  2024-01-30 16:02:00.000  2024-01-30 16:02:03.000
# 1   2024-01-30  2024-01-30 16:03:00.000  2024-01-30 16:03:03.000
# 2   2024-01-30  2024-01-30 16:04:00.000  2024-01-30 16:04:03.000
# 3   2024-01-30  2024-01-30 16:08:00.000  2024-01-30 16:08:03.000
# 4   2024-01-30  2024-01-30 16:09:00.000  2024-01-30 16:09:03.000
# ..         ...                      ...                      ...
# 95  2024-01-30  2024-01-30 17:27:00.000  2024-01-30 17:27:03.000
# 96  2024-01-30  2024-01-30 17:28:00.000  2024-01-30 17:28:03.000
# 97  2024-01-30  2024-01-30 17:29:00.000  2024-01-30 17:29:03.000
# 98  2024-01-30  2024-01-30 17:40:00.000  2024-01-30 17:40:03.000
# 99  2024-01-30  2024-01-30 17:41:00.000  2024-01-30 17:41:03.000
#
#     extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                1   AAPL  US0378331005          182   1.302233e+06
# ...

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="xtech_us_eqt_flow_with_isin_1min", target_location="./data", asof_date='2026-01-12')
# Out:
# Starting native python replication for xtech_us_eqt_flow_with_isin_1min (parallel)...
# Found 1 files to download.
# Native replication completed for xtech_us_eqt_flow_with_isin_1min. Downloaded 1 files.
