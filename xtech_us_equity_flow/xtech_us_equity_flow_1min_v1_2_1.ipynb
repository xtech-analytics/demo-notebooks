# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="xtech_us_equity_flow_1min_v1_2_1", asof_date='2024-01-18', limit=10)
display(df)
# Out:
#          date                timestamp            asof_datetime  \
# 0  2023-02-21  2023-02-21 07:11:00.000  2023-02-21 07:11:03.000
# 1  2023-02-21  2023-02-21 07:17:00.000  2023-02-21 07:17:03.000
# 2  2023-02-21  2023-02-21 07:39:00.000  2023-02-21 07:39:03.000
# 3  2023-02-21  2023-02-21 08:01:00.000  2023-02-21 08:01:03.000
# 4  2023-02-21  2023-02-21 08:02:00.000  2023-02-21 08:02:03.000
# 5  2023-02-21  2023-02-21 08:37:00.000  2023-02-21 08:37:03.000
# 6  2023-02-21  2023-02-21 09:02:00.000  2023-02-21 09:02:03.000
# 7  2023-02-21  2023-02-21 09:22:00.000  2023-02-21 09:22:03.000
# 8  2023-02-21  2023-02-21 09:23:00.000  2023-02-21 09:23:03.000
# 9  2023-02-21  2023-02-21 09:27:00.000  2023-02-21 09:27:03.000
#
#    extended_hours ticker  trade_count  dollar_volume  method1_inst_buy  \
# 0               1   AAAU            1         18.170              9.09
# 1               1   AAAU            3      21997.815              0.00
# ...

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='xtech_us_eqt_flow_with_isin_1min_v1_2', back_to='2024-01-31', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 1   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 2   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 3   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 4   2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# ..         ...                      ...                      ...
# 95  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 96  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 97  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 98  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
# 99  2024-01-31  2024-01-31 04:01:00.000  2024-01-31 04:01:03.000
#
#     extended_hours ticker          isin  trade_count  dollar_volume  \
# 0                1   AADI  US00032Q1040            1          40.71
# ...

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='xtech_us_equity_flow_1min_v1_2_1',key='AAPL', asof_date='2024-01-01', limit=100)
display(df)
# Out:
#           date                timestamp            asof_datetime  \
# 0   2023-04-17  2023-04-17 04:01:00.000  2023-04-17 04:01:03.000
# 1   2023-04-17  2023-04-17 04:02:00.000  2023-04-17 04:02:03.000
# 2   2023-04-17  2023-04-17 04:03:00.000  2023-04-17 04:03:03.000
# 3   2023-04-17  2023-04-17 04:04:00.000  2023-04-17 04:04:03.000
# 4   2023-04-17  2023-04-17 04:05:00.000  2023-04-17 04:05:03.000
# ..         ...                      ...                      ...
# 95  2023-04-17  2023-04-17 05:43:00.000  2023-04-17 05:43:03.000
# 96  2023-04-17  2023-04-17 05:44:00.000  2023-04-17 05:44:03.000
# 97  2023-04-17  2023-04-17 05:45:00.000  2023-04-17 05:45:03.000
# 98  2023-04-17  2023-04-17 05:46:00.000  2023-04-17 05:46:03.000
# 99  2023-04-17  2023-04-17 05:47:00.000  2023-04-17 05:47:03.000
#
#     extended_hours ticker  trade_count  dollar_volume  method1_inst_buy  \
# 0                1   AAPL           71      418945.91         179969.72
# ...

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='xtech_us_equity_flow_1min_v1_2_1',key='AAPL', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="xtech_us_equity_flow_1min_v1_2_1", target_location="./data", asof_date='2026-01-12')
# Out:
# Starting native python replication for xtech_us_equity_flow_1min_v1_2_1 (parallel)...
# Found 1 files to download.
# Native replication completed for xtech_us_equity_flow_1min_v1_2_1. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="xtech_us_equity_flow_1min_v1_2_1", target_location="./data")
