# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="xtech_us_eqt_flow_features_with_isin_labels_r2k_v1_2", asof_date='2024-01-18', limit=10)
display(df)
# Out:
#    use_risk_model          label_name  label_value          isin ticker  \
# 0            True  target_res_ret_63d     0.062165  US0240131047    AAT
# 1           False  target_fwd_ret_10d     0.006517  US0240131047    AAT
# 2           False  target_fwd_ret_42d    -0.012127  US0491642056   AAWW
# 3            True  target_res_ret_63d     0.050054  US0491642056   AAWW
# 4            True  target_res_ret_42d     0.018200  US0240131047    AAT
# 5            True  target_res_ret_21d    -0.009954  US0240131047    AAT
# 6           False  target_fwd_ret_63d     0.197610  US0240131047    AAT
# 7           False  target_fwd_ret_42d     0.160942  US0240131047    AAT
# 8           False  target_fwd_ret_21d     0.044975  US0240131047    AAT
# 9            True  target_res_ret_10d    -0.024273  US0240131047    AAT
#
#              asof_datetime                timestamp   asof_date
# 0  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 1  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 2  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 3  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 4  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 5  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 6  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 7  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 8  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30
# 9  2012-05-30 20:00:03.000  2012-05-30 20:00:00.000  2012-05-30

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='xtech_us_eqt_flow_features_with_isin_labels_r2k_v1_2', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value          isin ticker  \
# 0            False  target_fwd_ret_10d    -0.020277  BMG0772R2087    NTB
# 1            False  target_fwd_ret_10d    -0.053001  BMG0772R2087    NTB
# 2            False  target_fwd_ret_10d    -0.038769  US3369011032   SRCE
# 3            False  target_fwd_ret_10d    -0.016495  US88554D2053    DDD
# 4            False  target_fwd_ret_10d     0.041379  US0003602069   AAON
# ..             ...                 ...          ...           ...    ...
# 95           False  target_fwd_ret_10d    -0.026754  US1689051076   PLCE
# 96           False  target_fwd_ret_10d     0.248100  US88080T1043   WULF
# 97           False  target_fwd_ret_10d    -0.029679  US1778351056   CHCO
# 98           False  target_fwd_ret_10d     0.078414  US1910981026   COKE
# 99           False  target_fwd_ret_10d     0.054371  US1921085049    CDE
#
#               asof_datetime                timestamp   asof_date
# 0   2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
# 1   2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 2   2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
# 3   2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
# 4   2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
# ..                      ...                      ...         ...
# 95  2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
# 96  2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
# 97  2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
# 98  2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
# 99  2024-01-19 20:00:03.000  2024-01-19 20:00:00.000  2024-01-19
#
# [100 rows x 8 columns]

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='xtech_us_eqt_flow_features_with_isin_labels_r2k_v1_2',key='AAN', asof_date='2024-01-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value          isin ticker  \
# 0            False  target_fwd_ret_10d     0.101383  US00258R1095    AAN
# 1            False  target_fwd_ret_21d    -0.131394  US00258R1095    AAN
# 2            False  target_fwd_ret_42d    -0.002141  US00258R1095    AAN
# 3            False  target_fwd_ret_63d    -0.122070  US00258R1095    AAN
# 4             True  target_res_ret_10d     0.011751  US00258R1095    AAN
# ..             ...                 ...          ...           ...    ...
# 95            True  target_res_ret_63d     0.069090  US00258W1080    AAN
# 96           False  target_fwd_ret_10d     0.200725  US00258W1080    AAN
# 97           False  target_fwd_ret_21d     0.071295  US00258W1080    AAN
# 98           False  target_fwd_ret_42d     0.267668  US00258W1080    AAN
# 99           False  target_fwd_ret_63d     0.400019  US00258W1080    AAN
#
#               asof_datetime                timestamp   asof_date
# 0   2020-11-12 20:00:03.000  2020-11-12 20:00:00.000  2020-11-12
# 1   2020-11-12 20:00:03.000  2020-11-12 20:00:00.000  2020-11-12
# 2   2020-11-12 20:00:03.000  2020-11-12 20:00:00.000  2020-11-12
# 3   2020-11-12 20:00:03.000  2020-11-12 20:00:00.000  2020-11-12
# 4   2020-11-12 20:00:03.000  2020-11-12 20:00:00.000  2020-11-12
# ..                      ...                      ...         ...
# 95  2020-12-31 20:00:03.000  2020-12-31 20:00:00.000  2020-12-31
# 96  2020-12-24 20:00:03.000  2020-12-24 20:00:00.000  2020-12-24
# 97  2020-12-24 20:00:03.000  2020-12-24 20:00:00.000  2020-12-24
# 98  2020-12-24 20:00:03.000  2020-12-24 20:00:00.000  2020-12-24
# 99  2020-12-24 20:00:03.000  2020-12-24 20:00:00.000  2020-12-24
#
# [100 rows x 8 columns]

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='xtech_us_eqt_flow_features_with_isin_labels_r2k_v1_2',key='AAN', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value          isin ticker  \
# 0            False  target_fwd_ret_10d    -0.089707  US00258W1080    AAN
# 1            False  target_fwd_ret_21d    -0.124118  US00258W1080    AAN
# 2            False  target_fwd_ret_42d    -0.460985  US00258W1080    AAN
# 3            False  target_fwd_ret_63d    -0.393073  US00258W1080    AAN
# 4             True  target_res_ret_10d    -0.049877  US00258W1080    AAN
# ..             ...                 ...          ...           ...    ...
# 95            True  target_res_ret_63d    -0.325926  US00258W1080    AAN
# 96           False  target_fwd_ret_10d    -0.035058  US00258W1080    AAN
# 97           False  target_fwd_ret_21d    -0.021465  US00258W1080    AAN
# 98           False  target_fwd_ret_42d    -0.326076  US00258W1080    AAN
# 99           False  target_fwd_ret_63d    -0.346252  US00258W1080    AAN
#
#               asof_datetime                timestamp   asof_date
# 0   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 1   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 2   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 3   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 4   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# ..                      ...                      ...         ...
# 95  2024-01-26 20:00:03.000  2024-01-26 20:00:00.000  2024-01-26
# 96  2024-01-22 20:00:03.000  2024-01-22 20:00:00.000  2024-01-22
# 97  2024-01-22 20:00:03.000  2024-01-22 20:00:00.000  2024-01-22
# 98  2024-01-22 20:00:03.000  2024-01-22 20:00:00.000  2024-01-22
# 99  2024-01-22 20:00:03.000  2024-01-22 20:00:00.000  2024-01-22
#
# [100 rows x 8 columns]

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="xtech_us_eqt_flow_features_with_isin_labels_r2k_v1_2", target_location="./data", asof_date='2025-03-12')
# Out:
# Starting native python replication for xtech_us_eqt_flow_features_with_isin_labels_r2k_v1_2 (parallel)...
# Found 1 files to download.
# Native replication completed for xtech_us_eqt_flow_features_with_isin_labels_r2k_v1_2. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="xtech_us_eqt_flow_features_with_isin_labels_r2k_v1_2", target_location="./data")
