# %%
import os
from IPython.display import display

# %%
#pip install unifier

# %%
from unifier import unifier as Unifier
Unifier.user = 
Unifier.token =
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token


symbol_key_map = {
    "XLE": "Energy",
    "XLU": "Utilities",
    "XLB": "Materials",
    "XLP": "Consumer Staples",
    "XLRE": "Real Estate",
    "XLC": "Communication Services",
    "XLV": "Health Care",
    "XLF": "Financials",
    "XLK": "Information Technology",
    "XLI": "Industrials",
    "XLY": "Consumer Discretionary"
}

symbol='XLE'
key=symbol_key_map[symbol]
sector_flow_df = Unifier.get_dataframe(name="xtech_us_equity_sector_flow",key=key,back_to='2024-01-01', up_to='2024-01-10', asof_date=None)
sector_flow_df.sort_values(by='date', inplace=True)

etf_flow_df = Unifier.get_dataframe(name="xtech_us_equity_flow_daily",key=symbol,back_to='2024-01-01', up_to='2024-01-10', asof_date=None)
etf_flow_df.sort_values(by='date', inplace=True)
