# %%
import os
from IPython.display import display

# %%
pip install unifier

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %%
df =  Unifier.get_dataframe(name="xtech_us_equity_sector_flow_r3k_daily_v1_2_1", back_to='2025-11-18', limit=10)
display(df)
# Out:
#          date  num_tickers                timestamp            asof_datetime  \
# 0  2025-12-05          546  2025-12-05 16:55:00.000  2025-12-05 20:00:03.000
# 1  2025-12-05          136  2025-12-05 19:03:00.000  2025-12-05 20:00:03.000
# 2  2025-12-05          133  2025-12-05 19:47:00.000  2025-12-05 20:00:03.000
# 3  2025-12-05          418  2025-12-05 19:56:00.000  2025-12-05 20:00:03.000
# 4  2025-12-05           71  2025-12-05 19:57:00.000  2025-12-05 20:00:03.000
# 5  2025-12-05          469  2025-12-05 19:59:00.000  2025-12-05 20:00:03.000
# 6  2025-12-05          122  2025-12-05 20:00:00.000  2025-12-05 20:00:03.000
# 7  2025-12-05          311  2025-12-05 20:00:00.000  2025-12-05 20:00:03.000
# 8  2025-12-05          118  2025-12-05 20:00:00.000  2025-12-05 20:00:03.000
# 9  2025-12-05          339  2025-12-05 20:00:00.000  2025-12-05 20:00:03.000
#
#    method1_inst_buy  method1_inst_sell method1_net_flow  method2_inst_buy  \
# ...

# %%
df = Unifier.get_dataframe(name="xtech_us_equity_sector_flow_r3k_daily_v1_2_1", back_to='2024-01-11', up_to='2024-02-01', limit=10)
display(df)
# Out:
#          date  num_tickers                timestamp            asof_datetime  \
# 0  2024-01-22          532  2024-01-22 18:18:00.000  2024-01-22 20:00:03.000
# 1  2024-01-22          532  2024-01-22 19:00:00.000  2024-01-22 20:00:03.000
# 2  2024-01-22           74  2024-01-22 19:00:00.000  2024-01-22 20:00:03.000
# 3  2024-01-22          165  2024-01-22 19:06:00.000  2024-01-22 20:00:03.000
# 4  2024-01-22          120  2024-01-22 19:38:00.000  2024-01-22 20:00:03.000
# 5  2024-01-22          348  2024-01-22 19:44:00.000  2024-01-22 20:00:03.000
# 6  2024-01-22          142  2024-01-22 19:54:00.000  2024-01-22 20:00:03.000
# 7  2024-01-22          131  2024-01-22 19:56:00.000  2024-01-22 20:00:03.000
# 8  2024-01-22          125  2024-01-22 20:00:00.000  2024-01-22 20:00:03.000
# 9  2024-01-22          442  2024-01-22 20:00:00.000  2024-01-22 20:00:03.000
#
#    method1_inst_buy  method1_inst_sell method1_net_flow  method2_inst_buy  \
# ...

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="xtech_us_equity_sector_flow_r3k_daily_v1_2_1", target_location="./data", asof_date='2025-03-06')
# Out:
# ...
# Found 1 files to download.
# Native replication completed for xtech_us_equity_sector_flow_r3k_daily_v1_2_1. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="xtech_us_equity_sector_flow_r3k_daily_v1_2_1", target_location="./data")
