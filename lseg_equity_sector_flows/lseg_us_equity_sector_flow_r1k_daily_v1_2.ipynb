# %%
import os
from IPython.display import display

# %%
pip install unifier

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %%
df =  Unifier.get_dataframe(name="lseg_us_equity_sector_flow_r1k_daily_v1_2", back_to='2025-11-18', limit=10)
display(df)
# Out:
#          date  num_tickers                timestamp            asof_datetime  \
# 0  2026-02-17          158  2026-02-17 17:45:00.000  2026-02-17 20:00:03.000
# 1  2026-02-17          105  2026-02-17 19:01:00.000  2026-02-17 20:00:03.000
# 2  2026-02-17           40  2026-02-17 19:09:00.000  2026-02-17 20:00:03.000
# 3  2026-02-17           60  2026-02-17 19:15:00.000  2026-02-17 20:00:03.000
# 4  2026-02-17           64  2026-02-17 19:23:00.000  2026-02-17 20:00:03.000
# 5  2026-02-17           52  2026-02-17 19:49:00.000  2026-02-17 20:00:03.000
# 6  2026-02-17           35  2026-02-17 19:52:00.000  2026-02-17 20:00:03.000
# 7  2026-02-17          126  2026-02-17 19:58:00.000  2026-02-17 20:00:03.000
# 8  2026-02-17           46  2026-02-17 20:00:00.000  2026-02-17 20:00:03.000
# 9  2026-02-17          172  2026-02-17 20:00:00.000  2026-02-17 20:00:03.000
#
#    method1_inst_buy  method1_inst_sell  method1_net_flow  method2_inst_buy  \
# ...

# %%
df = Unifier.get_dataframe(name="lseg_us_equity_sector_flow_r1k_daily_v1_2", back_to='2024-01-11', up_to='2024-02-01', limit=10)
display(df)
# Out:
#          date  num_tickers                timestamp            asof_datetime  \
# 0  2024-01-25          127  2024-01-25 19:00:00.000  2024-01-25 20:00:03.000
# 1  2024-01-25           36  2024-01-25 19:00:00.000  2024-01-25 20:00:03.000
# 2  2024-01-25          117  2024-01-25 19:00:00.000  2024-01-25 20:00:03.000
# 3  2024-01-25          157  2024-01-25 19:33:00.000  2024-01-25 20:00:03.000
# 4  2024-01-25           59  2024-01-25 19:39:00.000  2024-01-25 20:00:03.000
# 5  2024-01-25           42  2024-01-25 19:45:00.000  2024-01-25 20:00:03.000
# 6  2024-01-25           63  2024-01-25 19:59:00.000  2024-01-25 20:00:03.000
# 7  2024-01-25           48  2024-01-25 20:00:00.000  2024-01-25 20:00:03.000
# 8  2024-01-25          165  2024-01-25 20:00:00.000  2024-01-25 20:00:03.000
# 9  2024-01-25          131  2024-01-25 20:00:00.000  2024-01-25 20:00:03.000
#
#    method1_inst_buy  method1_inst_sell  method1_net_flow  method2_inst_buy  \
# ...

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_equity_sector_flow_r1k_daily_v1_2", target_location="./data", asof_date='2025-03-12')
# Out:
# Starting native python replication for lseg_us_equity_sector_flow_r1k_daily_v1_2 (parallel)...
# Found 1 files to download.
# Native replication completed for lseg_us_equity_sector_flow_r1k_daily_v1_2. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="lseg_us_equity_sector_flow_r1k_daily_v1_2", target_location="./data")
