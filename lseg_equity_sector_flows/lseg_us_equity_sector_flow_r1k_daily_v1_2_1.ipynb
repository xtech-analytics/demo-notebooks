# %%
import os
from IPython.display import display

# %%
pip install unifier

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %%
df =  Unifier.get_dataframe(name="lseg_us_equity_sector_flow_r1k_daily_v1_2_1", back_to='2025-11-18', limit=10)
display(df)
# Out:
#          date  num_tickers                timestamp            asof_datetime  \
# 0  2025-11-25          153  2025-11-25 18:58:00.000  2025-11-25 20:00:03.000
# 1  2025-11-25           40  2025-11-25 19:01:00.000  2025-11-25 20:00:03.000
# 2  2025-11-25           61  2025-11-25 19:26:00.000  2025-11-25 20:00:03.000
# 3  2025-11-25           51  2025-11-25 19:43:00.000  2025-11-25 20:00:03.000
# 4  2025-11-25           33  2025-11-25 19:51:00.000  2025-11-25 20:00:03.000
# 5  2025-11-25          123  2025-11-25 19:55:00.000  2025-11-25 20:00:03.000
# 6  2025-11-25           60  2025-11-25 19:55:00.000  2025-11-25 20:00:03.000
# 7  2025-11-25          103  2025-11-25 19:58:00.000  2025-11-25 20:00:03.000
# 8  2025-11-25           47  2025-11-25 20:00:00.000  2025-11-25 20:00:03.000
# 9  2025-11-25          173  2025-11-25 20:00:00.000  2025-11-25 20:00:03.000
#
#    method1_inst_buy  method1_inst_sell  method1_net_flow  method2_inst_buy  \
# ...

# %%
df = Unifier.get_dataframe(name="lseg_us_equity_sector_flow_r1k_daily_v1_2_1", back_to='2024-01-11', up_to='2024-02-01', limit=10)
display(df)
# Out:
#          date  num_tickers                timestamp            asof_datetime  \
# 0  2024-01-17           39  2024-01-17 19:01:00.000  2024-01-17 20:00:03.000
# 1  2024-01-17           60  2024-01-17 19:12:00.000  2024-01-17 20:00:03.000
# 2  2024-01-17          106  2024-01-17 19:18:00.000  2024-01-17 20:00:03.000
# 3  2024-01-17           30  2024-01-17 19:50:00.000  2024-01-17 20:00:03.000
# 4  2024-01-17           55  2024-01-17 19:53:00.000  2024-01-17 20:00:03.000
# 5  2024-01-17          150  2024-01-17 19:55:00.000  2024-01-17 20:00:03.000
# 6  2024-01-17          122  2024-01-17 19:56:00.000  2024-01-17 20:00:03.000
# 7  2024-01-17           41  2024-01-17 20:00:00.000  2024-01-17 20:00:03.000
# 8  2024-01-17          158  2024-01-17 20:00:00.000  2024-01-17 20:00:03.000
# 9  2024-01-17          121  2024-01-17 20:00:00.000  2024-01-17 20:00:03.000
#
#    method1_inst_buy  method1_inst_sell  method1_net_flow  method2_inst_buy  \
# ...

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_equity_sector_flow_r1k_daily_v1_2_1", target_location="./data", asof_date='2025-03-04')
# Out:
# ...
# Found 1 files to download.
# Native replication completed for lseg_us_equity_sector_flow_r1k_daily_v1_2_1. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="lseg_us_equity_sector_flow_r1k_daily_v1_2_1", target_location="./data")
