# %% [markdown]
# # XTech Apollo Flow Demo Notebook

# %% [markdown]
# # Unifier Data Warehouse & API Simplify Data Access With A Single Interface

# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
#pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier

# %%
unifier.user = 'unifier username'
unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = unifier.user
os.environ['UNIFIER_TOKEN'] = unifier.token

# %% [markdown]
# #### Your 'unifier username' is your account email address, and your 'unifier api token' is your account api token found in the access my data page.

# %% [markdown]
# # XTech Apollo Flow Documentation
#
# ## Description
# The **XTech Apollo Flow™** provides unparalleled insights into global futures trading flows, aggregated by investor type. This dataset decipher’s the complex trading behaviors and active risk-taking by institutional buy-side, market makers, natural hedgers, and retail futures traders. By analyzing these trading behaviors on public futures markets and recomposing them by investor type, product and trading style, XTech Apollo Flow™ offers valuable market insights characterized through measurable trading behavior. This data analytic is similar to the CFTC Commitment Of Traders Report, but is offered on a daily basis rather than only on Fridays based on date from End-of-day Tuesday. The direction and style of active risk-takers is identified using proprietary methods, and the resulting trading flows are aggregated daily. This dataset is ideal for developing institutional investment strategies with holding periods ranging from next-day intraday to several months.
#
# ### Key Details
# - **Product**: XTech Apollo Flow™  (Turnover Rate, Trade Size, Position Size, Global Futures)
# - **Version**: Green Buffalo, Indigo Panther
# - **Coverage**: Top 100-300 Global Futures Products (All Expiries)
# - **Delivery Frequency**: Daily End of Day (EOD)
# - **Delivery Time**: 7 am UTC on T+1
# - **Delivery Method**: Unifier API
# - **Data Frequency**: Daily, Weekly
# - **Data Size**: 250K/day
# - **Deep History**: 1/1/2019-Present (5+ years)
# - **Data Description**: Contains Aggregate Gross, Net Long/Short Positions and Concentration Metrics grouped by Product, Investor Types (A: Producers/Hedgers, B: Fund Managers, C: Broker-Dealers, D: Other) and average Trade Size Style (Small, Medium, Large).
#
# ---
#
# ## Dataset: **`xtech_apollo_group_aggregates_indigo_panther`** (Indigo Panther), **`xtech_apollo_group_style_aggregates_turnover_style_green_buffalo`** (aggregated by turnover style), **`xtech_apollo_group_style_aggregates_trade_size_style_green_buffalo`** (aggregated by trade size style), **`xtech_apollo_group_style_aggregates_gross_position_style_green_buffalo`** (aggregated by gross position style)
#
# ### How is this dataset unique?
# This is a new dataset, complete with no missing or incorrect data sourced directly from a clearing system. Post anonymization and aggregation, it has an unparalleled ability to characterize daily trading behavior of investors in order to group them by investor type just like the Commitment of Traders which is only published on T+4 on Friday’s at 3:30 pm ET.
# In addition to the much higher frequency, few sources have the market share (as much as 45% market share in some products) to have sufficient sampling of each investor type. Future versions will have even more granular investor types and could include spreads, swaps and options. The data provides accurate market intelligence by investor type for the most liquid global futures contracts.
#
# ### Applications
# - **Intraday Strategy Development**: Supports strategies with holding periods ranging from minutes to hours.
# - **Historical Analysis**: Access over 10 years of historical data for backtesting and trend analysis.
# - **Market Behavior Research**: Understand the net buying/selling activity by different investor types.
#
# ---
#
# ### Common Field Descriptions
#
# | **Column Name**   | **Data Type** | **Description**                                                                 |
# |--------------------|---------------|---------------------------------------------------------------------------------|
# | `timestamp`          | varchar        | The timestamp as a string, indicating when the data was captured or recorded.                              |
# | `muts`          | bigint        | Unix millisecond timestamp, likely used for efficient time-based indexing or sorting.            |
# | `sector`          | varchar        | The industry or sector classification for the entity or product.                 |
# | `exchange_country`          | varchar          | Country where the related exchange or product is listed or traded.                    |
# | `reportable_product`          | varchar          | Name or identifier for the financial product that is reportable under regulatory rules.               |
# | `product_name`          | varchar          | Descriptive name of the product or instrument.              |
# | `position_style`          | varchar        | XTech position size style label segmenting each group and reportable_product into equal quantiles of: {Small, Medium or Large} average position size.                      |
# | `direction`          | double        | indicates the trading stance, where 1.0 represents a long (buy) position and -1.0 represents a short (sell) position.            |
# | `xt_group`   | varchar        | Group classification or category for the product, possibly internal or taxonomy-based.          |
# | `long_dollar_value`        | double      | Total dollar value of long positions for the product.          |
# | `short_dollar_value`   | double        | Total dollar value of short positions for the product.          |
# | `net_dollar_value`    | double        | Net dollar exposure calculated as long minus short dollar value.        |
# | `gross_dollar_value`   | double        | Sum of long and short dollar values for gross exposure.        |
# | `long_position`  | double        | Number or size of long positions held in the product.              |
# | `short_position`   | double        | Number or size of short positions held in the product.              |
# | `net_position`    | double        | Net position size, calculated as long position minus short position.         |
# | `gross_position`     | double        | Total position size, calculated as long position plus short position.         |
# | `long_position_concentration`     | double        | Concentration of long positions as a proportion of the total market or group.             |
# | `short_position_concentration`     | double        | Concentration of short positions as a proportion of the total market or group.             |
# | `combined_position_concentration`          | double        | Overall position concentration combining both long and short positions.          |
# | `asof_date`          | date        | The effective date for which the data is relevant or reported     |
#
# ---

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = unifier.get_dataframe(name="xtech_apollo_group_aggregates_green_buffalo", asof_date='2024-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190107    AGR              USA                 06
# 1     20190107    AGR              USA                 06
# 2     20190107    AGR              USA                 06
# 3     20190107    AGR              USA                 07
# 4     20190107    AGR              USA                 07
# ..         ...    ...              ...                ...
# 95    20190107    EQY              USA                BTC
# 96    20190107    EQY              USA                BTC
# 97    20190107    INT              DEU                 BV
# 98    20190107    INT              DEU                 BV
# 99    20190107    INT              DEU                 BV
#
#                                product_name           xt_group  direction  \
# 0                  CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0
# 1                  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers       -1.0
# 2                  CBOT SOYBEAN MEAL FUTURE      Fund Managers        1.0
# 3                   CBOT SOYBEAN OIL FUTURE     Broker-Dealers       -1.0
# 4                   CBOT SOYBEAN OIL FUTURE      Fund Managers        1.0
# ..                                      ...                ...        ...
# 95  CME CF BITCOIN REFERENCE RATE (BRR) FUT     Broker-Dealers        NaN
# 96  CME CF BITCOIN REFERENCE RATE (BRR) FUT      Fund Managers        NaN
# 97                   EUREX EURO-BUXL FUTURE     Broker-Dealers        NaN
# 98                   EUREX EURO-BUXL FUTURE  Producers/Hedgers        NaN
# 99                   EUREX EURO-BUXL FUTURE      Fund Managers        NaN
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         518380620.0         242945080.0       275435540.0
# 1         202665240.0         214587310.0       -11922070.0
# 2          39555690.0           7605060.0        31950630.0
# 3          28338888.0          97740048.0       -69401160.0
# 4          48187206.0          23606706.0        24580500.0
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96                NaN                 NaN               NaN
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0          761325700.0        21278.0         12764.0        8514.0
# 1          417252550.0         6920.0          7314.0        -394.0
# 2           47160750.0         1681.0           691.0         990.0
# 3          126078936.0         2100.0          6151.0       -4051.0
# 4           71793912.0         3004.0          1575.0        1429.0
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96                 NaN            NaN             NaN           NaN
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          34042.0                     0.021625                      0.028488
# 1          14234.0                     0.246829                      0.359068
# 2           2372.0                     0.107947                      0.113381
# 3           8251.0                     0.086651                      0.384589
# 4           4579.0                     0.436056                      0.192620
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96             NaN                          NaN                           NaN
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.012927  2019-01-08 00:00:00.000
# 1                          0.153201  2019-01-08 00:00:00.000
# 2                          0.078888  2019-01-08 00:00:00.000
# 3                          0.235508  2019-01-08 00:00:00.000
# 4                          0.217266  2019-01-08 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2019-01-08 00:00:00.000
# 96                              NaN  2019-01-08 00:00:00.000
# 97                              NaN  2019-01-08 00:00:00.000
# 98                              NaN  2019-01-08 00:00:00.000
# 99                              NaN  2019-01-08 00:00:00.000
#
# [100 rows x 19 columns]

# %%
df = unifier.get_dataframe(name="xtech_apollo_group_style_aggregates_trade_size_style_green_buffalo", asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190214    AGR              USA                 06
# 1     20190214    AGR              USA                 06
# 2     20190214    AGR              USA                 06
# 3     20190214    AGR              USA                 06
# 4     20190214    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190214    NRG              USA                 5C
# 96    20190214    AGR              USA                 62
# 97    20190214    AGR              USA                 62
# 98    20190214    AGR              USA                 62
# 99    20190214    AGR              USA                 62
#
#                                 product_name           xt_group  \
# 0                   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers
# 1                   CBOT SOYBEAN MEAL FUTURE      Fund Managers
# 2                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 3                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 4                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# ..                                       ...                ...
# 95  NYMEX CHICAGO ULSD (PLATTS) VS NY HARBOR     Broker-Dealers
# 96                  CME FEEDER CATTLE FUTURE  Producers/Hedgers
# 97                  CME FEEDER CATTLE FUTURE      Fund Managers
# 98                  CME FEEDER CATTLE FUTURE      Fund Managers
# 99                  CME FEEDER CATTLE FUTURE      Fund Managers
#
#    trade_size_style  direction  long_dollar_value  short_dollar_value  \
# 0             small          1         34943390.0          23613760.0
# 1             large          0                NaN                 NaN
# 2             small          1        208672750.0          46673840.0
# 3            medium         -1                NaN                 NaN
# 4             large          1                NaN                 NaN
# ..              ...        ...                ...                 ...
# 95           medium          0                NaN                 NaN
# 96           medium         -1                NaN                 NaN
# 97            small         -1          4692925.0           4926712.5
# 98           medium         -1                NaN                 NaN
# 99            large          0                NaN                 NaN
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0         11329630.0          58557150.0         2096.0          1724.0
# 1                NaN                 NaN            NaN             NaN
# 2        161998910.0         255346590.0        13128.0          7826.0
# 3                NaN                 NaN            NaN             NaN
# 4                NaN                 NaN            NaN             NaN
# ..               ...                 ...            ...             ...
# 95               NaN                 NaN            NaN             NaN
# 96               NaN                 NaN            NaN             NaN
# 97         -233787.5           9619637.5          149.0           151.0
# 98               NaN                 NaN            NaN             NaN
# 99               NaN                 NaN            NaN             NaN
#
#     net_position  gross_position  long_position_concentration  \
# 0          372.0          3820.0                     0.224077
# 1            NaN             NaN                          NaN
# 2         5302.0         20954.0                     0.039873
# 3            NaN             NaN                          NaN
# 4            NaN             NaN                          NaN
# ..           ...             ...                          ...
# 95           NaN             NaN                          NaN
# 96           NaN             NaN                          NaN
# 97          -2.0           300.0                     0.147721
# 98           NaN             NaN                          NaN
# 99           NaN             NaN                          NaN
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.150722                         0.104304
# 1                            NaN                              NaN
# 2                       0.217791                         0.033906
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ..                           ...                              ...
# 95                           NaN                              NaN
# 96                           NaN                              NaN
# 97                      0.210936                         0.090486
# 98                           NaN                              NaN
# 99                           NaN                              NaN
#
#                   asof_date
# 0   2019-02-15 00:00:00.000
# 1   2019-02-15 00:00:00.000
# 2   2019-02-15 00:00:00.000
# 3   2019-02-15 00:00:00.000
# 4   2019-02-15 00:00:00.000
# ..                      ...
# 95  2019-02-15 00:00:00.000
# 96  2019-02-15 00:00:00.000
# 97  2019-02-15 00:00:00.000
# 98  2019-02-15 00:00:00.000
# 99  2019-02-15 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name="xtech_apollo_group_style_aggregates_turnover_style_green_buffalo", asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190111    AGR              USA                 06
# 1     20190111    AGR              USA                 06
# 2     20190111    AGR              USA                 06
# 3     20190111    AGR              USA                 06
# 4     20190111    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190111    AGR              USA                 62
# 96    20190111    AGR              USA                 62
# 97    20190111    AGR              USA                 62
# 98    20190111    AGR              USA                 62
# 99    20190111    EQY              DEU                 64
#
#                                 product_name           xt_group  \
# 0                   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers
# 1                   CBOT SOYBEAN MEAL FUTURE      Fund Managers
# 2                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 3                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 4                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# ..                                       ...                ...
# 95                  CME FEEDER CATTLE FUTURE      Fund Managers
# 96                  CME FEEDER CATTLE FUTURE      Fund Managers
# 97                  CME FEEDER CATTLE FUTURE      Fund Managers
# 98                  CME FEEDER CATTLE FUTURE     Broker-Dealers
# 99  EUREX DJ EURO STOXX SELECT DIV 30 FUTURE     Broker-Dealers
#
#    turnover_style  direction  long_dollar_value  short_dollar_value  \
# 0             low          1        233613430.0          15495000.0
# 1            high          0                NaN                 NaN
# 2             low          1        319617860.0          56775700.0
# 3          medium         -1                NaN                 NaN
# 4            high          0                NaN                 NaN
# ..            ...        ...                ...                 ...
# 95           high          0                NaN                 NaN
# 96            low          1          4092062.5           1974325.0
# 97         medium         -1                NaN                 NaN
# 98            low         -1         57750100.0         161756925.0
# 99            low         -1                NaN                 NaN
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0        218118430.0         249108430.0         8935.0          2084.0
# 1                NaN                 NaN            NaN             NaN
# 2        262842160.0         376393560.0        16603.0          8296.0
# 3                NaN                 NaN            NaN             NaN
# 4                NaN                 NaN            NaN             NaN
# ..               ...                 ...            ...             ...
# 95               NaN                 NaN            NaN             NaN
# 96         2117737.5           6066387.5          108.0            79.0
# 97               NaN                 NaN            NaN             NaN
# 98      -104006825.0         219507025.0         1758.0          3201.0
# 99               NaN                 NaN            NaN             NaN
#
#     net_position  gross_position  long_position_concentration  \
# 0         6851.0         11019.0                     0.628777
# 1            NaN             NaN                          NaN
# 2         8307.0         24899.0                     0.074911
# 3            NaN             NaN                          NaN
# 4            NaN             NaN                          NaN
# ..           ...             ...                          ...
# 95           NaN             NaN                          NaN
# 96          29.0           187.0                     0.190272
# 97           NaN             NaN                          NaN
# 98       -1443.0          4959.0                     0.347197
# 99           NaN             NaN                          NaN
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.387932                         0.554489
# 1                            NaN                              NaN
# 2                       0.093451                         0.056142
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ..                           ...                              ...
# 95                           NaN                              NaN
# 96                      0.376299                         0.126434
# 97                           NaN                              NaN
# 98                      0.190486                         0.127473
# 99                           NaN                              NaN
#
#                   asof_date
# 0   2019-01-12 00:00:00.000
# 1   2019-01-12 00:00:00.000
# 2   2019-01-12 00:00:00.000
# 3   2019-01-12 00:00:00.000
# 4   2019-01-12 00:00:00.000
# ..                      ...
# 95  2019-01-12 00:00:00.000
# 96  2019-01-12 00:00:00.000
# 97  2019-01-12 00:00:00.000
# 98  2019-01-12 00:00:00.000
# 99  2019-01-12 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name="xtech_apollo_group_style_aggregates_gross_position_style_green_buffalo", asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190107    AGR              USA                 06
# 1     20190107    AGR              USA                 06
# 2     20190107    AGR              USA                 06
# 3     20190107    AGR              USA                 06
# 4     20190107    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190107    AGR              USA                 62
# 96    20190107    AGR              USA                 62
# 97    20190107    AGR              USA                 62
# 98    20190107    AGR              USA                 62
# 99    20190107    EQY              DEU                 64
#
#                                 product_name           xt_group  \
# 0                   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers
# 1                   CBOT SOYBEAN MEAL FUTURE      Fund Managers
# 2                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 3                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 4                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# ..                                       ...                ...
# 95                  CME FEEDER CATTLE FUTURE     Broker-Dealers
# 96                  CME FEEDER CATTLE FUTURE     Broker-Dealers
# 97                  CME FEEDER CATTLE FUTURE      Fund Managers
# 98                  CME FEEDER CATTLE FUTURE     Broker-Dealers
# 99  EUREX DJ EURO STOXX SELECT DIV 30 FUTURE     Broker-Dealers
#
#    position_style  direction  long_dollar_value  short_dollar_value  \
# 0           small          1          1908080.0             99440.0
# 1           large          1                NaN                 NaN
# 2           small          1          5327250.0            927460.0
# 3          medium          1         14379420.0           3697980.0
# 4           large          1        322358490.0          78596360.0
# ..            ...        ...                ...                 ...
# 95          small         -1          2468800.0           3070425.0
# 96         medium         -1          4664700.0          15919000.0
# 97         medium          1                NaN                 NaN
# 98          large         -1         54220837.5         134883487.5
# 99         medium          0                NaN                 NaN
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0          1808640.0           2007520.0           64.0             8.0
# 1                NaN                 NaN            NaN             NaN
# 2          4399790.0           6254710.0          236.0           100.0
# 3         10681440.0          18077400.0          962.0           629.0
# 4        243762130.0         400954850.0        19190.0         11658.0
# ..               ...                 ...            ...             ...
# 95         -601625.0           5539225.0           40.0            48.0
# 96       -11254300.0          20583700.0           77.0           233.0
# 97               NaN                 NaN            NaN             NaN
# 98       -80662650.0         189104325.0         1632.0          2755.0
# 99               NaN                 NaN            NaN             NaN
#
#     net_position  gross_position  long_position_concentration  \
# 0           56.0            72.0                     0.059974
# 1            NaN             NaN                          NaN
# 2          136.0           336.0                     0.019299
# 3          333.0          1591.0                     0.046300
# 4         7532.0         30848.0                     0.073227
# ..           ...             ...                          ...
# 95          -8.0            88.0                     0.070087
# 96        -156.0           310.0                     0.192885
# 97           NaN             NaN                          NaN
# 98       -1123.0          4387.0                     0.358714
# 99           NaN             NaN                          NaN
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.315256                         0.054953
# 1                            NaN                              NaN
# 2                       0.119070                         0.016618
# 3                       0.181866                         0.036905
# 4                       0.093252                         0.050915
# ..                           ...                              ...
# 95                      0.072314                         0.036141
# 96                      0.080507                         0.058058
# 97                           NaN                              NaN
# 98                      0.279577                         0.171728
# 99                           NaN                              NaN
#
#                   asof_date
# 0   2019-01-08 00:00:00.000
# 1   2019-01-08 00:00:00.000
# 2   2019-01-08 00:00:00.000
# 3   2019-01-08 00:00:00.000
# 4   2019-01-08 00:00:00.000
# ..                      ...
# 95  2019-01-08 00:00:00.000
# 96  2019-01-08 00:00:00.000
# 97  2019-01-08 00:00:00.000
# 98  2019-01-08 00:00:00.000
# 99  2019-01-08 00:00:00.000
#
# [100 rows x 20 columns]

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_aggregates_green_buffalo', back_to='2025-03-27', up_to='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20250401    AGR              USA                 06
# 1     20250401    AGR              USA                 06
# 2     20250401    AGR              USA                 06
# 3     20250401    AGR              USA                 06
# 4     20250401    AGR              USA                 07
# ..         ...    ...              ...                ...
# 95    20250401    NRG              GBR                ARR
# 96    20250401    NRG              GBR                ARR
# 97    20250401    NRG              GBR                ARV
# 98    20250401    NRG              GBR                ATW
# 99    20250401    NRG              GBR                ATW
#
#                                 product_name           xt_group  direction  \
# 0                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0
# 1                   CBOT SOYBEAN MEAL FUTURE              Other       -1.0
# 2                   CBOT SOYBEAN MEAL FUTURE      Fund Managers       -1.0
# 3                   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers        1.0
# 4                    CBOT SOYBEAN OIL FUTURE  Producers/Hedgers       -1.0
# ..                                       ...                ...        ...
# 95  ICEEU PROP,ARG F E VS NPTH C+F JAPAN FUT  Producers/Hedgers        NaN
# 96  ICEEU PROP,ARG F E VS NPTH C+F JAPAN FUT     Broker-Dealers        NaN
# 97    ICE CRUDE DIFF - ARGUS WCS HOUSTON FUT  Producers/Hedgers        NaN
# 98                ICE ROTTERDAM COAL FUTURES     Broker-Dealers        NaN
# 99                ICE ROTTERDAM COAL FUTURES      Fund Managers        NaN
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         695088310.0         452219630.0       242868680.0
# 1          82590200.0         204302110.0      -121711910.0
# 2          38933120.0          95229990.0       -56296870.0
# 3         657611550.0         546729420.0       110882130.0
# 4         271560126.0         372499326.0      -100939200.0
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96                NaN                 NaN               NaN
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0         1.147308e+09        36438.0         28322.0        8116.0
# 1         2.868923e+08         3475.0          7596.0       -4121.0
# 2         1.341631e+08         1772.0          3717.0       -1945.0
# 3         1.204341e+09        24435.0         20452.0        3983.0
# 4         6.440595e+08        12792.0         16303.0       -3511.0
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96                 NaN            NaN             NaN           NaN
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          64760.0                     0.015350                      0.047075
# 1          11071.0                     0.037433                      0.068241
# 2           5489.0                     0.102306                      0.152901
# 3          44887.0                     0.243757                      0.392738
# 4          29095.0                     0.034376                      0.054721
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96             NaN                          NaN                           NaN
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.012947  2025-04-02 00:00:00.000
# 1                          0.037708  2025-04-02 00:00:00.000
# 2                          0.085651  2025-04-02 00:00:00.000
# 3                          0.153614  2025-04-02 00:00:00.000
# 4                          0.024416  2025-04-02 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2025-04-02 00:00:00.000
# 96                              NaN  2025-04-02 00:00:00.000
# 97                              NaN  2025-04-02 00:00:00.000
# 98                              NaN  2025-04-02 00:00:00.000
# 99                              NaN  2025-04-02 00:00:00.000
#
# [100 rows x 19 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_trade_size_style_green_buffalo', back_to='1982-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190103    AGR              USA                 06
# 1     20190103    AGR              USA                 06
# 2     20190103    AGR              USA                 06
# 3     20190103    AGR              USA                 06
# 4     20190103    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190103    AGR              USA                 62
# 96    20190103    AGR              USA                 62
# 97    20190103    AGR              USA                 62
# 98    20190103    AGR              USA                 62
# 99    20190103    AGR              USA                 62
#
#                 product_name           xt_group trade_size_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            small          1
# 1   CBOT SOYBEAN MEAL FUTURE      Fund Managers            large          0
# 2   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            small          1
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers           medium          1
# 4   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            large          1
# ..                       ...                ...              ...        ...
# 95  CME FEEDER CATTLE FUTURE  Producers/Hedgers           medium         -1
# 96  CME FEEDER CATTLE FUTURE      Fund Managers           medium         -1
# 97  CME FEEDER CATTLE FUTURE      Fund Managers            large          0
# 98  CME FEEDER CATTLE FUTURE      Fund Managers            small          1
# 99  CME FEEDER CATTLE FUTURE     Broker-Dealers            large          0
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0          36641070.0           8143170.0        28497900.0
# 1                 NaN                 NaN               NaN
# 2         244836550.0          44672300.0       200164250.0
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95          9860587.5          57626087.5       -47765500.0
# 96                NaN                 NaN               NaN
# 97                NaN                 NaN               NaN
# 98          7100162.5           1092100.0         6008062.5
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0           44784240.0         2085.0          1190.0         895.0
# 1                  NaN            NaN             NaN           NaN
# 2          289508850.0        12960.0          6634.0        6326.0
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95          67486675.0          489.0          1151.0        -662.0
# 96                 NaN            NaN             NaN           NaN
# 97                 NaN            NaN             NaN           NaN
# 98           8192262.5          139.0            56.0          83.0
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0           3275.0                     0.179231                      0.363537
# 1              NaN                          NaN                           NaN
# 2          19594.0                     0.052452                      0.144583
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95          1640.0                     0.158535                      0.339030
# 96             NaN                          NaN                           NaN
# 97             NaN                          NaN                           NaN
# 98           195.0                     0.194843                      0.261332
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.131997  2019-01-04 00:00:00.000
# 1                               NaN  2019-01-04 00:00:00.000
# 2                          0.040956  2019-01-04 00:00:00.000
# 3                               NaN  2019-01-04 00:00:00.000
# 4                               NaN  2019-01-04 00:00:00.000
# ..                              ...                      ...
# 95                         0.250580  2019-01-04 00:00:00.000
# 96                              NaN  2019-01-04 00:00:00.000
# 97                              NaN  2019-01-04 00:00:00.000
# 98                         0.151001  2019-01-04 00:00:00.000
# 99                              NaN  2019-01-04 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_turnover_style_green_buffalo', back_to='2024-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20240131    AGR              USA                 06
# 1     20240131    AGR              USA                 06
# 2     20240131    AGR              USA                 06
# 3     20240131    AGR              USA                 06
# 4     20240131    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20240131    INT              USA                 26
# 96    20240131    INT              USA                 26
# 97    20240131    INT              USA                 26
# 98    20240131    INT              USA                 26
# 99    20240131    INT              USA                 26
#
#                     product_name           xt_group turnover_style  direction  \
# 0       CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            low         -1
# 1       CBOT SOYBEAN MEAL FUTURE      Fund Managers           high          0
# 2       CBOT SOYBEAN MEAL FUTURE              Other            low          0
# 3       CBOT SOYBEAN MEAL FUTURE              Other         medium          0
# 4       CBOT SOYBEAN MEAL FUTURE              Other           high          0
# ..                           ...                ...            ...        ...
# 95  CBT 2YR TREASURY NOTE FUTURE  Producers/Hedgers            low         -1
# 96  CBT 2YR TREASURY NOTE FUTURE     Broker-Dealers         medium          0
# 97  CBT 2YR TREASURY NOTE FUTURE     Broker-Dealers            low         -1
# 98  CBT 2YR TREASURY NOTE FUTURE      Fund Managers           high          0
# 99  CBT 2YR TREASURY NOTE FUTURE      Fund Managers            low         -1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0        1.679812e+08        2.927405e+08     -1.247594e+08
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95       7.062236e+08        1.477887e+10     -1.407265e+10
# 96                NaN                 NaN               NaN
# 97       5.591793e+08        1.368622e+10     -1.312704e+10
# 98                NaN                 NaN               NaN
# 99       1.412927e+08        2.147051e+08     -7.341239e+07
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0         4.607217e+08        11612.0         15043.0       -3431.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95        1.548509e+10         3504.0         71932.0      -68428.0
# 96                 NaN            NaN             NaN           NaN
# 97        1.424540e+10         2951.0         66781.0      -63830.0
# 98                 NaN            NaN             NaN           NaN
# 99        3.559979e+08          900.0          1257.0        -357.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          26655.0                     0.317106                      0.213248
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95         75436.0                     0.241829                      0.473774
# 96             NaN                          NaN                           NaN
# 97         69732.0                     0.333308                      0.547251
# 98             NaN                          NaN                           NaN
# 99          2157.0                     0.184750                      0.362682
#
#     combined_position_concentration                asof_date
# 0                          0.128249  2024-02-01 00:00:00.000
# 1                               NaN  2024-02-01 00:00:00.000
# 2                               NaN  2024-02-01 00:00:00.000
# 3                               NaN  2024-02-01 00:00:00.000
# 4                               NaN  2024-02-01 00:00:00.000
# ..                              ...                      ...
# 95                         0.432048  2024-02-01 00:00:00.000
# 96                              NaN  2024-02-01 00:00:00.000
# 97                         0.505645  2024-02-01 00:00:00.000
# 98                              NaN  2024-02-01 00:00:00.000
# 99                         0.161024  2024-02-01 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_gross_position_style_green_buffalo', back_to='2024-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20240205    AGR              USA                 06
# 1     20240205    AGR              USA                 06
# 2     20240205    AGR              USA                 06
# 3     20240205    AGR              USA                 06
# 4     20240205    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20240205    INT              USA                 26
# 96    20240205    INT              USA                 26
# 97    20240205    INT              USA                 26
# 98    20240205    INT              USA                 26
# 99    20240205    INT              USA                 26
#
#                     product_name           xt_group position_style  direction  \
# 0       CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          small          1
# 1       CBOT SOYBEAN MEAL FUTURE      Fund Managers          large         -1
# 2       CBOT SOYBEAN MEAL FUTURE              Other          small          0
# 3       CBOT SOYBEAN MEAL FUTURE              Other         medium          0
# 4       CBOT SOYBEAN MEAL FUTURE              Other          large          0
# ..                           ...                ...            ...        ...
# 95  CBT 2YR TREASURY NOTE FUTURE     Broker-Dealers         medium         -1
# 96  CBT 2YR TREASURY NOTE FUTURE     Broker-Dealers          small          1
# 97  CBT 2YR TREASURY NOTE FUTURE  Producers/Hedgers          small          1
# 98  CBT 2YR TREASURY NOTE FUTURE  Producers/Hedgers         medium          1
# 99  CBT 2YR TREASURY NOTE FUTURE  Producers/Hedgers          large         -1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0           2284700.0           1065070.0         1219630.0
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96                NaN                 NaN               NaN
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0            3349770.0          145.0           111.0          34.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96                 NaN            NaN             NaN           NaN
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0            256.0                     0.072177                      0.089899
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96             NaN                          NaN                           NaN
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.042664  2024-02-06 00:00:00.000
# 1                               NaN  2024-02-06 00:00:00.000
# 2                               NaN  2024-02-06 00:00:00.000
# 3                               NaN  2024-02-06 00:00:00.000
# 4                               NaN  2024-02-06 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2024-02-06 00:00:00.000
# 96                              NaN  2024-02-06 00:00:00.000
# 97                              NaN  2024-02-06 00:00:00.000
# 98                              NaN  2024-02-06 00:00:00.000
# 99                              NaN  2024-02-06 00:00:00.000
#
# [100 rows x 20 columns]

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='06' to sort by reportable product) using the asof_date parameter

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_aggregates_green_buffalo',key='06', asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190110    AGR              USA                 06
# 1     20190110    AGR              USA                 06
# 2     20190110    AGR              USA                 06
# 3     20190313    AGR              USA                 06
# 4     20190313    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190402    AGR              USA                 06
# 96    20190318    AGR              USA                 06
# 97    20190318    AGR              USA                 06
# 98    20190318    AGR              USA                 06
# 99    20190403    AGR              USA                 06
#
#                 product_name           xt_group  direction  long_dollar_value  \
# 0   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          1          507723300
# 1   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          1          210357380
# 2   CBOT SOYBEAN MEAL FUTURE      Fund Managers          1           35943060
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          1          507562600
# 4   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          1          249187630
# ..                       ...                ...        ...                ...
# 95  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          1          253212690
# 96  CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          1          510886610
# 97  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          1          273459520
# 98  CBOT SOYBEAN MEAL FUTURE      Fund Managers         -1           24822390
# 99  CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          1          570171340
#
#     short_dollar_value  net_dollar_value  gross_dollar_value  long_position  \
# 0            245040730         262682570           752764030          21383
# 1            208184850           2172530           418542230           6853
# 2             10705880          25237180            46648940           1625
# 3            294484490         213078110           802047090          22554
# 4            182716870          66470760           431904500           8323
# ..                 ...               ...                 ...            ...
# 95           178775920          74436770           431988610           8162
# 96           317149640         193736970           828036250          20668
# 97           180127510          93332010           453587030           8982
# 98            42781660         -17959270            67604050           2860
# 99           375888670         194282670           946060010          23190
#
#     short_position  net_position  gross_position  long_position_concentration  \
# 0            13129          8254           34512                     0.021185
# 1             6818            35           13671                     0.234608
# 2              835           790            2460                     0.120970
# 3            15564          6990           38118                     0.023847
# 4             6216          2107           14539                     0.188077
# ..             ...           ...             ...                          ...
# 95            5854          2308           14016                     0.124654
# 96           14420          6248           35088                     0.023607
# 97            6061          2921           15043                     0.160468
# 98            3442          -582            6302                     0.121379
# 99           16982          6208           40172                     0.023152
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.028357                         0.012643
# 1                       0.373911                         0.151772
# 2                       0.067842                         0.075390
# 3                       0.040252                         0.014977
# 4                       0.392895                         0.132922
# ..                           ...                              ...
# 95                      0.458485                         0.121352
# 96                      0.037381                         0.014470
# 97                      0.400743                         0.121523
# 98                      0.266227                         0.122980
# 99                      0.032444                         0.013531
#
#                   asof_date
# 0   2019-01-11 00:00:00.000
# 1   2019-01-11 00:00:00.000
# 2   2019-01-11 00:00:00.000
# 3   2019-03-14 00:00:00.000
# 4   2019-03-14 00:00:00.000
# ..                      ...
# 95  2019-04-03 00:00:00.000
# 96  2019-03-19 00:00:00.000
# 97  2019-03-19 00:00:00.000
# 98  2019-03-19 00:00:00.000
# 99  2019-04-04 00:00:00.000
#
# [100 rows x 19 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_trade_size_style_green_buffalo',key='06', asof_date='2025-01-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190114    AGR              USA                 06
# 1     20190114    AGR              USA                 06
# 2     20190114    AGR              USA                 06
# 3     20190114    AGR              USA                 06
# 4     20190114    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190124    AGR              USA                 06
# 96    20190124    AGR              USA                 06
# 97    20190124    AGR              USA                 06
# 98    20190124    AGR              USA                 06
# 99    20190418    AGR              USA                 06
#
#                 product_name           xt_group trade_size_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            small          1
# 1   CBOT SOYBEAN MEAL FUTURE      Fund Managers            large          0
# 2   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            small          1
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers           medium          1
# 4   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            large          1
# ..                       ...                ...              ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE      Fund Managers           medium         -1
# 96  CBOT SOYBEAN MEAL FUTURE      Fund Managers            small         -1
# 97  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            large         -1
# 98  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers           medium          1
# 99  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            small          1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0          33807730.0           7873320.0        25934410.0
# 1                 NaN                 NaN               NaN
# 2         215467790.0          47657770.0       167810020.0
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96          2471730.0           3110810.0         -639080.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99         43156170.0          25442640.0        17713530.0
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0           41681050.0         2060.0          1231.0         829.0
# 1                  NaN            NaN             NaN           NaN
# 2          263125560.0        12632.0          7233.0        5399.0
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96           5582540.0          166.0           186.0         -20.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99          68598810.0         2445.0          1871.0         574.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0           3291.0                     0.200509                      0.397271
# 1              NaN                          NaN                           NaN
# 2          19865.0                     0.052393                      0.125325
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96           352.0                     0.128348                      0.091938
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99          4316.0                     0.621539                      0.160514
#
#     combined_position_concentration                asof_date
# 0                          0.146089  2019-01-15 00:00:00.000
# 1                               NaN  2019-01-15 00:00:00.000
# 2                          0.039244  2019-01-15 00:00:00.000
# 3                               NaN  2019-01-15 00:00:00.000
# 4                               NaN  2019-01-15 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2019-01-25 00:00:00.000
# 96                         0.053709  2019-01-25 00:00:00.000
# 97                              NaN  2019-01-25 00:00:00.000
# 98                              NaN  2019-01-25 00:00:00.000
# 99                         0.268072  2019-04-19 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_turnover_style_green_buffalo',key='06', asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190426    AGR              USA                 06
# 1     20190426    AGR              USA                 06
# 2     20190426    AGR              USA                 06
# 3     20190426    AGR              USA                 06
# 4     20190426    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190301    AGR              USA                 06
# 96    20190301    AGR              USA                 06
# 97    20190301    AGR              USA                 06
# 98    20190301    AGR              USA                 06
# 99    20190226    AGR              USA                 06
#
#                 product_name           xt_group turnover_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            low          1
# 1   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            low          1
# 2   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers         medium          1
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers           high          0
# 4   CBOT SOYBEAN MEAL FUTURE      Fund Managers            low         -1
# ..                       ...                ...            ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE      Fund Managers         medium         -1
# 96  CBOT SOYBEAN MEAL FUTURE      Fund Managers            low         -1
# 97  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers           high          0
# 98  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers         medium         -1
# 99  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            low          1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         300446750.0          14509610.0       285937140.0
# 1         277961790.0         101208450.0       176753340.0
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4           3135890.0          11743690.0        -8607800.0
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96          1812410.0          10955270.0        -9142860.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99        279012910.0          50626060.0       228386850.0
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0          314956360.0        13149.0          3812.0        9337.0
# 1          379170240.0        17367.0         11508.0        5859.0
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4           14879580.0          418.0           700.0        -282.0
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96          12767680.0           75.0           372.0        -297.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99         329638970.0        11675.0          4308.0        7367.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          16961.0                     0.626778                      0.225171
# 1          28875.0                     0.068665                      0.068234
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4           1118.0                     0.117310                      0.071040
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96           447.0                     0.155031                      0.060695
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99         15983.0                     0.729551                      0.445873
#
#     combined_position_concentration                asof_date
# 0                          0.570837  2019-04-27 00:00:00.000
# 1                          0.041763  2019-04-27 00:00:00.000
# 2                               NaN  2019-04-27 00:00:00.000
# 3                               NaN  2019-04-27 00:00:00.000
# 4                          0.049463  2019-04-27 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2019-03-02 00:00:00.000
# 96                         0.047810  2019-03-02 00:00:00.000
# 97                              NaN  2019-03-02 00:00:00.000
# 98                              NaN  2019-03-02 00:00:00.000
# 99                         0.533186  2019-02-27 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_gross_position_style_green_buffalo',key='06', asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190102    AGR              USA                 06
# 1     20190102    AGR              USA                 06
# 2     20190102    AGR              USA                 06
# 3     20190102    AGR              USA                 06
# 4     20190102    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190410    AGR              USA                 06
# 96    20190410    AGR              USA                 06
# 97    20190410    AGR              USA                 06
# 98    20190410    AGR              USA                 06
# 99    20190131    AGR              USA                 06
#
#                 product_name           xt_group position_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          small          1
# 1   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers         medium          1
# 2   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          large         -1
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          large          1
# 4   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers         medium          1
# ..                       ...                ...            ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE      Fund Managers         medium          1
# 96  CBOT SOYBEAN MEAL FUTURE      Fund Managers          small         -1
# 97  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          large          1
# 98  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers         medium          1
# 99  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          small          1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0           2118510.0            159760.0         1958750.0
# 1           5540010.0           1951860.0         3588150.0
# 2         203209390.0         203363810.0         -154420.0
# 3         333858570.0          73500690.0       260357880.0
# 4          14603970.0           1584300.0        13019670.0
# ..                ...                 ...               ...
# 95          2269050.0           1944830.0          324220.0
# 96           466630.0            686190.0         -219560.0
# 97        298514480.0         177002760.0       121511720.0
# 98          5596600.0           3615170.0         1981430.0
# 99          1688250.0            410570.0         1277680.0
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0            2278270.0           76.0            14.0          62.0
# 1            7491870.0          193.0            79.0         114.0
# 2          406573200.0         8420.0          8458.0         -38.0
# 3          407359260.0        25446.0         17217.0        8229.0
# 4           16188270.0          979.0           565.0         414.0
# ..                 ...            ...             ...           ...
# 95           4213880.0          143.0           132.0          11.0
# 96           1152820.0           17.0            24.0          -7.0
# 97         475517240.0        13643.0          9871.0        3772.0
# 98           9211770.0          283.0           219.0          64.0
# 99           2098820.0           61.0            20.0          41.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0             90.0                     0.168002                      0.427431
# 1            272.0                     0.208213                      0.285551
# 2          16878.0                     0.686504                      0.886651
# 3          42663.0                     0.066542                      0.101309
# 4           1544.0                     0.043764                      0.231946
# ..             ...                          ...                           ...
# 95           275.0                     0.283408                      0.128093
# 96            41.0                     0.093166                      0.086806
# 97         23514.0                     0.675163                      0.469828
# 98           502.0                     0.081313                      0.219318
# 99            81.0                     0.056035                      0.120801
#
#     combined_position_concentration                asof_date
# 0                          0.147368  2019-01-03 00:00:00.000
# 1                          0.133236  2019-01-03 00:00:00.000
# 2                          0.393327  2019-01-03 00:00:00.000
# 3                          0.047994  2019-01-03 00:00:00.000
# 4                          0.037838  2019-01-03 00:00:00.000
# ..                              ...                      ...
# 95                         0.109459  2019-04-11 00:00:00.000
# 96                         0.046019  2019-04-11 00:00:00.000
# 97                         0.331175  2019-04-11 00:00:00.000
# 98                         0.063793  2019-04-11 00:00:00.000
# 99                         0.040879  2019-02-01 00:00:00.000
#
# [100 rows x 20 columns]

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='06' to sort by reportable product) using the back_to and up_to parameters

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_aggregates_green_buffalo',key='06', back_to='2024-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20240205    AGR              USA                 06
# 1     20240205    AGR              USA                 06
# 2     20240205    AGR              USA                 06
# 3     20240205    AGR              USA                 06
# 4     20240129    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20240411    AGR              USA                 06
# 96    20240328    AGR              USA                 06
# 97    20240328    AGR              USA                 06
# 98    20240328    AGR              USA                 06
# 99    20240328    AGR              USA                 06
#
#                 product_name           xt_group  direction  long_dollar_value  \
# 0   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0        782301750.0
# 1   CBOT SOYBEAN MEAL FUTURE      Fund Managers       -1.0         42466880.0
# 2   CBOT SOYBEAN MEAL FUTURE              Other        NaN                NaN
# 3   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers       -1.0        309888780.0
# 4   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0        729270220.0
# ..                       ...                ...        ...                ...
# 95  CBOT SOYBEAN MEAL FUTURE      Fund Managers       -1.0         45324410.0
# 96  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers        1.0        173105540.0
# 97  CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0        824913280.0
# 98  CBOT SOYBEAN MEAL FUTURE              Other       -1.0          4215910.0
# 99  CBOT SOYBEAN MEAL FUTURE      Fund Managers       -1.0         33627960.0
#
#     short_dollar_value  net_dollar_value  gross_dollar_value  long_position  \
# 0          457388720.0       324913030.0        1.239690e+09        29263.0
# 1           86411880.0       -43945000.0        1.288788e+08         1781.0
# 2                  NaN               NaN                 NaN            NaN
# 3          424303970.0      -114415190.0        7.341928e+08         9810.0
# 4          455122400.0       274147820.0        1.184393e+09        28656.0
# ..                 ...               ...                 ...            ...
# 95          99048570.0       -53724160.0        1.443730e+08         2077.0
# 96         158075110.0        15030430.0        3.311806e+08         6284.0
# 97         532612350.0       292300930.0        1.357526e+09        32614.0
# 98           5473690.0        -1257780.0        9.689600e+06          123.0
# 99          85798870.0       -52170910.0        1.194268e+08         1876.0
#
#     short_position  net_position  gross_position  long_position_concentration  \
# 0          20128.0        9135.0         49391.0                     0.022961
# 1           2998.0       -1217.0          4779.0                     0.074623
# 2              NaN           NaN             NaN                          NaN
# 3          13035.0       -3225.0         22845.0                     0.161272
# 4          20919.0        7737.0         49575.0                     0.023813
# ..             ...           ...             ...                          ...
# 95          3675.0       -1598.0          5752.0                     0.103117
# 96          5842.0         442.0         12126.0                     0.064777
# 97         24036.0        8578.0         56650.0                     0.021160
# 98           160.0         -37.0           283.0                     0.132707
# 99          3422.0       -1546.0          5298.0                     0.152086
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.035441                         0.013968
# 1                       0.113509                         0.059131
# 2                            NaN                              NaN
# 3                       0.110490                         0.065634
# 4                       0.033954                         0.014042
# ..                           ...                              ...
# 95                      0.095284                         0.055011
# 96                      0.129987                         0.047312
# 97                      0.030187                         0.012460
# 98                      0.169813                         0.079313
# 99                      0.225268                         0.128326
#
#                   asof_date
# 0   2024-02-06 01:00:00.000
# 1   2024-02-06 01:00:00.000
# 2   2024-02-06 01:00:00.000
# 3   2024-02-06 01:00:00.000
# 4   2024-01-30 01:00:00.000
# ..                      ...
# 95  2024-04-12 00:00:00.000
# 96  2024-03-29 00:00:00.000
# 97  2024-03-29 00:00:00.000
# 98  2024-03-29 00:00:00.000
# 99  2024-03-29 00:00:00.000
#
# [100 rows x 19 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_trade_size_style_green_buffalo',key='06', back_to='2024-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20240226    AGR              USA                 06
# 1     20240226    AGR              USA                 06
# 2     20240226    AGR              USA                 06
# 3     20240226    AGR              USA                 06
# 4     20240226    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20240306    AGR              USA                 06
# 96    20240219    AGR              USA                 06
# 97    20240219    AGR              USA                 06
# 98    20240219    AGR              USA                 06
# 99    20240219    AGR              USA                 06
#
#                 product_name        xt_group trade_size_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            small         -1
# 1   CBOT SOYBEAN MEAL FUTURE   Fund Managers            large          1
# 2   CBOT SOYBEAN MEAL FUTURE           Other            small          0
# 3   CBOT SOYBEAN MEAL FUTURE           Other           medium          0
# 4   CBOT SOYBEAN MEAL FUTURE           Other            large          0
# ..                       ...             ...              ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers           medium          1
# 96  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            small         -1
# 97  CBOT SOYBEAN MEAL FUTURE   Fund Managers            large          1
# 98  CBOT SOYBEAN MEAL FUTURE           Other            small          0
# 99  CBOT SOYBEAN MEAL FUTURE           Other           medium          0
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0          67920840.0         139514270.0       -71593430.0
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96         62593920.0         157642320.0       -95048400.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0          207435110.0         3403.0          5595.0       -2192.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96         220236240.0         3006.0          5786.0       -2780.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0           8998.0                     0.476964                      0.309289
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96          8792.0                     0.455195                      0.342694
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.191043  2024-02-27 00:00:00.000
# 1                               NaN  2024-02-27 00:00:00.000
# 2                               NaN  2024-02-27 00:00:00.000
# 3                               NaN  2024-02-27 00:00:00.000
# 4                               NaN  2024-02-27 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2024-03-07 00:00:00.000
# 96                         0.212349  2024-02-20 00:00:00.000
# 97                              NaN  2024-02-20 00:00:00.000
# 98                              NaN  2024-02-20 00:00:00.000
# 99                              NaN  2024-02-20 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_turnover_style_green_buffalo',key='06', back_to='2024-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20240129    AGR              USA                 06
# 1     20240129    AGR              USA                 06
# 2     20240129    AGR              USA                 06
# 3     20240129    AGR              USA                 06
# 4     20240129    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20240226    AGR              USA                 06
# 96    20240301    AGR              USA                 06
# 97    20240301    AGR              USA                 06
# 98    20240301    AGR              USA                 06
# 99    20240301    AGR              USA                 06
#
#                 product_name        xt_group turnover_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            low         -1
# 1   CBOT SOYBEAN MEAL FUTURE   Fund Managers           high          0
# 2   CBOT SOYBEAN MEAL FUTURE           Other            low          0
# 3   CBOT SOYBEAN MEAL FUTURE           Other         medium          0
# 4   CBOT SOYBEAN MEAL FUTURE           Other           high          0
# ..                       ...             ...            ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers           high          0
# 96  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            low          1
# 97  CBOT SOYBEAN MEAL FUTURE   Fund Managers           high          0
# 98  CBOT SOYBEAN MEAL FUTURE           Other            low          0
# 99  CBOT SOYBEAN MEAL FUTURE           Other         medium          0
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         172312060.0         282673810.0      -110361750.0
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96        210897180.0         193331140.0        17566040.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0          454985870.0        11732.0         14892.0       -3160.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96         404228320.0        13568.0         13042.0         526.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          26624.0                     0.327919                      0.205517
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96         26610.0                     0.244359                      0.243298
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.126360  2024-01-30 00:00:00.000
# 1                               NaN  2024-01-30 00:00:00.000
# 2                               NaN  2024-01-30 00:00:00.000
# 3                               NaN  2024-01-30 00:00:00.000
# 4                               NaN  2024-01-30 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2024-02-27 00:00:00.000
# 96                         0.122168  2024-03-02 00:00:00.000
# 97                              NaN  2024-03-02 00:00:00.000
# 98                              NaN  2024-03-02 00:00:00.000
# 99                              NaN  2024-03-02 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='xtech_apollo_group_style_aggregates_gross_position_style_green_buffalo',key='06', back_to='2024-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20240207    AGR              USA                 06
# 1     20240207    AGR              USA                 06
# 2     20240207    AGR              USA                 06
# 3     20240207    AGR              USA                 06
# 4     20240207    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20240229    AGR              USA                 06
# 96    20240306    AGR              USA                 06
# 97    20240306    AGR              USA                 06
# 98    20240306    AGR              USA                 06
# 99    20240306    AGR              USA                 06
#
#                 product_name        xt_group position_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE  Broker-Dealers          small          1
# 1   CBOT SOYBEAN MEAL FUTURE   Fund Managers          large         -1
# 2   CBOT SOYBEAN MEAL FUTURE           Other          small          0
# 3   CBOT SOYBEAN MEAL FUTURE           Other         medium          0
# 4   CBOT SOYBEAN MEAL FUTURE           Other          large          0
# ..                       ...             ...            ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers          large         -1
# 96  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers          small          1
# 97  CBOT SOYBEAN MEAL FUTURE   Fund Managers          large         -1
# 98  CBOT SOYBEAN MEAL FUTURE           Other          small          0
# 99  CBOT SOYBEAN MEAL FUTURE           Other         medium          0
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0           2288440.0           1372770.0          915670.0
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95        199848090.0         230406990.0       -30558900.0
# 96          2352530.0            669300.0         1683230.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0            3661210.0          116.0            90.0          26.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95         430255080.0        15280.0         16207.0        -927.0
# 96           3021830.0           87.0            36.0          51.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0            206.0                     0.071236                      0.120818
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95         31487.0                     0.263340                      0.174185
# 96           123.0                     0.072005                      0.118132
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.044816  2024-02-08 00:00:00.000
# 1                               NaN  2024-02-08 00:00:00.000
# 2                               NaN  2024-02-08 00:00:00.000
# 3                               NaN  2024-02-08 00:00:00.000
# 4                               NaN  2024-02-08 00:00:00.000
# ..                              ...                      ...
# 95                         0.106767  2024-03-01 00:00:00.000
# 96                         0.049436  2024-03-07 00:00:00.000
# 97                              NaN  2024-03-07 00:00:00.000
# 98                              NaN  2024-03-07 00:00:00.000
# 99                              NaN  2024-03-07 00:00:00.000
#
# [100 rows x 20 columns]
