# %%
import os
from IPython.display import display

# %%
# %pip install unifier --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from unifier import unifier

# %%
unifier.user = 'unifier email'
unifier.token ='unifier api token'
os.environ['UNIFIER_USER'] = unifier.user
os.environ['UNIFIER_TOKEN'] = unifier.token

# %% [markdown]
# Your 'unifier username' is your account email address, and your 'unifier api token' is your account api token found in the access my data page.
#
# Dataset: xtech_us_eqt_sip_bardata_flow_1min,
#  xtech_us_eqt_sip_bardata_flow_1min_extra,
#  xtech_us_eqt_sip_bardata_flow_5min,
#  xtech_us_eqt_sip_bardata_flow_15min,
#  xtech_us_eqt_sip_bardata_flow_30min,
#  xtech_us_eqt_sip_bardata_flow_60min,
#  xtech_us_eqt_sip_bardata_flow_daily_regular,
#  xtech_us_eqt_sip_bardata_flow_daily_regular_plus_auction

# %%
# Replicate a large dataset to a local folder
# Note: rclone must be installed on your system
unifier.replicate(
    name="xtech_us_eqt_sip_bardata_flow_1min_extra",
    target_location="./your_local_path",
    back_to="",    # Optional: fetch history back to this date
    up_to="",    # Optional: fetch history up to this date
    bandwidth_limit=20       # Optional: limit download speed to 20MB/s
)
# Out:
# ...
# No files found to replicate for xtech_us_eqt_sip_bardata_flow_1min_extra

# %%
df = unifier.get_dataframe(name="xtech_us_eqt_sip_bardata_flow_1min_extra", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#      asof_date                timestamp            asof_datetime    ident  \
# 0   2021-01-12  2021-01-12 03:01:00.000  2021-01-12 03:01:03.000  ATEST.A
# 1   2021-01-12  2021-01-12 03:01:00.000  2021-01-12 03:01:03.000  CTEST.A
# 2   2021-01-12  2021-01-12 03:01:00.000  2021-01-12 03:01:03.000  MTEST.A
# 3   2021-01-12  2021-01-12 03:01:00.000  2021-01-12 03:01:03.000  PTEST.A
# 4   2021-01-12  2021-01-12 03:02:00.000  2021-01-12 03:02:03.000  ATEST.A
# 5   2021-01-12  2021-01-12 03:02:00.000  2021-01-12 03:02:03.000  CTEST.A
# 6   2021-01-12  2021-01-12 03:02:00.000  2021-01-12 03:02:03.000  MTEST.A
# 7   2021-01-12  2021-01-12 03:02:00.000  2021-01-12 03:02:03.000  PTEST.A
# 8   2021-01-12  2021-01-12 03:03:00.000  2021-01-12 03:03:03.000  ATEST.A
# 9   2021-01-12  2021-01-12 03:03:00.000  2021-01-12 03:03:03.000  CTEST.A
# 10  2021-01-12  2021-01-12 03:03:00.000  2021-01-12 03:03:03.000  MTEST.A
# 11  2021-01-12  2021-01-12 03:03:00.000  2021-01-12 03:03:03.000  PTEST.A
# ...

# %%
df = unifier.get_dataframe(name="xtech_us_eqt_sip_bardata_flow_1min", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#      asof_date                timestamp            asof_datetime  ident  \
# 0   2021-01-07  2021-01-07 14:44:00.000  2021-01-07 14:44:03.000    USB
# 5   2021-01-29  2021-01-29 09:30:00.000  2021-01-29 09:30:03.000     A
# 6   2021-01-29  2021-01-29 09:45:00.000  2021-01-29 09:45:03.000     A
# 7   2021-01-29  2021-01-29 10:00:00.000  2021-01-29 10:00:03.000     A
# 8   2021-01-29  2021-01-29 10:15:00.000  2021-01-29 10:15:03.000     A
# 9   2021-01-29  2021-01-29 10:30:00.000  2021-01-29 10:30:03.000     A
# 10  2021-01-29  2021-01-29 10:45:00.000  2021-01-29 10:45:03.000     A
# 11  2021-01-29  2021-01-29 11:00:00.000  2021-01-29 11:00:03.000     A
# ...

# %%
df = unifier.get_dataframe(name="xtech_us_eqt_sip_bardata_flow_30min", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#      asof_date                timestamp            asof_datetime ident  \
# 0   2021-01-20  2021-01-20 07:30:00.000  2021-01-20 07:30:03.000     A
# 1   2021-01-20  2021-01-20 08:30:00.000  2021-01-20 08:30:03.000     A
# 2   2021-01-20  2021-01-20 09:30:00.000  2021-01-20 09:30:03.000     A
# 3   2021-01-20  2021-01-20 10:00:00.000  2021-01-20 10:00:03.000     A
# 4   2021-01-20  2021-01-20 10:30:00.000  2021-01-20 10:30:03.000     A
# 5   2021-01-20  2021-01-20 11:00:00.000  2021-01-20 11:00:03.000     A
# 6   2021-01-20  2021-01-20 11:30:00.000  2021-01-20 11:30:03.000     A
# 7   2021-01-20  2021-01-20 12:00:00.000  2021-01-20 12:00:03.000     A
# 8   2021-01-20  2021-01-20 12:30:00.000  2021-01-20 12:30:03.000     A
# 9   2021-01-20  2021-01-20 13:00:00.000  2021-01-20 13:00:03.000     A
# 10  2021-01-20  2021-01-20 13:30:00.000  2021-01-20 13:30:03.000     A
# 11  2021-01-20  2021-01-20 14:00:00.000  2021-01-20 14:00:03.000     A
# ...

# %%
df = unifier.get_dataframe(name="xtech_us_eqt_sip_bardata_flow_60min", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#      asof_date                timestamp            asof_datetime ident  \
# 0   2021-01-06  2021-01-06 05:00:00.000  2021-01-06 05:00:03.000     A
# 1   2021-01-06  2021-01-06 08:00:00.000  2021-01-06 08:00:03.000     A
# 2   2021-01-06  2021-01-06 09:00:00.000  2021-01-06 09:00:03.000     A
# 3   2021-01-06  2021-01-06 10:00:00.000  2021-01-06 10:00:03.000     A
# 4   2021-01-06  2021-01-06 11:00:00.000  2021-01-06 11:00:03.000     A
# 5   2021-01-06  2021-01-06 12:00:00.000  2021-01-06 12:00:03.000     A
# 6   2021-01-06  2021-01-06 13:00:00.000  2021-01-06 13:00:03.000     A
# 7   2021-01-06  2021-01-06 14:00:00.000  2021-01-06 14:00:03.000     A
# 8   2021-01-06  2021-01-06 15:00:00.000  2021-01-06 15:00:03.000     A
# 9   2021-01-06  2021-01-06 16:00:00.000  2021-01-06 16:00:03.000     A
# 10  2021-01-06  2021-01-06 17:00:00.000  2021-01-06 17:00:03.000     A
# 11  2021-01-06  2021-01-06 18:00:00.000  2021-01-06 18:00:03.000     A
# ...

# %%
df = unifier.get_dataframe(name="xtech_us_eqt_sip_bardata_flow_daily_regular", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#      asof_date                timestamp            asof_datetime    ident  \
# 0   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TAAG
# 1   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000      TAC
# 2   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000   TACA.U
# 3   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TACE
# 4   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TACO
# 5   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TACT
# 6   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TADS
# 7   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TAEQ
# 8   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TAGS
# 9   2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TAIL
# 10  2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000     TAIT
# 11  2021-01-08  2021-01-08 16:00:00.000  2021-01-08 16:00:03.000      TAK
# ...

# %%
df = unifier.get_dataframe(name="xtech_us_eqt_sip_bardata_flow_daily_regular_plus_auction", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#      asof_date                timestamp            asof_datetime   ident  \
# 0   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000     SVT
# 1   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000    SVVC
# 2   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000    SVXY
# 3   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000    SWAN
# 4   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000    SWAV
# 5   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000    SWBI
# 6   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000  SWBK.U
# 7   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000    SWCH
# 8   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000   SWETU
# 9   2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000     SWI
# 10  2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000    SWIR
# 11  2021-01-21  2021-01-21 16:15:00.000  2021-01-21 16:15:03.000     SWK
# ...
