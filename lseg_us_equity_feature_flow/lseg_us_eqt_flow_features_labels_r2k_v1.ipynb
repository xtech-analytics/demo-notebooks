# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier
# Out:
# Requirement already satisfied: unifier in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (0.1.20)
# Requirement already satisfied: requests in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from unifier) (2.32.5)
# Requirement already satisfied: pandas in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from unifier) (3.0.1)
# Requirement already satisfied: boto3 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from unifier) (1.42.75)
# Requirement already satisfied: botocore<1.43.0,>=1.42.75 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from boto3->unifier) (1.42.75)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from boto3->unifier) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from boto3->unifier) (0.16.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from pandas->unifier) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from pandas->unifier) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from requests->unifier) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from requests->unifier) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from requests->unifier) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from requests->unifier) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->unifier) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="lseg_us_eqt_flow_features_labels_r2k_v1", asof_date='2024-01-18', limit=10)
display(df)
# Out:
#    use_risk_model          label_name  label_value ticker  \
# 0            True  target_res_ret_42d     0.296453    AAN
# 1            True  target_res_ret_10d     0.175846    AAN
# 2           False  target_fwd_ret_63d     0.383862    AAN
# 3            True  target_res_ret_21d     0.231989    AAN
# 4           False  target_fwd_ret_10d     0.184948    AAN
# 5           False  target_fwd_ret_42d     0.307090    AAN
# 6            True  target_res_ret_63d     0.292184    AAN
# 7           False  target_fwd_ret_21d     0.168316    AAN
# 8            True  target_res_ret_10d    -0.029724   AAON
# 9           False  target_fwd_ret_10d    -0.016966   AAON
#
#              asof_datetime                timestamp   asof_date
# 0  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 1  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 2  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 3  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 4  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 5  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 6  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 7  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 8  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16
# 9  2022-11-16 20:00:03.000  2022-11-16 20:00:00.000  2022-11-16

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_features_labels_r2k_v1', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value ticker  \
# 0            False  target_fwd_ret_42d    -0.346980    AAN
# 1            False  target_fwd_ret_63d    -0.387858    AAN
# 2             True  target_res_ret_21d    -0.277425    AAN
# 3            False  target_fwd_ret_10d     0.000926    AAN
# 4             True  target_res_ret_63d    -0.284626    AAN
# ..             ...                 ...          ...    ...
# 95           False  target_fwd_ret_10d     0.055002   ACCO
# 96           False  target_fwd_ret_42d     0.077751   ACDC
# 97            True  target_res_ret_21d     0.120936   ACDC
# 98            True  target_res_ret_42d     0.035490   ACDC
# 99            True  target_res_ret_10d    -0.024947   ACDC
#
#               asof_datetime                timestamp   asof_date
# 0   2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 1   2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 2   2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 3   2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 4   2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# ..                      ...                      ...         ...
# 95  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 96  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 97  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 98  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 99  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_features_labels_r2k_v1',key='AAN', asof_date='2024-01-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value ticker  \
# 0            False  target_fwd_ret_21d     0.040763    AAN
# 1            False  target_fwd_ret_10d    -0.070690    AAN
# 2            False  target_fwd_ret_21d     0.262093    AAN
# 3             True  target_res_ret_10d     0.092044    AAN
# 4            False  target_fwd_ret_10d     0.148258    AAN
# ..             ...                 ...          ...    ...
# 95           False  target_fwd_ret_21d     0.036941    AAN
# 96           False  target_fwd_ret_10d    -0.103406    AAN
# 97           False  target_fwd_ret_42d    -0.180431    AAN
# 98           False  target_fwd_ret_10d    -0.046475    AAN
# 99            True  target_res_ret_42d     0.027693    AAN
#
#               asof_datetime                timestamp   asof_date
# 0   2009-05-07 20:00:03.000  2009-05-07 20:00:00.000  2009-05-07
# 1   2009-05-07 20:00:03.000  2009-05-07 20:00:00.000  2009-05-07
# 2   2022-10-20 20:00:03.000  2022-10-20 20:00:00.000  2022-10-20
# 3   2022-10-20 20:00:03.000  2022-10-20 20:00:00.000  2022-10-20
# 4   2022-10-20 20:00:03.000  2022-10-20 20:00:00.000  2022-10-20
# ..                      ...                      ...         ...
# 95  2022-12-05 20:00:03.000  2022-12-05 20:00:00.000  2022-12-05
# 96  2009-06-02 20:00:03.000  2009-06-02 20:00:00.000  2009-06-02
# 97  2022-03-23 20:00:03.000  2022-03-23 20:00:00.000  2022-03-23
# 98  2022-03-23 20:00:03.000  2022-03-23 20:00:00.000  2022-03-23
# 99  2022-03-23 20:00:03.000  2022-03-23 20:00:00.000  2022-03-23
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_features_labels_r2k_v1',key='AAN', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value ticker  \
# 0            False  target_fwd_ret_63d    -0.393073    AAN
# 1             True  target_res_ret_10d    -0.049877    AAN
# 2             True  target_res_ret_63d    -0.319573    AAN
# 3            False  target_fwd_ret_21d    -0.124118    AAN
# 4            False  target_fwd_ret_10d    -0.089707    AAN
# ..             ...                 ...          ...    ...
# 95            True  target_res_ret_21d     0.009662    AAN
# 96           False  target_fwd_ret_42d    -0.346980    AAN
# 97           False  target_fwd_ret_63d    -0.387858    AAN
# 98            True  target_res_ret_21d    -0.277425    AAN
# 99           False  target_fwd_ret_10d     0.000926    AAN
#
#               asof_datetime                timestamp   asof_date
# 0   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 1   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 2   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 3   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 4   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# ..                      ...                      ...         ...
# 95  2024-01-24 20:00:03.000  2024-01-24 20:00:00.000  2024-01-24
# 96  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 97  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 98  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
# 99  2024-01-29 20:00:03.000  2024-01-29 20:00:00.000  2024-01-29
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_eqt_flow_features_labels_r2k_v1", target_location="./data", asof_date='2025-03-12')
# Out:
# Downloading using native python implementation for lseg_us_eqt_flow_features_labels_r2k_v1...
# Found 1 files to download.
# Native replication completed for lseg_us_eqt_flow_features_labels_r2k_v1. Downloaded 1 files.
