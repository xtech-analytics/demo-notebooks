# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="lseg_us_eqt_flow_features_labels_r2k_v1", asof_date='2024-01-18', limit=10)
display(df)

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_features_labels_r2k_v1', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value ticker  \
# 0             True  target_res_ret_63d    -0.234363    AAN
# 1            False  target_fwd_ret_63d    -0.318988    AAN
# 2            False  target_fwd_ret_42d    -0.362321    AAN
# 3             True  target_res_ret_21d    -0.026664    AAN
# 4             True  target_res_ret_42d    -0.351710    AAN
# ..             ...                 ...          ...    ...
# 95           False  target_fwd_ret_63d     0.105781   ACDC
# 96           False  target_fwd_ret_21d     0.063222   ACDC
# 97            True  target_res_ret_21d     0.043915   ACDC
# 98            True  target_res_ret_42d     0.081837   ACDC
# 99           False  target_fwd_ret_10d     0.055949   ACDC
#
#               asof_datetime                timestamp   asof_date
# 0   2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# 1   2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# 2   2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# 3   2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# 4   2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# ..                      ...                      ...         ...
# 95  2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# 96  2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# 97  2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# 98  2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
# 99  2024-01-18 20:00:03.000  2024-01-18 20:00:00.000  2024-01-18
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_features_labels_r2k_v1',key='AAN', asof_date='2024-01-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value ticker  \
# 0            False  target_fwd_ret_42d    -0.018098    AAN
# 1             True  target_res_ret_42d     0.104145    AAN
# 2            False  target_fwd_ret_21d     0.083212    AAN
# 3            False  target_fwd_ret_63d    -0.079039    AAN
# 4             True  target_res_ret_10d     0.098926    AAN
# ..             ...                 ...          ...    ...
# 95            True  target_res_ret_10d     0.019248    AAN
# 96           False  target_fwd_ret_10d    -0.064505    AAN
# 97           False  target_fwd_ret_21d     0.036941    AAN
# 98           False  target_fwd_ret_42d    -0.462892    AAN
# 99           False  target_fwd_ret_63d    -0.223785    AAN
#
#               asof_datetime                timestamp   asof_date
# 0   2022-02-24 20:00:03.000  2022-02-24 20:00:00.000  2022-02-24
# 1   2022-02-24 20:00:03.000  2022-02-24 20:00:00.000  2022-02-24
# 2   2022-02-24 20:00:03.000  2022-02-24 20:00:00.000  2022-02-24
# 3   2022-02-24 20:00:03.000  2022-02-24 20:00:00.000  2022-02-24
# 4   2022-02-24 20:00:03.000  2022-02-24 20:00:00.000  2022-02-24
# ..                      ...                      ...         ...
# 95  2022-12-05 20:00:03.000  2022-12-05 20:00:00.000  2022-12-05
# 96  2022-12-05 20:00:03.000  2022-12-05 20:00:00.000  2022-12-05
# 97  2022-12-05 20:00:03.000  2022-12-05 20:00:00.000  2022-12-05
# 98  2022-08-23 20:00:03.000  2022-08-23 20:00:00.000  2022-08-23
# 99  2022-08-23 20:00:03.000  2022-08-23 20:00:00.000  2022-08-23
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_eqt_flow_features_labels_r2k_v1',key='AAN', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#     use_risk_model          label_name  label_value ticker  \
# 0            False  target_fwd_ret_63d    -0.393073    AAN
# 1             True  target_res_ret_10d    -0.049877    AAN
# 2             True  target_res_ret_63d    -0.319573    AAN
# 3            False  target_fwd_ret_21d    -0.124118    AAN
# 4            False  target_fwd_ret_10d    -0.089707    AAN
# ..             ...                 ...          ...    ...
# 95            True  target_res_ret_10d    -0.014009    AAN
# 96            True  target_res_ret_21d    -0.049071    AAN
# 97           False  target_fwd_ret_21d    -0.008299    AAN
# 98           False  target_fwd_ret_10d    -0.013870    AAN
# 99            True  target_res_ret_63d    -0.297792    AAN
#
#               asof_datetime                timestamp   asof_date
# 0   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 1   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 2   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 3   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# 4   2024-01-08 20:00:03.000  2024-01-08 20:00:00.000  2024-01-08
# ..                      ...                      ...         ...
# 95  2024-01-11 20:00:03.000  2024-01-11 20:00:00.000  2024-01-11
# 96  2024-01-11 20:00:03.000  2024-01-11 20:00:00.000  2024-01-11
# 97  2024-01-11 20:00:03.000  2024-01-11 20:00:00.000  2024-01-11
# 98  2024-01-11 20:00:03.000  2024-01-11 20:00:00.000  2024-01-11
# 99  2024-01-11 20:00:03.000  2024-01-11 20:00:00.000  2024-01-11
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_eqt_flow_features_labels_r2k_v1", target_location="./data", asof_date='2025-03-12')
# Out:
# Starting native python replication for lseg_us_eqt_flow_features_labels_r2k_v1 (parallel)...
# Found 1 files to download.
# Native replication completed for lseg_us_eqt_flow_features_labels_r2k_v1. Downloaded 1 files.
