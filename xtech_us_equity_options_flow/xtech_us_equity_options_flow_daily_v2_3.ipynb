# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="xtech_us_equity_options_flow_daily_v2_3", asof_date='2024-01-31', limit=10)
display(df)
# Out:
#                  asof_datetime        date                    timestamp ident  \
# 0  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:11:00.000 UTC   NDX
# 1  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:05:00.000 UTC   NDX
# 2  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:05:00.000 UTC   NDX
# 3  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:05:00.000 UTC   NDX
# 4  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:04:00.000 UTC   RUT
# 5  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:01:00.000 UTC   XLY
# 6  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:01:00.000 UTC   RUT
# 7  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:07:00.000 UTC   NDX
# 8  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:01:00.000 UTC   ECL
# 9  2018-08-06 20:52:03.000 UTC  2018-08-06  2018-08-06 20:01:00.000 UTC   ECL
#
#   okey_tk tradingsession okey_at okey_cp  okey_dy  okey_mn  ...  \
# 0     NDX     RegularMkt     EQT     Put       19       10  ...
# 1     NDX     RegularMkt     EQT     Put       21        9  ...
# 2     NDX     RegularMkt     EQT     Put       21        9  ...
# 3     NDX     RegularMkt     EQT     Put       19       10  ...
# 4     RUT     RegularMkt     EQT    Call       19       10  ...
# 5     XLY     RegularMkt     EQT    Call       21       12  ...
# 6     RUT     RegularMkt     EQT     Put       19       10  ...
# 7     NDX     RegularMkt     EQT     Put       19       10  ...
# 8     ECL     RegularMkt     EQT     Put       14        9  ...
# 9     ECL     RegularMkt     EQT     Put       14        9  ...
#
#   m4_neutral_volume  m4_num_buy_trades  m4_num_neutral_trades  \
# 0                 0                  1                      0
# 1                 0                  1                      0
# 2                 0                  1                      0
# 3                 0                  1                      0
# 4                 0                  1                      0
# 5                 0                  2                      0
# 6                 2                  0                      1
# 7                 0                  3                      0
# 8                 0                  0                      0
# 9                 0                  1                      0
#
#    m4_num_sell_trades  m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  \
# 0                   0               0          0.00               0.858
# 1                   0               0          0.00               1.113
# 2                   0               0          0.00               0.408
# 3                   0               0          0.00               2.262
# 4                   0               0          0.00               1.555
# 5                   0               0          0.00               1.140
# 6                   0               0          0.00               0.000
# 7                   0               0          0.00               2.527
# 8                   1              12          2.13               0.000
# 9                   0               0          0.00               2.268
#
#    m4_vega_neutral_volume  m4_vega_sell_volume   asof_date
# 0                   0.000                0.000  2018-08-06
# 1                   0.000                0.000  2018-08-06
# 2                   0.000                0.000  2018-08-06
# 3                   0.000                0.000  2018-08-06
# 4                   0.000                0.000  2018-08-06
# 5                   0.000                0.000  2018-08-06
# 6                   4.486                0.000  2018-08-06
# 7                   0.000                0.000  2018-08-06
# 8                   0.000                2.352  2018-08-06
# 9                   0.000                0.000  2018-08-06
#
# [10 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='xtech_us_equity_options_flow_daily_v2_3', back_to='2024-01-31', up_to='2024-02-01', limit=100)
display(df)
# Out:
#                   asof_datetime        date                    timestamp  \
# 0   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 17:04:00.000 UTC
# 1   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 17:01:00.000 UTC
# 2   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 17:02:00.000 UTC
# 3   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 19:38:00.000 UTC
# 4   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 20:14:00.000 UTC
# ..                          ...         ...                          ...
# 95  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 18:32:00.000 UTC
# 96  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 20:46:00.000 UTC
# 97  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 15:50:00.000 UTC
# 98  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 17:08:00.000 UTC
# 99  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 20:46:00.000 UTC
#
#    ident okey_tk tradingsession okey_at okey_cp  okey_dy  okey_mn  ...  \
# 0    UNP     UNP     RegularMkt     EQT     Put       20        9  ...
# 1   UVIX    UVIX     RegularMkt     EQT     Put       19        4  ...
# 2   ABAT    ABAT     RegularMkt     EQT     Put       16        2  ...
# 3    CVE     CVE     RegularMkt     EQT     Put        9        2  ...
# 4    UAL     UAL     RegularMkt     EQT     Put        2        2  ...
# ..   ...     ...            ...     ...     ...      ...      ...  ...
# 95  ADAP    ADAP     RegularMkt     EQT     Put       16        2  ...
# 96  META    META     RegularMkt     EQT    Call       16        2  ...
# 97  CBRE    CBRE     RegularMkt     EQT     Put       16        2  ...
# 98   DUK     DUK     RegularMkt     EQT     Put       21        6  ...
# 99  FSLR    FSLR     RegularMkt     EQT     Put       19        4  ...
#
#    m4_neutral_volume  m4_num_buy_trades  m4_num_neutral_trades  \
# 0                  0                  8                      0
# 1                  0                  0                      0
# 2                  0                  0                      0
# 3                  0                  2                      0
# 4                  0                  5                      0
# ..               ...                ...                    ...
# 95                11                  0                      2
# 96                 0                 26                      0
# 97                 0                  1                      0
# 98                 0                  1                      0
# 99                 0                  0                      0
#
#     m4_num_sell_trades  m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  \
# 0                    0               0       0.00000           42.910024
# 1                    1              27       0.15000            0.000000
# 2                    1               1       0.15000            0.000000
# 3                    2               5       0.21000            0.107182
# 4                   28             197       0.08599            1.091516
# ..                 ...             ...           ...                 ...
# 95                   0               0       0.00000            0.000000
# 96                   9              50       1.08340            7.880575
# 97                   2              25       0.40000            0.185172
# 98                   0               0       0.00000            0.130831
# 99                   2               2      10.82500            0.000000
#
#     m4_vega_neutral_volume  m4_vega_sell_volume   asof_date
# 0                        0             0.000000  2024-01-31
# 1                        0             0.152970  2024-01-31
# 2                        0             0.002142  2024-01-31
# 3                        0             0.048897  2024-01-31
# 4                        0             1.609006  2024-01-31
# ..                     ...                  ...         ...
# 95                       0             0.000000  2024-01-31
# 96                       0             5.333355  2024-01-31
# 97                       0             0.925862  2024-01-31
# 98                       0             0.000000  2024-01-31
# 99                       0             0.532794  2024-01-31
#
# [100 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='xtech_us_equity_options_flow_daily_v2_3', key='SPXW', asof_date='2024-01-01', limit=10)
display(df)
# Out:
#                  asof_datetime        date                    timestamp ident  \
# 0  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:11:00.000 UTC  SPXW
# 1  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:09:00.000 UTC  SPXW
# 2  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:07:00.000 UTC  SPXW
# 3  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:07:00.000 UTC  SPXW
# 4  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:07:00.000 UTC  SPXW
# 5  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:07:00.000 UTC  SPXW
# 6  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:07:00.000 UTC  SPXW
# 7  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:07:00.000 UTC  SPXW
# 8  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:07:00.000 UTC  SPXW
# 9  2018-07-17 20:56:03.000 UTC  2018-07-17  2018-07-17 20:07:00.000 UTC  SPXW
#
#   okey_tk tradingsession okey_at okey_cp  okey_dy  okey_mn  ...  \
# 0    SPXW     RegularMkt     EQT    Call       18        7  ...
# 1    SPXW     RegularMkt     EQT     Put       23        7  ...
# 2    SPXW     RegularMkt     EQT     Put       21        9  ...
# 3    SPXW     RegularMkt     EQT     Put       28        9  ...
# 4    SPXW     RegularMkt     EQT     Put       21        9  ...
# 5    SPXW     RegularMkt     EQT     Put       21        9  ...
# 6    SPXW     RegularMkt     EQT     Put       21        9  ...
# 7    SPXW     RegularMkt     EQT     Put       19       10  ...
# 8    SPXW     RegularMkt     EQT     Put       21        9  ...
# 9    SPXW     RegularMkt     EQT     Put       21        9  ...
#
#   m4_neutral_volume  m4_num_buy_trades  m4_num_neutral_trades  \
# 0                 0                  1                      0
# 1                 0                  1                      0
# 2                 0                  1                      0
# 3                 0                  1                      0
# 4                 0                  1                      0
# 5                 0                  1                      0
# 6                 0                  1                      0
# 7                 0                  1                      0
# 8                 0                  2                      0
# 9                 0                  1                      0
#
#    m4_num_sell_trades  m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  \
# 0                   0               0             0               0.024
# 1                   0               0             0               2.000
# 2                   0               0             0              11.298
# 3                   0               0             0              25.346
# 4                   0               0             0               4.880
# 5                   0               0             0               5.073
# 6                   0               0             0               3.458
# 7                   0               0             0               1.992
# 8                   0               0             0               7.024
# 9                   0               0             0               3.234
#
#    m4_vega_neutral_volume  m4_vega_sell_volume   asof_date
# 0                       0                    0  2018-07-17
# 1                       0                    0  2018-07-17
# 2                       0                    0  2018-07-17
# 3                       0                    0  2018-07-17
# 4                       0                    0  2018-07-17
# 5                       0                    0  2018-07-17
# 6                       0                    0  2018-07-17
# 7                       0                    0  2018-07-17
# 8                       0                    0  2018-07-17
# 9                       0                    0  2018-07-17
#
# [10 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='xtech_us_equity_options_flow_daily_v2_3',key='SPX', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#                   asof_datetime        date                    timestamp  \
# 0   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 20:09:00.000 UTC
# 1   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 17:02:00.000 UTC
# 2   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 17:15:00.000 UTC
# 3   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 17:23:00.000 UTC
# 4   2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 18:26:00.000 UTC
# ..                          ...         ...                          ...
# 95  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 18:17:00.000 UTC
# 96  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 19:15:00.000 UTC
# 97  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 20:58:00.000 UTC
# 98  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 18:35:00.000 UTC
# 99  2024-01-31 22:44:03.000 UTC  2024-01-31  2024-01-31 18:21:00.000 UTC
#
#    ident okey_tk tradingsession okey_at okey_cp  okey_dy  okey_mn  ...  \
# 0    SPX     SPX     RegularMkt     EQT     Put       19        7  ...
# 1    SPX     SPX     RegularMkt     EQT    Call       18       10  ...
# 2    SPX     SPX     RegularMkt     EQT     Put       19       12  ...
# 3    SPX     SPX     RegularMkt     EQT     Put       17        5  ...
# 4    SPX     SPX     RegularMkt     EQT     Put       20       12  ...
# ..   ...     ...            ...     ...     ...      ...      ...  ...
# 95   SPX     SPX     RegularMkt     EQT    Call       19        4  ...
# 96   SPX     SPX     RegularMkt     EQT     Put       19        4  ...
# 97   SPX     SPX     RegularMkt     EQT    Call       19        4  ...
# 98   SPX     SPX     RegularMkt     EQT    Call       17        5  ...
# 99   SPX     SPX     RegularMkt     EQT     Put       16        2  ...
#
#    m4_neutral_volume  m4_num_buy_trades  m4_num_neutral_trades  \
# 0                  0                  5                      0
# 1                  0                  2                      0
# 2                  0                  0                      0
# 3                  0                  1                      0
# 4                  0                  0                      0
# ..               ...                ...                    ...
# 95                 0                  0                      0
# 96                 0                  1                      0
# 97                 0                  0                      0
# 98                 0                  2                      0
# 99                 0                  0                      0
#
#     m4_num_sell_trades  m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  \
# 0                    1               1     80.100000           230.53840
# 1                    0               0      0.000000            29.99990
# 2                    2              31    317.072903             0.00000
# 3                    1               1     62.500000             8.55177
# 4                    6            2250     18.820000             0.00000
# ..                 ...             ...           ...                 ...
# 95                   1               1      9.900000             0.00000
# 96                   1              27     19.300000            31.18256
# 97                   7              14     52.074286             0.00000
# 98                   0               0      0.000000            21.07260
# 99                   2              21      1.050000             0.00000
#
#     m4_vega_neutral_volume  m4_vega_sell_volume   asof_date
# 0                      0.0            10.340200  2024-01-31
# 1                      0.0             0.000000  2024-01-31
# 2                      0.0           759.898300  2024-01-31
# 3                      0.0             8.517150  2024-01-31
# 4                      0.0          7271.572500  2024-01-31
# ..                     ...                  ...         ...
# 95                     0.0             3.701110  2024-01-31
# 96                     0.0           103.105980  2024-01-31
# 97                     0.0           113.046660  2024-01-31
# 98                     0.0             0.000000  2024-01-31
# 99                     0.0             4.930554  2024-01-31
#
# [100 rows x 109 columns]

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="xtech_us_equity_options_flow_daily_v2_3", target_location="./data", asof_date='2014-01-31')
# Out:
# Starting native python replication for xtech_us_equity_options_flow_daily_v2_3 (parallel)...
# Found 1 files to download.
# Native replication completed for xtech_us_equity_options_flow_daily_v2_3. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="xtech_us_equity_options_flow_daily_v2_3", target_location="./data")
# Out:
# Starting native python replication for xtech_us_equity_options_flow_daily_v2_3 (parallel)...
# Found 3095 files to download.
