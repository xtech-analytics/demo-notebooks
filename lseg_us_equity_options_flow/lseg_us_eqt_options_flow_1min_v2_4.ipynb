# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="lseg_us_equity_options_flow_1min_v2_4", asof_date='2024-01-31', limit=10)
display(df)
# Out:
#          date            asof_datetime                timestamp ident okey_tk  \
# 0  2014-04-29  2014-04-29 13:37:03.000  2014-04-29 13:37:00.000  ABMD    ABMD
# 1  2014-04-29  2014-04-29 13:57:03.000  2014-04-29 13:57:00.000  ABMD    ABMD
# 2  2014-04-29  2014-04-29 15:27:03.000  2014-04-29 15:27:00.000  ABMD    ABMD
# 3  2014-04-29  2014-04-29 16:11:03.000  2014-04-29 16:11:00.000  ABMD    ABMD
# 4  2014-04-29  2014-04-29 16:45:03.000  2014-04-29 16:45:00.000  ABMD    ABMD
# 5  2014-04-29  2014-04-29 17:22:03.000  2014-04-29 17:22:00.000  ABMD    ABMD
# 6  2014-04-29  2014-04-29 18:47:03.000  2014-04-29 18:47:00.000  ABMD    ABMD
# 7  2014-04-29  2014-04-29 17:21:03.000  2014-04-29 17:21:00.000  ACHN    ACHN
# 8  2014-04-29  2014-04-29 19:29:03.000  2014-04-29 19:29:00.000  ACHN    ACHN
# 9  2014-04-29  2014-04-29 16:32:03.000  2014-04-29 16:32:00.000   AEC     AEC
#
#   tradingsession okey_at okey_cp  okey_dy  okey_mn  ... m4_neutral_volume  \
# 0     RegularMkt     EQT    Call       21        6  ...                 0
# 1     RegularMkt     EQT    Call       21        6  ...                 0
# 2     RegularMkt     EQT    Call       21        6  ...                 0
# 3     RegularMkt     EQT    Call       21        6  ...                 0
# 4     RegularMkt     EQT    Call       21        6  ...                 0
# 5     RegularMkt     EQT    Call       21        6  ...                 0
# 6     RegularMkt     EQT     Put       21        6  ...                 0
# 7     RegularMkt     EQT    Call       20       12  ...                 0
# 8     RegularMkt     EQT    Call       21        6  ...                 0
# 9     RegularMkt     EQT     Put       20       12  ...                 0
#
#    m4_num_buy_trades  m4_num_neutral_trades  m4_num_sell_trades  \
# 0                  0                      0                   1
# 1                  0                      0                   1
# 2                  0                      0                   1
# 3                  1                      0                   0
# 4                  1                      0                   0
# 5                  1                      0                   0
# 6                  1                      0                   0
# 7                  0                      0                   1
# 8                  1                      0                   0
# 9                  1                      0                   0
#
#    m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  m4_vega_neutral_volume  \
# 0               5          0.25               0.000                       0
# 1               1          0.41               0.000                       0
# 2               1          0.30               0.000                       0
# 3               0          0.00               0.105                       0
# 4               0          0.00               0.345                       0
# 5               0          0.00               0.074                       0
# 6               0          0.00               0.132                       0
# 7               4          0.35               0.000                       0
# 8               0          0.00               0.006                       0
# 9               0          0.00               0.052                       0
#
#    m4_vega_sell_volume   asof_date
# 0                0.095  2014-04-29
# 1                0.024  2014-04-29
# 2                0.021  2014-04-29
# 3                0.000  2014-04-29
# 4                0.000  2014-04-29
# 5                0.000  2014-04-29
# 6                0.000  2014-04-29
# 7                0.032  2014-04-29
# 8                0.000  2014-04-29
# 9                0.000  2014-04-29
#
# [10 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_equity_options_flow_1min_v2_4', back_to='2024-01-31', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date            asof_datetime                timestamp ident  \
# 0   2024-01-31  2024-01-31 18:40:03.000  2024-01-31 18:40:00.000  ACGL
# 1   2024-01-31  2024-01-31 18:41:03.000  2024-01-31 18:41:00.000  ACGL
# 2   2024-01-31  2024-01-31 18:42:03.000  2024-01-31 18:42:00.000  ACGL
# 3   2024-01-31  2024-01-31 18:59:03.000  2024-01-31 18:59:00.000  ACGL
# 4   2024-01-31  2024-01-31 19:01:03.000  2024-01-31 19:01:00.000  ACGL
# ..         ...                      ...                      ...   ...
# 95  2024-01-31  2024-01-31 18:42:03.000  2024-01-31 18:42:00.000  ADBE
# 96  2024-01-31  2024-01-31 18:42:03.000  2024-01-31 18:42:00.000  ADBE
# 97  2024-01-31  2024-01-31 18:44:03.000  2024-01-31 18:44:00.000  ADBE
# 98  2024-01-31  2024-01-31 18:44:03.000  2024-01-31 18:44:00.000  ADBE
# 99  2024-01-31  2024-01-31 18:44:03.000  2024-01-31 18:44:00.000  ADBE
#
#    okey_tk tradingsession okey_at okey_cp  okey_dy  okey_mn  ...  \
# 0     ACGL     RegularMkt     EQT     Put       15        3  ...
# 1     ACGL     RegularMkt     EQT    Call       16        2  ...
# 2     ACGL     RegularMkt     EQT    Call       15        3  ...
# 3     ACGL     RegularMkt     EQT    Call       15        3  ...
# 4     ACGL     RegularMkt     EQT    Call       16        2  ...
# ..     ...            ...     ...     ...      ...      ...  ...
# 95    ADBE     RegularMkt     EQT    Call        9        2  ...
# 96    ADBE     RegularMkt     EQT    Call       23        2  ...
# 97    ADBE     RegularMkt     EQT    Call       19        4  ...
# 98    ADBE     RegularMkt     EQT     Put        9        2  ...
# 99    ADBE     RegularMkt     EQT     Put        2        2  ...
#
#    m4_neutral_volume  m4_num_buy_trades  m4_num_neutral_trades  \
# 0                  0                  0                      0
# 1                  0                  0                      0
# 2                  0                  1                      0
# 3                  0                  1                      0
# 4                  0                  0                      0
# ..               ...                ...                    ...
# 95                 0                  1                      0
# 96                 0                  0                      0
# 97                 0                  1                      0
# 98                 0                  1                      0
# 99                 0                  0                      0
#
#     m4_num_sell_trades  m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  \
# 0                    1               2          0.65            0.000000
# 1                    1               2          1.00            0.000000
# 2                    0               0          0.00            0.420624
# 3                    0               0          0.00            0.050081
# 4                    1               1          0.95            0.000000
# ..                 ...             ...           ...                 ...
# 95                   0               0          0.00            1.366304
# 96                   4               9          2.27            0.000000
# 97                   0               0          0.00            1.142380
# 98                   0               0          0.00            0.347604
# 99                   1               1          1.10            0.000000
#
#     m4_vega_neutral_volume  m4_vega_sell_volume   asof_date
# 0                        0             0.133514  2024-01-31
# 1                        0             0.129144  2024-01-31
# 2                        0             0.000000  2024-01-31
# 3                        0             0.000000  2024-01-31
# 4                        0             0.063550  2024-01-31
# ..                     ...                  ...         ...
# 95                       0             0.000000  2024-01-31
# 96                       0             2.673126  2024-01-31
# 97                       0             0.000000  2024-01-31
# 98                       0             0.000000  2024-01-31
# 99                       0             0.111915  2024-01-31
#
# [100 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='lseg_us_equity_options_flow_1min_v2_4', key='SPXW', asof_date='2024-01-01', limit=10)
display(df)
# Out:
#          date            asof_datetime                timestamp ident okey_tk  \
# 0  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 1  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 2  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 3  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 4  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 5  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 6  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 7  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 8  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
# 9  2021-01-26  2021-01-26 16:30:03.000  2021-01-26 16:30:00.000  SPXW    SPXW
#
#   tradingsession okey_at okey_cp  okey_dy  okey_mn  ... m4_neutral_volume  \
# 0     RegularMkt     EQT     Put       26        2  ...                 0
# 1     RegularMkt     EQT     Put       27        1  ...                 0
# 2     RegularMkt     EQT    Call       29        1  ...                 1
# 3     RegularMkt     EQT     Put        1        2  ...                 0
# 4     RegularMkt     EQT     Put       26        2  ...                 0
# 5     RegularMkt     EQT     Put       27        1  ...                 0
# 6     RegularMkt     EQT    Call       27        1  ...                 0
# 7     RegularMkt     EQT    Call       27        1  ...                 0
# 8     RegularMkt     EQT    Call       29        1  ...                 2
# 9     RegularMkt     EQT     Put       27        1  ...                 0
#
#    m4_num_buy_trades  m4_num_neutral_trades  m4_num_sell_trades  \
# 0                  0                      0                   1
# 1                  0                      0                   1
# 2                  0                      1                   0
# 3                  0                      0                   1
# 4                  0                      0                   2
# 5                  1                      0                   0
# 6                  3                      0                   0
# 7                  0                      0                   1
# 8                  0                      1                   0
# 9                  0                      0                   2
#
#    m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  m4_vega_neutral_volume  \
# 0               1     37.200001              0.0000                  0.0000
# 1               5     22.900000              0.0000                  0.0000
# 2               0      0.000000              0.0000                  0.4523
# 3              10     31.299999              0.0000                  0.0000
# 4               2     39.450001              0.0000                  0.0000
# 5               0      0.000000              1.0626                  0.0000
# 6               0      0.000000              2.9433                  0.0000
# 7              50     18.700001              0.0000                  0.0000
# 8               0      0.000000              0.0000                  3.1094
# 9               4     15.225000              0.0000                  0.0000
#
#    m4_vega_sell_volume   asof_date
# 0             3.472600  2021-01-26
# 1             5.254500  2021-01-26
# 2             0.000000  2021-01-26
# 3            20.606000  2021-01-26
# 4             7.176300  2021-01-26
# 5             0.000000  2021-01-26
# 6             0.000000  2021-01-26
# 7            56.209999  2021-01-26
# 8             0.000000  2021-01-26
# 9             4.545200  2021-01-26
#
# [10 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_equity_options_flow_1min_v2_4',key='SPX', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date            asof_datetime                timestamp ident  \
# 0   2024-01-24  2024-01-24 17:55:03.000  2024-01-24 17:55:00.000   SPX
# 1   2024-01-24  2024-01-24 17:55:03.000  2024-01-24 17:55:00.000   SPX
# 2   2024-01-24  2024-01-24 17:55:03.000  2024-01-24 17:55:00.000   SPX
# 3   2024-01-24  2024-01-24 17:55:03.000  2024-01-24 17:55:00.000   SPX
# 4   2024-01-24  2024-01-24 17:55:03.000  2024-01-24 17:55:00.000   SPX
# ..         ...                      ...                      ...   ...
# 95  2024-01-24  2024-01-24 18:16:03.000  2024-01-24 18:16:00.000   SPX
# 96  2024-01-24  2024-01-24 18:16:03.000  2024-01-24 18:16:00.000   SPX
# 97  2024-01-24  2024-01-24 18:16:03.000  2024-01-24 18:16:00.000   SPX
# 98  2024-01-24  2024-01-24 18:16:03.000  2024-01-24 18:16:00.000   SPX
# 99  2024-01-24  2024-01-24 18:16:03.000  2024-01-24 18:16:00.000   SPX
#
#    okey_tk tradingsession okey_at okey_cp  okey_dy  okey_mn  ...  \
# 0      SPX     RegularMkt     EQT     Put       16        2  ...
# 1      SPX     RegularMkt     EQT    Call       15        3  ...
# 2      SPX     RegularMkt     EQT     Put       16        2  ...
# 3      SPX     RegularMkt     EQT    Call       19        4  ...
# 4      SPX     RegularMkt     EQT     Put       19        4  ...
# ..     ...            ...     ...     ...      ...      ...  ...
# 95     SPX     RegularMkt     EQT     Put       19        4  ...
# 96     SPX     RegularMkt     EQT     Put       21        6  ...
# 97     SPX     RegularMkt     EQT    Call       21        6  ...
# 98     SPX     RegularMkt     EQT     Put       21        6  ...
# 99     SPX     RegularMkt     EQT    Call       16        2  ...
#
#    m4_neutral_volume  m4_num_buy_trades  m4_num_neutral_trades  \
# 0                  0                  1                      0
# 1                  0                  1                      0
# 2                  0                  1                      0
# 3                  0                  0                      0
# 4                  0                  0                      0
# ..               ...                ...                    ...
# 95                 0                  2                      0
# 96                 0                  1                      0
# 97                 0                  0                      0
# 98                 0                  0                      0
# 99                 0                  2                      0
#
#     m4_num_sell_trades  m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  \
# 0                    0               0      0.000000           21.870251
# 1                    0               0      0.000000            7.191840
# 2                    0               0      0.000000           39.795799
# 3                    1               1    250.600006            0.000000
# 4                    1               6     31.500000            0.000000
# ..                 ...             ...           ...                 ...
# 95                   0               0      0.000000           66.127041
# 96                   0               0      0.000000           12.050400
# 97                   3               3    181.166667            0.000000
# 98                   1               1    137.500000            0.000000
# 99                   0               0      0.000000          207.672926
#
#     m4_vega_neutral_volume  m4_vega_sell_volume   asof_date
# 0                        0             0.000000  2024-01-24
# 1                        0             0.000000  2024-01-24
# 2                        0             0.000000  2024-01-24
# 3                        0             7.517780  2024-01-24
# 4                        0            34.803540  2024-01-24
# ..                     ...                  ...         ...
# 95                       0             0.000000  2024-01-24
# 96                       0             0.000000  2024-01-24
# 97                       0            36.611901  2024-01-24
# 98                       0            12.316900  2024-01-24
# 99                       0             0.000000  2024-01-24
#
# [100 rows x 109 columns]

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_equity_options_flow_1min_v2_4", target_location="./data", asof_date='2014-01-31')
# Out:
# Downloading using native python implementation for lseg_us_equity_options_flow_1min_v2_4...
# Found 1 files to download.
# Native replication completed for lseg_us_equity_options_flow_1min_v2_4. Downloaded 1 files.

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="lseg_us_equity_options_flow_1min_v2_4", target_location="./data")
