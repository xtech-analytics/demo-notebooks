# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier as Unifier

# %%
Unifier.user = 'unifier username'
Unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = Unifier.user
os.environ['UNIFIER_TOKEN'] = Unifier.token

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = Unifier.get_dataframe(name="lseg_us_equity_options_flow_1min_v2_3", asof_date='2024-01-31', limit=10)
display(df)
# Out:
#          date            asof_datetime                timestamp ident okey_tk  \
# 0  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 1  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 2  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 3  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 4  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 5  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 6  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 7  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 8  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 9  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
#
#   tradingsession okey_at okey_cp  okey_dy  okey_mn  ... m4_neutral_volume  \
# 0     RegularMkt     EQT     Put       14       10  ...                 0
# 1     RegularMkt     EQT    Call       14       10  ...                 0
# 2     RegularMkt     EQT     Put       19       10  ...                 0
# 3     RegularMkt     EQT     Put       14       10  ...                 0
# 4     RegularMkt     EQT    Call        9       11  ...                 0
# 5     RegularMkt     EQT     Put       19       10  ...                 0
# 6     RegularMkt     EQT    Call       14       10  ...                 0
# 7     RegularMkt     EQT     Put        4       11  ...                 0
# 8     RegularMkt     EQT    Call       31       10  ...                 0
# 9     RegularMkt     EQT    Call       14       10  ...                 0
#
#    m4_num_buy_trades  m4_num_neutral_trades  m4_num_sell_trades  \
# 0                  0                      0                   1
# 1                  0                      0                   1
# 2                  8                      0                   0
# 3                  1                      0                   0
# 4                  0                      0                   1
# 5                  8                      0                   0
# 6                  0                      0                   1
# 7                  1                      0                   0
# 8                  0                      0                   1
# 9                  0                      0                   1
#
#    m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  m4_vega_neutral_volume  \
# 0               1          9.00               0.000                       0
# 1               5          4.24               0.000                       0
# 2               0          0.00              18.882                       0
# 3               0          0.00               3.710                       0
# 4               2          1.73               0.000                       0
# 5               0          0.00              15.609                       0
# 6               5          2.82               0.000                       0
# 7               0          0.00               9.970                       0
# 8               2          2.87               0.000                       0
# 9               9          1.70               0.000                       0
#
#    m4_vega_sell_volume   asof_date
# 0                0.917  2016-10-11
# 1                3.910  2016-10-11
# 2                0.000  2016-10-11
# 3                0.000  2016-10-11
# 4                1.640  2016-10-11
# 5                0.000  2016-10-11
# 6                3.345  2016-10-11
# 7                0.000  2016-10-11
# 8                2.138  2016-10-11
# 9                4.734  2016-10-11
#
# [10 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_equity_options_flow_1min_v2_3', back_to='2024-01-31', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date            asof_datetime                timestamp ident  \
# 0   2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# 1   2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# 2   2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# 3   2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# 4   2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# ..         ...                      ...                      ...   ...
# 95  2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# 96  2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# 97  2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# 98  2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
# 99  2024-01-31  2024-01-31 23:30:30.000  2024-01-31 16:48:00.000  SPXW
#
#    okey_tk tradingsession okey_at okey_cp  okey_dy  okey_mn  ...  \
# 0     SPXW     RegularMkt     EQT     Put       31        1  ...
# 1     SPXW     RegularMkt     EQT     Put       31        1  ...
# 2     SPXW     RegularMkt     EQT     Put       31        1  ...
# 3     SPXW     RegularMkt     EQT     Put       31        1  ...
# 4     SPXW     RegularMkt     EQT     Put       31        1  ...
# ..     ...            ...     ...     ...      ...      ...  ...
# 95    SPXW     RegularMkt     EQT    Call        2        2  ...
# 96    SPXW     RegularMkt     EQT    Call        2        2  ...
# 97    SPXW     RegularMkt     EQT    Call        2        2  ...
# 98    SPXW     RegularMkt     EQT    Call        2        2  ...
# 99    SPXW     RegularMkt     EQT    Call        2        2  ...
#
#    m4_neutral_volume  m4_num_buy_trades  m4_num_neutral_trades  \
# 0                  0                  4                      0
# 1                  0                  2                      0
# 2                  0                  1                      0
# 3                  0                  0                      0
# 4                  0                  1                      0
# ..               ...                ...                    ...
# 95                 0                 10                      0
# 96                 0                  1                      0
# 97                 0                  2                      0
# 98                 0                  1                      0
# 99                 0                  2                      0
#
#     m4_num_sell_trades  m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  \
# 0                    0               0      0.000000            0.124524
# 1                    1               1      0.050000            0.057973
# 2                    2              10      0.080000            0.089210
# 3                    3              13      0.084615            0.000000
# 4                    0               0      0.000000            0.318639
# ..                 ...             ...           ...                 ...
# 95                   0               0      0.000000          134.487000
# 96                   0               0      0.000000            1.725500
# 97                   4              12     12.600000           81.387100
# 98                   0               0      0.000000            1.287780
# 99                   0               0      0.000000           11.987200
#
#     m4_vega_neutral_volume  m4_vega_sell_volume   asof_date
# 0                        0             0.000000  2024-01-31
# 1                        0             0.025296  2024-01-31
# 2                        0             0.381338  2024-01-31
# 3                        0             0.535514  2024-01-31
# 4                        0             0.000000  2024-01-31
# ..                     ...                  ...         ...
# 95                       0             0.000000  2024-01-31
# 96                       0             0.000000  2024-01-31
# 97                       0            18.800580  2024-01-31
# 98                       0             0.000000  2024-01-31
# 99                       0             0.000000  2024-01-31
#
# [100 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='ticker') using the asof_date parameter

# %%
df = Unifier.get_dataframe(name='lseg_us_equity_options_flow_1min_v2_3', key='SPXW', asof_date='2024-01-01', limit=10)
display(df)
# Out:
#          date            asof_datetime                timestamp ident okey_tk  \
# 0  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 1  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 2  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 3  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 4  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 5  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 6  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 7  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 8  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
# 9  2016-10-11  2016-10-11 23:30:30.000  2016-10-11 20:06:00.000  SPXW    SPXW
#
#   tradingsession okey_at okey_cp  okey_dy  okey_mn  ... m4_neutral_volume  \
# 0     RegularMkt     EQT     Put       14       10  ...                 0
# 1     RegularMkt     EQT    Call       14       10  ...                 0
# 2     RegularMkt     EQT     Put       19       10  ...                 0
# 3     RegularMkt     EQT     Put       14       10  ...                 0
# 4     RegularMkt     EQT    Call        9       11  ...                 0
# 5     RegularMkt     EQT     Put       19       10  ...                 0
# 6     RegularMkt     EQT    Call       14       10  ...                 0
# 7     RegularMkt     EQT     Put        4       11  ...                 0
# 8     RegularMkt     EQT    Call       31       10  ...                 0
# 9     RegularMkt     EQT    Call       14       10  ...                 0
#
#    m4_num_buy_trades  m4_num_neutral_trades  m4_num_sell_trades  \
# 0                  0                      0                   1
# 1                  0                      0                   1
# 2                  8                      0                   0
# 3                  1                      0                   0
# 4                  0                      0                   1
# 5                  8                      0                   0
# 6                  0                      0                   1
# 7                  1                      0                   0
# 8                  0                      0                   1
# 9                  0                      0                   1
#
#    m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  m4_vega_neutral_volume  \
# 0               1          9.00               0.000                       0
# 1               5          4.24               0.000                       0
# 2               0          0.00              18.882                       0
# 3               0          0.00               3.710                       0
# 4               2          1.73               0.000                       0
# 5               0          0.00              15.609                       0
# 6               5          2.82               0.000                       0
# 7               0          0.00               9.970                       0
# 8               2          2.87               0.000                       0
# 9               9          1.70               0.000                       0
#
#    m4_vega_sell_volume   asof_date
# 0                0.917  2016-10-11
# 1                3.910  2016-10-11
# 2                0.000  2016-10-11
# 3                0.000  2016-10-11
# 4                1.640  2016-10-11
# 5                0.000  2016-10-11
# 6                3.345  2016-10-11
# 7                0.000  2016-10-11
# 8                2.138  2016-10-11
# 9                4.734  2016-10-11
#
# [10 rows x 109 columns]

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='ticker') using the back_to and up_to parameters

# %%
df = Unifier.get_dataframe(name='lseg_us_equity_options_flow_1min_v2_3',key='SPX', back_to='2024-01-01', up_to='2024-02-01', limit=100)
display(df)
# Out:
#           date            asof_datetime                timestamp ident  \
# 0   2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:41:00.000   SPX
# 1   2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:41:00.000   SPX
# 2   2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:41:00.000   SPX
# 3   2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:41:00.000   SPX
# 4   2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:41:00.000   SPX
# ..         ...                      ...                      ...   ...
# 95  2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:45:00.000   SPX
# 96  2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:45:00.000   SPX
# 97  2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:45:00.000   SPX
# 98  2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:45:00.000   SPX
# 99  2024-01-09  2024-01-09 23:30:30.000  2024-01-09 17:45:00.000   SPX
#
#    okey_tk tradingsession okey_at okey_cp  okey_dy  okey_mn  ...  \
# 0      SPX     RegularMkt     EQT     Put       19        1  ...
# 1      SPX     RegularMkt     EQT     Put       19        1  ...
# 2      SPX     RegularMkt     EQT    Call       19        1  ...
# 3      SPX     RegularMkt     EQT     Put       16        2  ...
# 4      SPX     RegularMkt     EQT     Put       16        2  ...
# ..     ...            ...     ...     ...      ...      ...  ...
# 95     SPX     RegularMkt     EQT     Put       18       10  ...
# 96     SPX     RegularMkt     EQT     Put       18       10  ...
# 97     SPX     RegularMkt     EQT     Put       18       10  ...
# 98     SPX     RegularMkt     EQT    Call       20       12  ...
# 99     SPX     RegularMkt     EQT    Call       20       12  ...
#
#    m4_neutral_volume  m4_num_buy_trades  m4_num_neutral_trades  \
# 0                  0                  1                      0
# 1                  0                 10                      0
# 2                  0                  1                      0
# 3                  0                  1                      0
# 4                  0                  1                      0
# ..               ...                ...                    ...
# 95                 0                  0                      0
# 96                 0                  1                      0
# 97                 0                  1                      0
# 98                 0                  0                      0
# 99                 0                  0                      0
#
#     m4_num_sell_trades  m4_sell_volume  m4_sell_vwap  m4_vega_buy_volume  \
# 0                    0               0           0.0             3.96110
# 1                    0               0           0.0            19.88368
# 2                    0               0           0.0             3.06517
# 3                    0               0           0.0             3.85618
# 4                    0               0           0.0             4.58839
# ..                 ...             ...           ...                 ...
# 95                   1               1          28.8             0.00000
# 96                   0               0           0.0             6.25044
# 97                   0               0           0.0             6.63359
# 98                   1               1         289.8             0.00000
# 99                   1               1         207.4             0.00000
#
#     m4_vega_neutral_volume  m4_vega_sell_volume   asof_date
# 0                        0               0.0000  2024-01-09
# 1                        0               0.0000  2024-01-09
# 2                        0               0.0000  2024-01-09
# 3                        0               0.0000  2024-01-09
# 4                        0               0.0000  2024-01-09
# ..                     ...                  ...         ...
# 95                       0               4.9145  2024-01-09
# 96                       0               0.0000  2024-01-09
# 97                       0               0.0000  2024-01-09
# 98                       0              18.1417  2024-01-09
# 99                       0              18.1815  2024-01-09
#
# [100 rows x 109 columns]

# %% [markdown]
# ## Download data file for a specific date using asof_date

# %%
Unifier.replicate(name="lseg_us_equity_options_flow_1min_v2_3", target_location="./data", asof_date='2014-01-31')

# %% [markdown]
# ## Download all data files

# %%
Unifier.replicate(name="lseg_us_equity_options_flow_1min_v2_3", target_location="./data")
