# %%
import os
from IPython.display import display

# %%
# %pip install unifier --upgrade
# Out:
# Requirement already satisfied: unifier in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (0.1.20)
# Requirement already satisfied: requests in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from unifier) (2.32.5)
# Requirement already satisfied: pandas in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from unifier) (3.0.1)
# Requirement already satisfied: boto3 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from unifier) (1.42.75)
# Requirement already satisfied: botocore<1.43.0,>=1.42.75 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from boto3->unifier) (1.42.75)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from boto3->unifier) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from boto3->unifier) (0.16.0)
# Requirement already satisfied: numpy>=1.26.0 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from pandas->unifier) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from pandas->unifier) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from requests->unifier) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from requests->unifier) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from requests->unifier) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from requests->unifier) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /home/kiwitech/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->unifier) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from unifier import unifier

# %%
unifier.user = 'unifier email'
unifier.token ='unifier api token'
os.environ['UNIFIER_USER'] = unifier.user
os.environ['UNIFIER_TOKEN'] = unifier.token

# %% [markdown]
# Your 'unifier username' is your account email address, and your 'unifier api token' is your account api token found in the access my data page.
#
# Dataset: xtech_apollo_group_aggregates_red_eagle,
#  xtech_apollo_group_style_aggregates_gross_position_style_red_eagle,
#  xtech_apollo_group_style_aggregates_trade_size_style_red_eagle,
#  xtech_apollo_group_style_aggregates_turnover_style_red_eagle

# %%
# Replicate a large dataset to a local folder
# Note: rclone must be installed on your system
unifier.replicate(
    name="xtech_apollo_group_aggregates_red_eagle",
    target_location="./your_local_path",
    back_to="",    # Optional: fetch history back to this date
    up_to="",    # Optional: fetch history up to this date
    bandwidth_limit=20       # Optional: limit download speed to 20MB/s
)
# Out:
# Downloading using native python implementation for xtech_apollo_group_aggregates_red_eagle...
# Found 1880 files to download.
# Downloaded 10/1880 files...
# Downloaded 20/1880 files...
# Downloaded 30/1880 files...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Replicate a large dataset to a local folder
#       2 # Note: rclone must be installed on your system
# ----> 3 unifier.replicate(
#       4     name="xtech_apollo_group_aggregates_red_eagle",
#       5     target_location="/home/kiwitech/workspace/eponential_work_tracking/demo_download",
#       6     back_to="",    # Optional: fetch history back to this date
#       7     up_to="",    # Optional: fetch history up to this date
#       8     bandwidth_limit=20       # Optional: limit download speed to 20MB/s
#       9 )
#
# File ~/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages/unifier/unifier.py:493, in Unifier.replicate(cls, name, target_location, asof_date, back_to, up_to, bandwidth_limit, use_rclone)
#     491         print(f"Replication completed for {name}")
#     492     else:
# --> 493         cls._replicate_native(
#     494             access_key_id=access_key_id,
#     495             secret_access_key=secret_access_key,
#     496             endpoint=endpoint,
#     497             region=region,
#     498             data_path=data_path,
#     499             target_location=target_location,
#     500             folders=folders,
#     501             name=name
#     502         )
#     504 except requests.exceptions.RequestException as e:
#     505     err_msg = f"Replicate network request failed: {e}"
#
# File ~/workspace/eponential_work_tracking/.venv/lib/python3.12/site-packages/unifier/unifier.py:609, in Unifier._replicate_native(cls, access_key_id, secret_access_key, endpoint, region, data_path, target_location, folders, name)
#     606 completed_count = 0
#     607 with ThreadPoolExecutor(max_workers=10) as executor:
#     608     # We use list() to consume the iterator and wait for all tasks to complete
# --> 609     for _ in executor.map(_download_one, download_tasks):
#     610         completed_count += 1
#     611         if completed_count % 10 == 0:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
df = unifier.get_dataframe(name="xtech_apollo_group_aggregates_red_eagle", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#                   asof_date  trade_date sector mds_exchange exchange_country  \
# 0   2021-01-05 00:00:00.000    20210104    EQY        EUREX              DEU
# 1   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 2   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 3   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 4   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 5   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 6   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 7   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 8   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 9   2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 10  2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 11  2021-01-05 00:00:00.000    20210104    NRG          IPE              GBR
# 12  2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 13  2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 14  2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 15  2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 16  2021-01-05 00:00:00.000    20210104    AGR         CBOT              USA
# 17  2021-01-05 00:00:00.000    20210104    INT         CBOT              USA
# 18  2021-01-05 00:00:00.000    20210104    INT         CBOT              USA
# 19  2021-01-05 00:00:00.000    20210104    INT         CBOT              USA
#
#    reportable_product                          product_name  \
# 0                  (H  EUREX STOXX EUROPE 600 ESG-X FUTURES
# 1                  06              CBOT SOYBEAN MEAL FUTURE
# 2                  06              CBOT SOYBEAN MEAL FUTURE
# 3                  06              CBOT SOYBEAN MEAL FUTURE
# 4                  06              CBOT SOYBEAN MEAL FUTURE
# 5                  06              CBOT SOYBEAN MEAL FUTURE
# 6                  07               CBOT SOYBEAN OIL FUTURE
# 7                  07               CBOT SOYBEAN OIL FUTURE
# 8                  07               CBOT SOYBEAN OIL FUTURE
# 9                  07               CBOT SOYBEAN OIL FUTURE
# 10                 07               CBOT SOYBEAN OIL FUTURE
# 11                14Y    ICEEU ULSD 10PPM CIF NWE CARGOES F
# 12                 14            CBOT CRC ROUGH RICE FUTURE
# 13                 14            CBOT CRC ROUGH RICE FUTURE
# 14                 14            CBOT CRC ROUGH RICE FUTURE
# 15                 14            CBOT CRC ROUGH RICE FUTURE
# 16                 14            CBOT CRC ROUGH RICE FUTURE
# 17                 17          CBOT US TREASURY BOND FUTURE
# 18                 17          CBOT US TREASURY BOND FUTURE
# 19                 17          CBOT US TREASURY BOND FUTURE
#
#              xt_group  direction  long_dollar_value  short_dollar_value  \
# 0   other_reportables        NaN                NaN                 NaN
# 1            producer        1.0       7.371172e+08        4.775354e+08
# 2       nonreportable        1.0       2.644754e+07        1.546508e+07
# 3   other_reportables        1.0       7.936906e+07        2.591101e+07
# 4                swap       -1.0       8.190700e+06        2.750862e+07
# 5       managed_money        1.0       6.862702e+07        9.317720e+06
# 6            producer       -1.0       2.006969e+08        2.108687e+08
# 7       nonreportable        1.0       8.901712e+07        7.795236e+06
# 8   other_reportables        1.0       9.437258e+07        2.926698e+07
# 9                swap       -1.0       9.648540e+05        1.395262e+07
# 10      managed_money        1.0       9.735136e+07        1.988843e+07
# 11  other_reportables        NaN                NaN                 NaN
# 12           producer        NaN                NaN                 NaN
# 13      nonreportable        NaN                NaN                 NaN
# 14  other_reportables        NaN                NaN                 NaN
# 15               swap        NaN                NaN                 NaN
# 16      managed_money        NaN                NaN                 NaN
# 17           producer        NaN                NaN                 NaN
# 18      nonreportable        1.0       4.233210e+09        9.170656e+06
# 19  other_reportables       -1.0       5.588909e+07        1.197376e+08
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0                NaN                 NaN            NaN             NaN
# 1       2.595817e+08        1.214653e+09        35017.0         28519.0
# 2       1.098246e+07        4.191262e+07          706.0           431.0
# 3       5.345805e+07        1.052801e+08         2262.0          1003.0
# 4      -1.931792e+07        3.569932e+07          203.0           657.0
# 5       5.930930e+07        7.794474e+07         1752.0           346.0
# 6      -1.017180e+07        4.115657e+08        13846.0         14092.0
# 7       8.122188e+07        9.681235e+07         3836.0           473.0
# 8       6.510560e+07        1.236396e+08         3971.0          1305.0
# 9      -1.298777e+07        1.491748e+07           39.0           554.0
# 10      7.746293e+07        1.172398e+08         4085.0           947.0
# 11               NaN                 NaN            NaN             NaN
# 12               NaN                 NaN            NaN             NaN
# 13               NaN                 NaN            NaN             NaN
# 14               NaN                 NaN            NaN             NaN
# 15               NaN                 NaN            NaN             NaN
# 16               NaN                 NaN            NaN             NaN
# 17               NaN                 NaN            NaN             NaN
# 18      4.224039e+09        4.242380e+09        24465.0            53.0
# 19     -6.384853e+07        1.756267e+08          328.0           697.0
#
#     net_position  gross_position  long_position_concentration  \
# 0            NaN             NaN                          NaN
# 1         6498.0         63536.0                     0.050021
# 2          275.0          1137.0                     0.043663
# 3         1259.0          3265.0                     0.176800
# 4         -454.0           860.0                     0.134883
# 5         1406.0          2098.0                     0.083932
# 6         -246.0         27938.0                     0.102484
# 7         3363.0          4309.0                     0.075421
# 8         2666.0          5276.0                     0.077201
# 9         -515.0           593.0                     0.303820
# 10        3138.0          5032.0                     0.072371
# 11           NaN             NaN                          NaN
# 12           NaN             NaN                          NaN
# 13           NaN             NaN                          NaN
# 14           NaN             NaN                          NaN
# 15           NaN             NaN                          NaN
# 16           NaN             NaN                          NaN
# 17           NaN             NaN                          NaN
# 18       24412.0         24518.0                     0.493449
# 19        -369.0          1025.0                     0.347219
#
#     short_position_concentration  combined_position_concentration
# 0                            NaN                              NaN
# 1                       0.053017                         0.026616
# 2                       0.239159                         0.049947
# 3                       0.183634                         0.111606
# 4                       0.647071                         0.391311
# 5                       0.548584                         0.072904
# 6                       0.076300                         0.044400
# 7                       0.354733                         0.066064
# 8                       0.216523                         0.057111
# 9                       0.470708                         0.413058
# 10                      0.621546                         0.067786
# 11                           NaN                              NaN
# 12                           NaN                              NaN
# 13                           NaN                              NaN
# 14                           NaN                              NaN
# 15                           NaN                              NaN
# 16                           NaN                              NaN
# 17                           NaN                              NaN
# 18                      0.177643                         0.491319
# 19                      0.246709                         0.149836

# %%
df = unifier.get_dataframe(name="xtech_apollo_group_style_aggregates_gross_position_style_red_eagle", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#                   asof_date  trade_date sector mds_exchange exchange_country  \
# 0   2021-01-13 00:00:00.000    20210112    EQY        EUREX              DEU
# 1   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 2   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 3   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 4   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 5   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 6   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 7   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 8   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 9   2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 10  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 11  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 12  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 13  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 14  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 15  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 16  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 17  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 18  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
# 19  2021-01-13 00:00:00.000    20210112    AGR         CBOT              USA
#
#    reportable_product                          product_name  \
# 0                  (H  EUREX STOXX EUROPE 600 ESG-X FUTURES
# 1                  06              CBOT SOYBEAN MEAL FUTURE
# 2                  06              CBOT SOYBEAN MEAL FUTURE
# 3                  06              CBOT SOYBEAN MEAL FUTURE
# 4                  06              CBOT SOYBEAN MEAL FUTURE
# 5                  06              CBOT SOYBEAN MEAL FUTURE
# 6                  06              CBOT SOYBEAN MEAL FUTURE
# 7                  06              CBOT SOYBEAN MEAL FUTURE
# 8                  06              CBOT SOYBEAN MEAL FUTURE
# 9                  06              CBOT SOYBEAN MEAL FUTURE
# 10                 06              CBOT SOYBEAN MEAL FUTURE
# 11                 06              CBOT SOYBEAN MEAL FUTURE
# 12                 06              CBOT SOYBEAN MEAL FUTURE
# 13                 06              CBOT SOYBEAN MEAL FUTURE
# 14                 06              CBOT SOYBEAN MEAL FUTURE
# 15                 06              CBOT SOYBEAN MEAL FUTURE
# 16                 07               CBOT SOYBEAN OIL FUTURE
# 17                 07               CBOT SOYBEAN OIL FUTURE
# 18                 07               CBOT SOYBEAN OIL FUTURE
# 19                 07               CBOT SOYBEAN OIL FUTURE
#
#              xt_group position_style  direction  ...  short_dollar_value  \
# 0   other_reportables          large          1  ...                 NaN
# 1       managed_money          small          1  ...                 0.0
# 2       managed_money         medium          1  ...           1023880.0
# 3       managed_money          large          1  ...             15120.0
# 4       nonreportable          small          1  ...            187800.0
# 5       nonreportable         medium          1  ...                 NaN
# 6       nonreportable          large          1  ...                 NaN
# 7   other_reportables          small          1  ...                 NaN
# 8   other_reportables         medium          1  ...           1045060.0
# 9   other_reportables          large          1  ...                 NaN
# 10           producer          small          1  ...            487680.0
# 11           producer         medium          1  ...          14551020.0
# 12           producer          large          1  ...         351610340.0
# 13               swap          small          1  ...                 NaN
# 14               swap         medium          1  ...                 NaN
# 15               swap          large         -1  ...                 NaN
# 16      managed_money          small          1  ...             77628.0
# 17      managed_money         medium          1  ...              9750.0
# 18      managed_money          large          1  ...            109200.0
# 19      nonreportable          small          1  ...             76734.0
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0                NaN                 NaN            NaN             NaN
# 1          2349930.0        2.349930e+06           70.0            20.0
# 2          6717480.0        8.765240e+06          190.0            44.0
# 3         46308620.0        4.633886e+07         1331.0           326.0
# 4          2188630.0        2.564230e+06           54.0             6.0
# 5                NaN                 NaN            NaN             NaN
# 6                NaN                 NaN            NaN             NaN
# 7                NaN                 NaN            NaN             NaN
# 8          2748450.0        4.838570e+06          121.0            61.0
# 9                NaN                 NaN            NaN             NaN
# 10         9533920.0        1.050928e+07          239.0            24.0
# 11        28980960.0        5.808300e+07         1186.0           510.0
# 12       297614260.0        1.000835e+09        28725.0         21795.0
# 13               NaN                 NaN            NaN             NaN
# 14               NaN                 NaN            NaN             NaN
# 15               NaN                 NaN            NaN             NaN
# 16         2143914.0        2.299170e+06           93.0             9.0
# 17         6128052.0        6.147552e+06          270.0            30.0
# 18        61842318.0        6.206072e+07         3439.0           976.0
# 19          816444.0        9.699120e+05           37.0             5.0
#
#     net_position  gross_position  long_position_concentration  \
# 0            NaN             NaN                          NaN
# 1           50.0            90.0                     0.085954
# 2          146.0           234.0                     0.206893
# 3         1005.0          1657.0                     0.159425
# 4           48.0            60.0                     0.063647
# 5            NaN             NaN                          NaN
# 6            NaN             NaN                          NaN
# 7            NaN             NaN                          NaN
# 8           60.0           182.0                     0.126877
# 9            NaN             NaN                          NaN
# 10         215.0           263.0                     0.051520
# 11         676.0          1696.0                     0.032083
# 12        6930.0         50520.0                     0.271686
# 13           NaN             NaN                          NaN
# 14           NaN             NaN                          NaN
# 15           NaN             NaN                          NaN
# 16          84.0           102.0                     0.062793
# 17         240.0           300.0                     0.066896
# 18        2463.0          4415.0                     0.112697
# 19          32.0            42.0                     0.062266
#
#     short_position_concentration  combined_position_concentration
# 0                            NaN                              NaN
# 1                       0.000000                         0.085954
# 2                       0.537190                         0.168711
# 3                       1.000000                         0.159321
# 4                       0.245698                         0.055983
# 5                            NaN                              NaN
# 6                            NaN                              NaN
# 7                            NaN                              NaN
# 8                       0.576736                         0.104893
# 9                            NaN                              NaN
# 10                      0.189304                         0.047257
# 11                      0.279374                         0.035555
# 12                      0.082170                         0.124464
# 13                           NaN                              NaN
# 14                           NaN                              NaN
# 15                           NaN                              NaN
# 16                      0.542966                         0.059243
# 17                      0.226374                         0.066685
# 18                      0.199441                         0.112301
# 19                      1.000000                         0.059063
#
# [20 rows x 21 columns]

# %%
df = unifier.get_dataframe(name="xtech_apollo_group_style_aggregates_trade_size_style_red_eagle", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#                   asof_date  trade_date sector mds_exchange exchange_country  \
# 0   2021-01-07 00:00:00.000    20210106    EQY        EUREX              DEU
# 1   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 2   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 3   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 4   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 5   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 6   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 7   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 8   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 9   2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 10  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 11  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 12  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 13  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 14  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 15  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 16  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 17  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 18  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
# 19  2021-01-07 00:00:00.000    20210106    AGR         CBOT              USA
#
#    reportable_product                          product_name  \
# 0                  (H  EUREX STOXX EUROPE 600 ESG-X FUTURES
# 1                  06              CBOT SOYBEAN MEAL FUTURE
# 2                  06              CBOT SOYBEAN MEAL FUTURE
# 3                  06              CBOT SOYBEAN MEAL FUTURE
# 4                  06              CBOT SOYBEAN MEAL FUTURE
# 5                  06              CBOT SOYBEAN MEAL FUTURE
# 6                  06              CBOT SOYBEAN MEAL FUTURE
# 7                  06              CBOT SOYBEAN MEAL FUTURE
# 8                  06              CBOT SOYBEAN MEAL FUTURE
# 9                  06              CBOT SOYBEAN MEAL FUTURE
# 10                 06              CBOT SOYBEAN MEAL FUTURE
# 11                 06              CBOT SOYBEAN MEAL FUTURE
# 12                 06              CBOT SOYBEAN MEAL FUTURE
# 13                 07               CBOT SOYBEAN OIL FUTURE
# 14                 07               CBOT SOYBEAN OIL FUTURE
# 15                 07               CBOT SOYBEAN OIL FUTURE
# 16                 07               CBOT SOYBEAN OIL FUTURE
# 17                 07               CBOT SOYBEAN OIL FUTURE
# 18                 07               CBOT SOYBEAN OIL FUTURE
# 19                 07               CBOT SOYBEAN OIL FUTURE
#
#              xt_group trade_size_style  direction  ...  short_dollar_value  \
# 0   other_reportables            large          1  ...                 NaN
# 1       managed_money            small          1  ...            525960.0
# 2       managed_money           medium          1  ...                 NaN
# 3       nonreportable            small          1  ...           6885640.0
# 4       nonreportable           medium         -1  ...                 NaN
# 5   other_reportables            small          1  ...            896430.0
# 6   other_reportables           medium          1  ...                 NaN
# 7            producer            small          1  ...         104876260.0
# 8            producer           medium          1  ...         239232810.0
# 9            producer            large          1  ...                 NaN
# 10               swap            small          1  ...                 NaN
# 11               swap           medium          1  ...                 NaN
# 12               swap            large         -1  ...                 NaN
# 13      managed_money            small          1  ...            269976.0
# 14      managed_money           medium          1  ...                 NaN
# 15      nonreportable            small          1  ...             64122.0
# 16      nonreportable           medium          1  ...                 NaN
# 17  other_reportables            small          1  ...          15010506.0
# 18  other_reportables           medium          1  ...                 NaN
# 19           producer            small          1  ...         121535718.0
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0                NaN                 NaN            NaN             NaN
# 1         48213820.0          49265740.0         1172.0            66.0
# 2                NaN                 NaN            NaN             NaN
# 3         28184350.0          41955630.0         1012.0           301.0
# 4                NaN                 NaN            NaN             NaN
# 5         50821530.0          52614390.0         1363.0           192.0
# 6                NaN                 NaN            NaN             NaN
# 7        112558510.0         322311030.0         6956.0          4275.0
# 8        176421670.0         654887290.0        19217.0         14845.0
# 9                NaN                 NaN            NaN             NaN
# 10               NaN                 NaN            NaN             NaN
# 11               NaN                 NaN            NaN             NaN
# 12               NaN                 NaN            NaN             NaN
# 13        61238862.0          61778814.0         2512.0           174.0
# 14               NaN                 NaN            NaN             NaN
# 15        86220066.0          86348310.0         3644.0           205.0
# 16               NaN                 NaN            NaN             NaN
# 17        44824584.0          74845596.0         2416.0           620.0
# 18               NaN                 NaN            NaN             NaN
# 19         4758852.0         247830288.0         6527.0          6258.0
#
#     net_position  gross_position  long_position_concentration  \
# 0            NaN             NaN                          NaN
# 1         1106.0          1238.0                     0.133714
# 2            NaN             NaN                          NaN
# 3          711.0          1313.0                     0.331012
# 4            NaN             NaN                          NaN
# 5         1171.0          1555.0                     0.397390
# 6            NaN             NaN                          NaN
# 7         2681.0         11231.0                     0.062496
# 8         4372.0         34062.0                     0.580607
# 9            NaN             NaN                          NaN
# 10           NaN             NaN                          NaN
# 11           NaN             NaN                          NaN
# 12           NaN             NaN                          NaN
# 13        2338.0          2686.0                     0.099706
# 14           NaN             NaN                          NaN
# 15        3439.0          3849.0                     0.569706
# 16           NaN             NaN                          NaN
# 17        1796.0          3036.0                     0.552351
# 18           NaN             NaN                          NaN
# 19         269.0         12785.0                     0.223175
#
#     short_position_concentration  combined_position_concentration
# 0                            NaN                              NaN
# 1                       0.513889                         0.130933
# 2                            NaN                              NaN
# 3                       0.403146                         0.242136
# 4                            NaN                              NaN
# 5                       0.263324                         0.384041
# 6                            NaN                              NaN
# 7                       0.165492                         0.045964
# 8                       0.149467                         0.253837
# 9                            NaN                              NaN
# 10                           NaN                              NaN
# 11                           NaN                              NaN
# 12                           NaN                              NaN
# 13                      0.082467                         0.098838
# 14                           NaN                              NaN
# 15                      0.684232                         0.568860
# 16                           NaN                              NaN
# 17                      0.964038                         0.391791
# 18                           NaN                              NaN
# 19                      0.165915                         0.097858
#
# [20 rows x 21 columns]

# %%
df = unifier.get_dataframe(name="xtech_apollo_group_style_aggregates_turnover_style_red_eagle", back_to="2021-01-03" , up_to="2021-02-03", limit=20)
display(df)
# Out:
#                   asof_date  trade_date sector mds_exchange exchange_country  \
# 0   2021-01-12 00:00:00.000    20210111    EQY        EUREX              DEU
# 1   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 2   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 3   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 4   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 5   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 6   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 7   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 8   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 9   2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 10  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 11  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 12  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 13  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 14  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 15  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 16  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 17  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 18  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
# 19  2021-01-12 00:00:00.000    20210111    AGR         CBOT              USA
#
#    reportable_product                          product_name  \
# 0                  (H  EUREX STOXX EUROPE 600 ESG-X FUTURES
# 1                  06              CBOT SOYBEAN MEAL FUTURE
# 2                  06              CBOT SOYBEAN MEAL FUTURE
# 3                  06              CBOT SOYBEAN MEAL FUTURE
# 4                  06              CBOT SOYBEAN MEAL FUTURE
# 5                  06              CBOT SOYBEAN MEAL FUTURE
# 6                  06              CBOT SOYBEAN MEAL FUTURE
# 7                  06              CBOT SOYBEAN MEAL FUTURE
# 8                  06              CBOT SOYBEAN MEAL FUTURE
# 9                  06              CBOT SOYBEAN MEAL FUTURE
# 10                 06              CBOT SOYBEAN MEAL FUTURE
# 11                 07               CBOT SOYBEAN OIL FUTURE
# 12                 07               CBOT SOYBEAN OIL FUTURE
# 13                 07               CBOT SOYBEAN OIL FUTURE
# 14                 07               CBOT SOYBEAN OIL FUTURE
# 15                 07               CBOT SOYBEAN OIL FUTURE
# 16                 07               CBOT SOYBEAN OIL FUTURE
# 17                 07               CBOT SOYBEAN OIL FUTURE
# 18                 07               CBOT SOYBEAN OIL FUTURE
# 19                 07               CBOT SOYBEAN OIL FUTURE
#
#              xt_group turnover_style  direction  ...  short_dollar_value  \
# 0   other_reportables         medium          1  ...                 NaN
# 1       managed_money            low          1  ...           1563800.0
# 2       managed_money         medium          1  ...                 NaN
# 3       nonreportable            low          1  ...          12025640.0
# 4       nonreportable         medium         -1  ...                 NaN
# 5   other_reportables            low          1  ...           8770060.0
# 6   other_reportables         medium          1  ...                 NaN
# 7            producer            low          1  ...         246613460.0
# 8            producer         medium         -1  ...                 NaN
# 9                swap            low          1  ...                 NaN
# 10               swap         medium         -1  ...                 NaN
# 11      managed_money            low          1  ...            234552.0
# 12      managed_money         medium          1  ...                 NaN
# 13      nonreportable            low          1  ...            148968.0
# 14      nonreportable         medium          1  ...                 NaN
# 15  other_reportables            low          1  ...          18541848.0
# 16  other_reportables         medium          1  ...                 NaN
# 17           producer            low         -1  ...         152731434.0
# 18           producer         medium         -1  ...                 NaN
# 19               swap            low         -1  ...                 NaN
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0                NaN                 NaN            NaN             NaN
# 1         46198670.0          49326270.0         1491.0           446.0
# 2                NaN                 NaN            NaN             NaN
# 3         15326090.0          39377370.0          766.0           395.0
# 4                NaN                 NaN            NaN             NaN
# 5         44703940.0          62244060.0         1813.0           775.0
# 6                NaN                 NaN            NaN             NaN
# 7        418448680.0         911675600.0        20306.0         10418.0
# 8                NaN                 NaN            NaN             NaN
# 9                NaN                 NaN            NaN             NaN
# 10               NaN                 NaN            NaN             NaN
# 11        71883642.0          72352746.0         3867.0          1009.0
# 12               NaN                 NaN            NaN             NaN
# 13        91701942.0          91999878.0         4204.0           482.0
# 14               NaN                 NaN            NaN             NaN
# 15        55731300.0          92814996.0         3119.0           863.0
# 16               NaN                 NaN            NaN             NaN
# 17       -12847566.0         292615302.0        12269.0         12697.0
# 18               NaN                 NaN            NaN             NaN
# 19               NaN                 NaN            NaN             NaN
#
#     net_position  gross_position  long_position_concentration  \
# 0            NaN             NaN                          NaN
# 1         1045.0          1937.0                     0.138632
# 2            NaN             NaN                          NaN
# 3          371.0          1161.0                     0.281986
# 4            NaN             NaN                          NaN
# 5         1038.0          2588.0                     0.366425
# 6            NaN             NaN                          NaN
# 7         9888.0         30724.0                     0.268255
# 8            NaN             NaN                          NaN
# 9            NaN             NaN                          NaN
# 10           NaN             NaN                          NaN
# 11        2858.0          4876.0                     0.084744
# 12           NaN             NaN                          NaN
# 13        3722.0          4686.0                     0.607616
# 14           NaN             NaN                          NaN
# 15        2256.0          3982.0                     0.357513
# 16           NaN             NaN                          NaN
# 17        -428.0         24966.0                     0.218830
# 18           NaN             NaN                          NaN
# 19           NaN             NaN                          NaN
#
#     short_position_concentration  combined_position_concentration
# 0                            NaN                              NaN
# 1                       0.369796                         0.130352
# 2                            NaN                              NaN
# 3                       0.313726                         0.165312
# 4                            NaN                              NaN
# 5                       0.698277                         0.284305
# 6                            NaN                              NaN
# 7                       0.115588                         0.151213
# 8                            NaN                              NaN
# 9                            NaN                              NaN
# 10                           NaN                              NaN
# 11                      0.139003                         0.084197
# 12                           NaN                              NaN
# 13                      0.455250                         0.605651
# 14                           NaN                              NaN
# 15                      0.628314                         0.254014
# 16                           NaN                              NaN
# 17                      0.107984                         0.079428
# 18                           NaN                              NaN
# 19                           NaN                              NaN
#
# [20 rows x 21 columns]
