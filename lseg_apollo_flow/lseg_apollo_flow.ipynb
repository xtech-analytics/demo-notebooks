# %% [markdown]
# # LSEG Apollo Flow Demo Notebook

# %% [markdown]
# # Unifier Data Warehouse & API Simplify Data Access With A Single Interface

# %%
import os
from IPython.display import display

# %% [markdown]
# ### If you have not installed unifier you can do so by running the following command:

# %%
#pip install unifier

# %% [markdown]
# ## Simply Import and initialize Unifier and Go!

# %%
from unifier import unifier

# %%
unifier.user = 'unifier username'
unifier.token = 'unifier api token'
os.environ['UNIFIER_USER'] = unifier.user
os.environ['UNIFIER_TOKEN'] = unifier.token

# %% [markdown]
# #### Your 'unifier username' is your account email address, and your 'unifier api token' is your account api token found in the access my data page.

# %% [markdown]
# # LSEG Apollo Flow Documentation
#
# ## Description
# The **LSEG Apollo Flow™** provides unparalleled insights into global futures trading flows, aggregated by investor type. This dataset decipher’s the complex trading behaviors and active risk-taking by institutional buy-side, market makers, natural hedgers, and retail futures traders. By analyzing these trading behaviors on public futures markets and recomposing them by investor type, product and trading style, LSEG Apollo Flow™ offers valuable market insights characterized through measurable trading behavior. This data analytic is similar to the CFTC Commitment Of Traders Report, but is offered on a daily basis rather than only on Fridays based on date from End-of-day Tuesday. The direction and style of active risk-takers is identified using proprietary methods, and the resulting trading flows are aggregated daily. This dataset is ideal for developing institutional investment strategies with holding periods ranging from next-day intraday to several months.
#
# ### Key Details
# - **Product**: LSEG Apollo Flow™  (Turnover Rate, Trade Size, Position Size, Global Futures)
# - **Version**: Green Buffalo
# - **Coverage**: Top 100-300 Global Futures Products (All Expiries)
# - **Delivery Frequency**: Daily End of Day (EOD)
# - **Delivery Time**: 7 am UTC on T+1
# - **Delivery Method**: Unifier API
# - **Data Frequency**: Daily, Weekly
# - **Data Size**: 250K/day
# - **Deep History**: 1/1/2019-Present (5+ years)
# - **Data Description**: Contains Aggregate Gross, Net Long/Short Positions and Concentration Metrics grouped by Product, Investor Types (A: Producers/Hedgers, B: Fund Managers, C: Broker-Dealers, D: Other) and average Trade Size Style (Small, Medium, Large).
#
# ---
#
# ## Dataset: **`lseg_apollo_group_aggregates_green_buffalo`** (Green Buffalo), **`lseg_apollo_group_style_aggregates_turnover_style_green_buffalo`** (aggregated by turnover style), **`lseg_apollo_group_style_aggregates_trade_size_style_green_buffalo`** (aggregated by trade size style), **`lseg_apollo_group_style_aggregates_gross_position_style_green_buffalo`** (aggregated by gross position style)
#
# ### How is this dataset unique?
# This is a new dataset, complete with no missing or incorrect data sourced directly from a clearing system. Post anonymization and aggregation, it has an unparalleled ability to characterize daily trading behavior of investors in order to group them by investor type just like the Commitment of Traders which is only published on T+4 on Friday’s at 3:30 pm ET.
# In addition to the much higher frequency, few sources have the market share (as much as 45% market share in some products) to have sufficient sampling of each investor type. Future versions will have even more granular investor types and could include spreads, swaps and options. The data provides accurate market intelligence by investor type for the most liquid global futures contracts.
#
# ### Applications
# - **Intraday Strategy Development**: Supports strategies with holding periods ranging from minutes to hours.
# - **Historical Analysis**: Access over 10 years of historical data for backtesting and trend analysis.
# - **Market Behavior Research**: Understand the net buying/selling activity by different investor types.
#
# ---
#
# ### Common Field Descriptions
#
# | **Column Name**   | **Data Type** | **Description**                                                                 |
# |--------------------|---------------|---------------------------------------------------------------------------------|
# | `timestamp`          | varchar        | The timestamp as a string, indicating when the data was captured or recorded.                              |
# | `muts`          | bigint        | Unix millisecond timestamp, likely used for efficient time-based indexing or sorting.            |
# | `sector`          | varchar        | The industry or sector classification for the entity or product.                 |
# | `exchange_country`          | varchar          | Country where the related exchange or product is listed or traded.                    |
# | `reportable_product`          | varchar          | Name or identifier for the financial product that is reportable under regulatory rules.               |
# | `product_name`          | varchar          | Descriptive name of the product or instrument.              |
# | `position_style`          | varchar        | XTech position size style label segmenting each group and reportable_product into equal quantiles of: {Small, Medium or Large} average position size.                      |
# | `direction`          | double        | indicates the trading stance, where 1.0 represents a long (buy) position and -1.0 represents a short (sell) position.            |
# | `xt_group`   | varchar        | Group classification or category for the product, possibly internal or taxonomy-based.          |
# | `long_dollar_value`        | double      | Total dollar value of long positions for the product.          |
# | `short_dollar_value`   | double        | Total dollar value of short positions for the product.          |
# | `net_dollar_value`    | double        | Net dollar exposure calculated as long minus short dollar value.        |
# | `gross_dollar_value`   | double        | Sum of long and short dollar values for gross exposure.        |
# | `long_position`  | double        | Number or size of long positions held in the product.              |
# | `short_position`   | double        | Number or size of short positions held in the product.              |
# | `net_position`    | double        | Net position size, calculated as long position minus short position.         |
# | `gross_position`     | double        | Total position size, calculated as long position plus short position.         |
# | `long_position_concentration`     | double        | Concentration of long positions as a proportion of the total market or group.             |
# | `short_position_concentration`     | double        | Concentration of short positions as a proportion of the total market or group.             |
# | `combined_position_concentration`          | double        | Overall position concentration combining both long and short positions.          |
# | `asof_date`          | date        | The effective date for which the data is relevant or reported     |
#
# ---

# %% [markdown]
# ## Retrieve data for a specific date using the asof_date parameter

# %%
df = unifier.get_dataframe(name="lseg_apollo_group_aggregates_green_buffalo", asof_date='2024-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190117    AGR              USA                 06
# 1     20190117    AGR              USA                 06
# 2     20190117    AGR              USA                 06
# 3     20190117    AGR              USA                 07
# 4     20190117    AGR              USA                 07
# ..         ...    ...              ...                ...
# 95    20190117    CCY              USA                 BP
# 96    20190117    CCY              USA                 BR
# 97    20190117    CCY              USA                 BR
# 98    20190117    CCY              USA                 BR
# 99    20190117    EQY              USA                BTC
#
#                                product_name           xt_group  direction  \
# 0                  CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0
# 1                  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers        1.0
# 2                  CBOT SOYBEAN MEAL FUTURE      Fund Managers        1.0
# 3                   CBOT SOYBEAN OIL FUTURE  Producers/Hedgers        1.0
# 4                   CBOT SOYBEAN OIL FUTURE     Broker-Dealers       -1.0
# ..                                      ...                ...        ...
# 95                 IMM BRITISH POUND FUTURE  Producers/Hedgers        1.0
# 96                IMM BRAZILIAN REAL FUTURE  Producers/Hedgers        1.0
# 97                IMM BRAZILIAN REAL FUTURE     Broker-Dealers        NaN
# 98                IMM BRAZILIAN REAL FUTURE      Fund Managers        NaN
# 99  CME CF BITCOIN REFERENCE RATE (BRR) FUT  Producers/Hedgers        NaN
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         516672620.0         215321760.0       301350860.0
# 1         230341830.0         186393650.0        43948180.0
# 2          32065030.0          22794940.0         9270090.0
# 3         279385968.0          60757158.0       218628810.0
# 4          25099218.0          84614280.0       -59515062.0
# ..                ...                 ...               ...
# 95         22225612.5           8223337.5        14002275.0
# 96         15201900.0                 0.0        15201900.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0          731994380.0        22523.0         12906.0        9617.0
# 1          416735480.0         7694.0          6335.0        1359.0
# 2           54859970.0         1516.0          1222.0         294.0
# 3          340143126.0        17791.0          5322.0       12469.0
# 4          109713498.0         1485.0          4926.0       -3441.0
# ..                 ...            ...             ...           ...
# 95          30448950.0          287.0           115.0         172.0
# 96          15201900.0          570.0             0.0         570.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          35429.0                     0.019994                      0.032236
# 1          14029.0                     0.209922                      0.366328
# 2           2738.0                     0.107041                      0.325956
# 3          23113.0                     0.030199                      0.070505
# 4           6411.0                     0.089121                      0.277751
# ..             ...                          ...                           ...
# 95           402.0                     0.147875                      0.321783
# 96           570.0                     0.541841                      0.000000
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.012750  2019-01-18 00:00:00.000
# 1                          0.137417  2019-01-18 00:00:00.000
# 2                          0.092844  2019-01-18 00:00:00.000
# 3                          0.022624  2019-01-18 00:00:00.000
# 4                          0.169869  2019-01-18 00:00:00.000
# ..                              ...                      ...
# 95                         0.102258  2019-01-18 00:00:00.000
# 96                         0.541841  2019-01-18 00:00:00.000
# 97                              NaN  2019-01-18 00:00:00.000
# 98                              NaN  2019-01-18 00:00:00.000
# 99                              NaN  2019-01-18 00:00:00.000
#
# [100 rows x 19 columns]

# %%
df = unifier.get_dataframe(name="lseg_apollo_group_style_aggregates_trade_size_style_green_buffalo", asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190122    AGR              USA                 06
# 1     20190122    AGR              USA                 06
# 2     20190122    AGR              USA                 06
# 3     20190122    AGR              USA                 06
# 4     20190122    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190122    NRG              USA                 5C
# 96    20190122    AGR              USA                 62
# 97    20190122    AGR              USA                 62
# 98    20190122    AGR              USA                 62
# 99    20190122    AGR              USA                 62
#
#                                 product_name           xt_group  \
# 0                   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers
# 1                   CBOT SOYBEAN MEAL FUTURE      Fund Managers
# 2                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 3                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 4                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# ..                                       ...                ...
# 95  NYMEX CHICAGO ULSD (PLATTS) VS NY HARBOR     Broker-Dealers
# 96                  CME FEEDER CATTLE FUTURE      Fund Managers
# 97                  CME FEEDER CATTLE FUTURE      Fund Managers
# 98                  CME FEEDER CATTLE FUTURE      Fund Managers
# 99                  CME FEEDER CATTLE FUTURE  Producers/Hedgers
#
#    trade_size_style  direction  long_dollar_value  short_dollar_value  \
# 0             small          1         37035700.0           7498860.0
# 1             large          0                NaN                 NaN
# 2             small          1        210795930.0          34134180.0
# 3            medium          1                NaN                 NaN
# 4             large          1                NaN                 NaN
# ..              ...        ...                ...                 ...
# 95            large          0                NaN                 NaN
# 96            large          0                NaN                 NaN
# 97           medium         -1                NaN                 NaN
# 98            small          1          5642425.0           5382475.0
# 99            small         -1        119861950.0         440786100.0
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0         29536840.0          44534560.0         2137.0          1196.0
# 1                NaN                 NaN            NaN             NaN
# 2        176661750.0         244930110.0        12271.0          6611.0
# 3                NaN                 NaN            NaN             NaN
# 4                NaN                 NaN            NaN             NaN
# ..               ...                 ...            ...             ...
# 95               NaN                 NaN            NaN             NaN
# 96               NaN                 NaN            NaN             NaN
# 97               NaN                 NaN            NaN             NaN
# 98          259950.0          11024900.0          164.0           160.0
# 99      -320924150.0         560648050.0         4765.0          9245.0
#
#     net_position  gross_position  long_position_concentration  \
# 0          941.0          3333.0                     0.173696
# 1            NaN             NaN                          NaN
# 2         5660.0         18882.0                     0.045379
# 3            NaN             NaN                          NaN
# 4            NaN             NaN                          NaN
# ..           ...             ...                          ...
# 95           NaN             NaN                          NaN
# 96           NaN             NaN                          NaN
# 97           NaN             NaN                          NaN
# 98           4.0           324.0                     0.116742
# 99       -4480.0         14010.0                     0.011245
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.460300                         0.133176
# 1                            NaN                              NaN
# 2                       0.154089                         0.036605
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ..                           ...                              ...
# 95                           NaN                              NaN
# 96                           NaN                              NaN
# 97                           NaN                              NaN
# 98                      0.169452                         0.070967
# 99                      0.010956                         0.007286
#
#                   asof_date
# 0   2019-01-23 00:00:00.000
# 1   2019-01-23 00:00:00.000
# 2   2019-01-23 00:00:00.000
# 3   2019-01-23 00:00:00.000
# 4   2019-01-23 00:00:00.000
# ..                      ...
# 95  2019-01-23 00:00:00.000
# 96  2019-01-23 00:00:00.000
# 97  2019-01-23 00:00:00.000
# 98  2019-01-23 00:00:00.000
# 99  2019-01-23 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name="lseg_apollo_group_style_aggregates_turnover_style_green_buffalo", asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190118    AGR              USA                 06
# 1     20190118    AGR              USA                 06
# 2     20190118    AGR              USA                 06
# 3     20190118    AGR              USA                 06
# 4     20190118    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190118    NRG              USA                 5C
# 96    20190118    AGR              USA                 62
# 97    20190118    AGR              USA                 62
# 98    20190118    AGR              USA                 62
# 99    20190118    AGR              USA                 62
#
#                                 product_name           xt_group  \
# 0                   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers
# 1                   CBOT SOYBEAN MEAL FUTURE      Fund Managers
# 2                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 3                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 4                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# ..                                       ...                ...
# 95  NYMEX CHICAGO ULSD (PLATTS) VS NY HARBOR     Broker-Dealers
# 96                  CME FEEDER CATTLE FUTURE      Fund Managers
# 97                  CME FEEDER CATTLE FUTURE      Fund Managers
# 98                  CME FEEDER CATTLE FUTURE      Fund Managers
# 99                  CME FEEDER CATTLE FUTURE  Producers/Hedgers
#
#    turnover_style  direction  long_dollar_value  short_dollar_value  \
# 0             low          1        254446470.0          20936150.0
# 1            high          0                NaN                 NaN
# 2             low          1        320078190.0          43147960.0
# 3          medium          1                NaN                 NaN
# 4            high          0                NaN                 NaN
# ..            ...        ...                ...                 ...
# 95           high          0                NaN                 NaN
# 96           high          0                NaN                 NaN
# 97         medium         -1                NaN                 NaN
# 98            low          1          5331687.5           2713737.5
# 99            low         -1        143522650.0         526263450.0
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0        233510320.0         275382620.0         9600.0          2275.0
# 1                NaN                 NaN            NaN             NaN
# 2        276930230.0         363226150.0        16476.0          7723.0
# 3                NaN                 NaN            NaN             NaN
# 4                NaN                 NaN            NaN             NaN
# ..               ...                 ...            ...             ...
# 95               NaN                 NaN            NaN             NaN
# 96               NaN                 NaN            NaN             NaN
# 97               NaN                 NaN            NaN             NaN
# 98         2617950.0           8045425.0          161.0           124.0
# 99      -382740800.0         669786100.0         5527.0         10834.0
#
#     net_position  gross_position  long_position_concentration  \
# 0         7325.0         11875.0                     0.649717
# 1            NaN             NaN                          NaN
# 2         8753.0         24199.0                     0.074011
# 3            NaN             NaN                          NaN
# 4            NaN             NaN                          NaN
# ..           ...             ...                          ...
# 95           NaN             NaN                          NaN
# 96           NaN             NaN                          NaN
# 97           NaN             NaN                          NaN
# 98          37.0           285.0                     0.129466
# 99       -5307.0         16361.0                     0.015426
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.506653                         0.557611
# 1                            NaN                              NaN
# 2                       0.110186                         0.059027
# 3                            NaN                              NaN
# 4                            NaN                              NaN
# ..                           ...                              ...
# 95                           NaN                              NaN
# 96                           NaN                              NaN
# 97                           NaN                              NaN
# 98                      0.255690                         0.085948
# 99                      0.014128                         0.009430
#
#                   asof_date
# 0   2019-01-19 00:00:00.000
# 1   2019-01-19 00:00:00.000
# 2   2019-01-19 00:00:00.000
# 3   2019-01-19 00:00:00.000
# 4   2019-01-19 00:00:00.000
# ..                      ...
# 95  2019-01-19 00:00:00.000
# 96  2019-01-19 00:00:00.000
# 97  2019-01-19 00:00:00.000
# 98  2019-01-19 00:00:00.000
# 99  2019-01-19 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name="lseg_apollo_group_style_aggregates_gross_position_style_green_buffalo", asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190117    AGR              USA                 06
# 1     20190117    AGR              USA                 06
# 2     20190117    AGR              USA                 06
# 3     20190117    AGR              USA                 06
# 4     20190117    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190117    NRG              USA                 5C
# 96    20190117    AGR              USA                 62
# 97    20190117    AGR              USA                 62
# 98    20190117    AGR              USA                 62
# 99    20190117    AGR              USA                 62
#
#                                 product_name           xt_group  \
# 0                   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers
# 1                   CBOT SOYBEAN MEAL FUTURE      Fund Managers
# 2                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 3                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# 4                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers
# ..                                       ...                ...
# 95  NYMEX CHICAGO ULSD (PLATTS) VS NY HARBOR     Broker-Dealers
# 96                  CME FEEDER CATTLE FUTURE  Producers/Hedgers
# 97                  CME FEEDER CATTLE FUTURE  Producers/Hedgers
# 98                  CME FEEDER CATTLE FUTURE     Broker-Dealers
# 99                  CME FEEDER CATTLE FUTURE  Producers/Hedgers
#
#    position_style  direction  long_dollar_value  short_dollar_value  \
# 0           small          1          1634240.0            162350.0
# 1           large          1                NaN                 NaN
# 2           small          1          5543910.0            477610.0
# 3          medium          1         17810850.0           1450160.0
# 4           large          1        316353840.0          46955700.0
# ..            ...        ...                ...                 ...
# 95          large         -1                NaN                 NaN
# 96          small         -1         17193225.0          26955925.0
# 97          large         -1         84286112.5         404683825.0
# 98          large         -1         22072050.0         147456912.5
# 99         medium         -1         35009000.0          93654800.0
#
#     net_dollar_value  gross_dollar_value  long_position  short_position  \
# 0          1471890.0           1796590.0           60.0            13.0
# 1                NaN                 NaN            NaN             NaN
# 2          5066300.0           6021520.0          258.0            96.0
# 3         16360690.0          19261010.0         1117.0           590.0
# 4        269398140.0         363309540.0        20043.0         11453.0
# ..               ...                 ...            ...             ...
# 95               NaN                 NaN            NaN             NaN
# 96        -9762700.0          44149150.0          275.0           411.0
# 97      -320397712.5         488969937.5         4445.0          8892.0
# 98      -125384862.5         169528962.5         1690.0          3450.0
# 99       -58645800.0         128663800.0          668.0          1478.0
#
#     net_position  gross_position  long_position_concentration  \
# 0           47.0            73.0                     0.066441
# 1            NaN             NaN                          NaN
# 2          162.0           354.0                     0.018815
# 3          527.0          1707.0                     0.034801
# 4         8590.0         31496.0                     0.081187
# ..           ...             ...                          ...
# 95           NaN             NaN                          NaN
# 96        -136.0           686.0                     0.007959
# 97       -4447.0         13337.0                     0.037932
# 98       -1760.0          5140.0                     0.199525
# 99        -810.0          2146.0                     0.018446
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.628945                         0.060112
# 1                            NaN                              NaN
# 2                       0.248279                         0.017511
# 3                       0.228044                         0.031051
# 4                       0.098988                         0.063211
# ..                           ...                              ...
# 95                           NaN                              NaN
# 96                      0.007746                         0.004095
# 97                      0.023634                         0.017315
# 98                      0.223502                         0.172474
# 99                      0.007014                         0.005082
#
#                   asof_date
# 0   2019-01-18 00:00:00.000
# 1   2019-01-18 00:00:00.000
# 2   2019-01-18 00:00:00.000
# 3   2019-01-18 00:00:00.000
# 4   2019-01-18 00:00:00.000
# ..                      ...
# 95  2019-01-18 00:00:00.000
# 96  2019-01-18 00:00:00.000
# 97  2019-01-18 00:00:00.000
# 98  2019-01-18 00:00:00.000
# 99  2019-01-18 00:00:00.000
#
# [100 rows x 20 columns]

# %% [markdown]
# ## Retrieve data for a specific date range using the back_to and up_to parameters

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_aggregates_green_buffalo', back_to='2025-03-27', up_to='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20250401    AGR              USA                 06
# 1     20250401    AGR              USA                 06
# 2     20250401    AGR              USA                 06
# 3     20250401    AGR              USA                 06
# 4     20250401    AGR              USA                 07
# ..         ...    ...              ...                ...
# 95    20250401    NRG              GBR                ARR
# 96    20250401    NRG              GBR                ARR
# 97    20250401    NRG              GBR                ARV
# 98    20250401    NRG              GBR                ATW
# 99    20250401    NRG              GBR                ATW
#
#                                 product_name           xt_group  direction  \
# 0                   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0
# 1                   CBOT SOYBEAN MEAL FUTURE              Other       -1.0
# 2                   CBOT SOYBEAN MEAL FUTURE      Fund Managers       -1.0
# 3                   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers        1.0
# 4                    CBOT SOYBEAN OIL FUTURE  Producers/Hedgers       -1.0
# ..                                       ...                ...        ...
# 95  ICEEU PROP,ARG F E VS NPTH C+F JAPAN FUT  Producers/Hedgers        NaN
# 96  ICEEU PROP,ARG F E VS NPTH C+F JAPAN FUT     Broker-Dealers        NaN
# 97    ICE CRUDE DIFF - ARGUS WCS HOUSTON FUT  Producers/Hedgers        NaN
# 98                ICE ROTTERDAM COAL FUTURES     Broker-Dealers        NaN
# 99                ICE ROTTERDAM COAL FUTURES      Fund Managers        NaN
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         695088310.0         452219630.0       242868680.0
# 1          82590200.0         204302110.0      -121711910.0
# 2          38933120.0          95229990.0       -56296870.0
# 3         657611550.0         546729420.0       110882130.0
# 4         271560126.0         372499326.0      -100939200.0
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96                NaN                 NaN               NaN
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0         1.147308e+09        36438.0         28322.0        8116.0
# 1         2.868923e+08         3475.0          7596.0       -4121.0
# 2         1.341631e+08         1772.0          3717.0       -1945.0
# 3         1.204341e+09        24435.0         20452.0        3983.0
# 4         6.440595e+08        12792.0         16303.0       -3511.0
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96                 NaN            NaN             NaN           NaN
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          64760.0                     0.015350                      0.047075
# 1          11071.0                     0.037433                      0.068241
# 2           5489.0                     0.102306                      0.152901
# 3          44887.0                     0.243757                      0.392738
# 4          29095.0                     0.034376                      0.054721
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96             NaN                          NaN                           NaN
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.012947  2025-04-02 00:00:00.000
# 1                          0.037708  2025-04-02 00:00:00.000
# 2                          0.085651  2025-04-02 00:00:00.000
# 3                          0.153614  2025-04-02 00:00:00.000
# 4                          0.024416  2025-04-02 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2025-04-02 00:00:00.000
# 96                              NaN  2025-04-02 00:00:00.000
# 97                              NaN  2025-04-02 00:00:00.000
# 98                              NaN  2025-04-02 00:00:00.000
# 99                              NaN  2025-04-02 00:00:00.000
#
# [100 rows x 19 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_trade_size_style_green_buffalo', back_to='1982-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190114    AGR              USA                 06
# 1     20190114    AGR              USA                 06
# 2     20190114    AGR              USA                 06
# 3     20190114    AGR              USA                 06
# 4     20190114    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190114    AGR              USA                 62
# 96    20190114    AGR              USA                 62
# 97    20190114    AGR              USA                 62
# 98    20190114    AGR              USA                 62
# 99    20190114    AGR              USA                 62
#
#                 product_name           xt_group trade_size_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            small          1
# 1   CBOT SOYBEAN MEAL FUTURE      Fund Managers            large          0
# 2   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            small          1
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers           medium          1
# 4   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            large          1
# ..                       ...                ...              ...        ...
# 95  CME FEEDER CATTLE FUTURE  Producers/Hedgers            large         -1
# 96  CME FEEDER CATTLE FUTURE      Fund Managers            large          0
# 97  CME FEEDER CATTLE FUTURE      Fund Managers           medium         -1
# 98  CME FEEDER CATTLE FUTURE      Fund Managers            small          1
# 99  CME FEEDER CATTLE FUTURE     Broker-Dealers            small         -1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0          33807730.0           7873320.0        25934410.0
# 1                 NaN                 NaN               NaN
# 2         215467790.0          47657770.0       167810020.0
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96                NaN                 NaN               NaN
# 97                NaN                 NaN               NaN
# 98          4428112.5           1879137.5         2548975.0
# 99         22860637.5          75342300.0       -52481662.5
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0           41681050.0         2060.0          1231.0         829.0
# 1                  NaN            NaN             NaN           NaN
# 2          263125560.0        12632.0          7233.0        5399.0
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96                 NaN            NaN             NaN           NaN
# 97                 NaN            NaN             NaN           NaN
# 98           6307250.0           77.0            42.0          35.0
# 99          98202937.5          610.0          1339.0        -729.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0           3291.0                     0.200509                      0.397271
# 1              NaN                          NaN                           NaN
# 2          19865.0                     0.052393                      0.125325
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96             NaN                          NaN                           NaN
# 97             NaN                          NaN                           NaN
# 98           119.0                     0.167138                      0.407840
# 99          1949.0                     0.169194                      0.118240
#
#     combined_position_concentration                asof_date
# 0                          0.146089  2019-01-15 00:00:00.000
# 1                               NaN  2019-01-15 00:00:00.000
# 2                          0.039244  2019-01-15 00:00:00.000
# 3                               NaN  2019-01-15 00:00:00.000
# 4                               NaN  2019-01-15 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2019-01-15 00:00:00.000
# 96                              NaN  2019-01-15 00:00:00.000
# 97                              NaN  2019-01-15 00:00:00.000
# 98                         0.118583  2019-01-15 00:00:00.000
# 99                         0.078766  2019-01-15 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_turnover_style_green_buffalo', back_to='2024-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20240129    AGR              USA                 06
# 1     20240129    AGR              USA                 06
# 2     20240129    AGR              USA                 06
# 3     20240129    AGR              USA                 06
# 4     20240129    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20240129    INT              USA                 26
# 96    20240129    INT              USA                 26
# 97    20240129    INT              USA                 26
# 98    20240129    INT              USA                 26
# 99    20240129    INT              USA                 26
#
#                     product_name           xt_group turnover_style  direction  \
# 0       CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            low         -1
# 1       CBOT SOYBEAN MEAL FUTURE      Fund Managers           high          0
# 2       CBOT SOYBEAN MEAL FUTURE              Other            low          0
# 3       CBOT SOYBEAN MEAL FUTURE              Other         medium          0
# 4       CBOT SOYBEAN MEAL FUTURE              Other           high          0
# ..                           ...                ...            ...        ...
# 95  CBT 2YR TREASURY NOTE FUTURE              Other            low          0
# 96  CBT 2YR TREASURY NOTE FUTURE              Other         medium          0
# 97  CBT 2YR TREASURY NOTE FUTURE              Other           high          0
# 98  CBT 2YR TREASURY NOTE FUTURE  Producers/Hedgers         medium         -1
# 99  CBT 2YR TREASURY NOTE FUTURE  Producers/Hedgers            low         -1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         172312060.0        2.826738e+08     -1.103618e+08
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96                NaN                 NaN               NaN
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99        704659312.5        1.381518e+10     -1.311052e+10
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0         4.549859e+08        11732.0         14892.0       -3160.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96                 NaN            NaN             NaN           NaN
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99        1.451984e+10         3498.0         67352.0      -63854.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          26624.0                     0.327919                      0.205517
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96             NaN                          NaN                           NaN
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99         70850.0                     0.241574                      0.476798
#
#     combined_position_concentration                asof_date
# 0                          0.126360  2024-01-30 00:00:00.000
# 1                               NaN  2024-01-30 00:00:00.000
# 2                               NaN  2024-01-30 00:00:00.000
# 3                               NaN  2024-01-30 00:00:00.000
# 4                               NaN  2024-01-30 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2024-01-30 00:00:00.000
# 96                              NaN  2024-01-30 00:00:00.000
# 97                              NaN  2024-01-30 00:00:00.000
# 98                              NaN  2024-01-30 00:00:00.000
# 99                         0.432211  2024-01-30 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_gross_position_style_green_buffalo', back_to='2024-01-27 09:30:00', up_to='2025-06-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20240129    AGR              USA                 06
# 1     20240129    AGR              USA                 06
# 2     20240129    AGR              USA                 06
# 3     20240129    AGR              USA                 06
# 4     20240129    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20240129    INT              USA                 26
# 96    20240129    INT              USA                 26
# 97    20240129    INT              USA                 26
# 98    20240129    INT              USA                 26
# 99    20240129    INT              USA                 26
#
#                     product_name           xt_group position_style  direction  \
# 0       CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          small          1
# 1       CBOT SOYBEAN MEAL FUTURE      Fund Managers          large         -1
# 2       CBOT SOYBEAN MEAL FUTURE              Other          small          0
# 3       CBOT SOYBEAN MEAL FUTURE              Other         medium          0
# 4       CBOT SOYBEAN MEAL FUTURE              Other          large          0
# ..                           ...                ...            ...        ...
# 95  CBT 2YR TREASURY NOTE FUTURE              Other          small          0
# 96  CBT 2YR TREASURY NOTE FUTURE              Other         medium          0
# 97  CBT 2YR TREASURY NOTE FUTURE              Other          large          0
# 98  CBT 2YR TREASURY NOTE FUTURE  Producers/Hedgers         medium          1
# 99  CBT 2YR TREASURY NOTE FUTURE  Producers/Hedgers          small          1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0           2020170.0            995340.0         1024830.0
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96                NaN                 NaN               NaN
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0            3015510.0           76.0            47.0          29.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96                 NaN            NaN             NaN           NaN
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0            123.0                     0.054462                      0.156995
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96             NaN                          NaN                           NaN
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.041547  2024-01-30 00:00:00.000
# 1                               NaN  2024-01-30 00:00:00.000
# 2                               NaN  2024-01-30 00:00:00.000
# 3                               NaN  2024-01-30 00:00:00.000
# 4                               NaN  2024-01-30 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2024-01-30 00:00:00.000
# 96                              NaN  2024-01-30 00:00:00.000
# 97                              NaN  2024-01-30 00:00:00.000
# 98                              NaN  2024-01-30 00:00:00.000
# 99                              NaN  2024-01-30 00:00:00.000
#
# [100 rows x 20 columns]

# %% [markdown]
# ## Retrieve data for a specific date with a specific ticker (key='06' to sort by reportable product) using the asof_date parameter

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_aggregates_green_buffalo',key='06', asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190107    AGR              USA                 06
# 1     20190107    AGR              USA                 06
# 2     20190107    AGR              USA                 06
# 3     20190122    AGR              USA                 06
# 4     20190122    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190218    AGR              USA                 06
# 96    20190215    AGR              USA                 06
# 97    20190215    AGR              USA                 06
# 98    20190215    AGR              USA                 06
# 99    20190222    AGR              USA                 06
#
#                 product_name           xt_group  direction  long_dollar_value  \
# 0   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          1          518380620
# 1   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers         -1          202665240
# 2   CBOT SOYBEAN MEAL FUTURE      Fund Managers          1           39555690
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          1          498657130
# 4   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          1          233293150
# ..                       ...                ...        ...                ...
# 95  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          1          234539370
# 96  CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          1          507403090
# 97  CBOT SOYBEAN MEAL FUTURE      Fund Managers          1           31950330
# 98  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          1          234539370
# 99  CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          1          502547010
#
#     short_dollar_value  net_dollar_value  gross_dollar_value  long_position  \
# 0            242945080         275435540           761325700          21278
# 1            214587310         -11922070           417252550           6920
# 2              7605060          31950630            47160750           1681
# 3            224819070         273838060           723476200          22300
# 4            185325320          47967830           418618470           7853
# ..                 ...               ...                 ...            ...
# 95           194828260          39711110           429367630           7593
# 96           270043510         237359580           777446600          23303
# 97            27334220           4616110            59284550           2491
# 98           194828260          39711110           429367630           7593
# 99           267588850         234958160           770135860          23262
#
#     short_position  net_position  gross_position  long_position_concentration  \
# 0            12764          8514           34042                     0.021625
# 1             7314          -394           14234                     0.246829
# 2              691           990            2372                     0.107947
# 3            13587          8713           35887                     0.020134
# 4             6365          1488           14218                     0.201007
# ..             ...           ...             ...                          ...
# 95            6373          1220           13966                     0.265371
# 96           15605          7698           38908                     0.018934
# 97            2346           145            4837                     0.140326
# 98            6373          1220           13966                     0.265371
# 99           15628          7634           38890                     0.019654
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.028488                         0.012927
# 1                       0.359068                         0.153201
# 2                       0.113381                         0.078888
# 3                       0.031512                         0.012608
# 4                       0.363585                         0.133687
# ..                           ...                              ...
# 95                      0.532352                         0.188791
# 96                      0.029538                         0.011629
# 97                      0.089355                         0.059753
# 98                      0.532352                         0.188791
# 99                      0.033773                         0.012446
#
#                   asof_date
# 0   2019-01-08 00:00:00.000
# 1   2019-01-08 00:00:00.000
# 2   2019-01-08 00:00:00.000
# 3   2019-01-23 00:00:00.000
# 4   2019-01-23 00:00:00.000
# ..                      ...
# 95  2019-02-19 00:00:00.000
# 96  2019-02-16 00:00:00.000
# 97  2019-02-16 00:00:00.000
# 98  2019-02-16 00:00:00.000
# 99  2019-02-23 00:00:00.000
#
# [100 rows x 19 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_trade_size_style_green_buffalo',key='06', asof_date='2025-01-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190114    AGR              USA                 06
# 1     20190114    AGR              USA                 06
# 2     20190114    AGR              USA                 06
# 3     20190114    AGR              USA                 06
# 4     20190114    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190121    AGR              USA                 06
# 96    20190121    AGR              USA                 06
# 97    20190121    AGR              USA                 06
# 98    20190121    AGR              USA                 06
# 99    20190201    AGR              USA                 06
#
#                 product_name           xt_group trade_size_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            small          1
# 1   CBOT SOYBEAN MEAL FUTURE      Fund Managers            large          0
# 2   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            small          1
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers           medium          1
# 4   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            large          1
# ..                       ...                ...              ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE      Fund Managers           medium         -1
# 96  CBOT SOYBEAN MEAL FUTURE      Fund Managers            small          1
# 97  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers           medium          1
# 98  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            large         -1
# 99  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            small          1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0          33807730.0           7873320.0        25934410.0
# 1                 NaN                 NaN               NaN
# 2         215467790.0          47657770.0       167810020.0
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96          3091170.0           1584450.0         1506720.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99         39915780.0          12994860.0        26920920.0
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0           41681050.0         2060.0          1231.0         829.0
# 1                  NaN            NaN             NaN           NaN
# 2          263125560.0        12632.0          7233.0        5399.0
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96           4675620.0          190.0           141.0          49.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99          52910640.0         2258.0          1400.0         858.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0           3291.0                     0.200509                      0.397271
# 1              NaN                          NaN                           NaN
# 2          19865.0                     0.052393                      0.125325
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96           331.0                     0.104221                      0.219357
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99          3658.0                     0.168428                      0.272627
#
#     combined_position_concentration                asof_date
# 0                          0.146089  2019-01-15 00:00:00.000
# 1                               NaN  2019-01-15 00:00:00.000
# 2                          0.039244  2019-01-15 00:00:00.000
# 3                               NaN  2019-01-15 00:00:00.000
# 4                               NaN  2019-01-15 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2019-01-22 00:00:00.000
# 96                         0.070744  2019-01-22 00:00:00.000
# 97                              NaN  2019-01-22 00:00:00.000
# 98                              NaN  2019-01-22 00:00:00.000
# 99                         0.112300  2019-02-02 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_turnover_style_green_buffalo',key='06', asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190118    AGR              USA                 06
# 1     20190118    AGR              USA                 06
# 2     20190118    AGR              USA                 06
# 3     20190118    AGR              USA                 06
# 4     20190118    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190122    AGR              USA                 06
# 96    20190122    AGR              USA                 06
# 97    20190122    AGR              USA                 06
# 98    20190122    AGR              USA                 06
# 99    20190111    AGR              USA                 06
#
#                 product_name           xt_group turnover_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            low          1
# 1   CBOT SOYBEAN MEAL FUTURE      Fund Managers           high          0
# 2   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers            low          1
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers         medium          1
# 4   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers           high          0
# ..                       ...                ...            ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE      Fund Managers         medium          1
# 96  CBOT SOYBEAN MEAL FUTURE      Fund Managers            low          1
# 97  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers         medium         -1
# 98  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers           high          0
# 99  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers            low          1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         254446470.0          20936150.0       233510320.0
# 1                 NaN                 NaN               NaN
# 2         320078190.0          43147960.0       276930230.0
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96          2789770.0           2620310.0          169460.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99        233613430.0          15495000.0       218118430.0
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0          275382620.0         9600.0          2275.0        7325.0
# 1                  NaN            NaN             NaN           NaN
# 2          363226150.0        16476.0          7723.0        8753.0
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96           5410080.0          241.0           232.0           9.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99         249108430.0         8935.0          2084.0        6851.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          11875.0                     0.649717                      0.506653
# 1              NaN                          NaN                           NaN
# 2          24199.0                     0.074011                      0.110186
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96           473.0                     0.109775                      0.106603
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99         11019.0                     0.628777                      0.387932
#
#     combined_position_concentration                asof_date
# 0                          0.557611  2019-01-19 00:00:00.000
# 1                               NaN  2019-01-19 00:00:00.000
# 2                          0.059027  2019-01-19 00:00:00.000
# 3                               NaN  2019-01-19 00:00:00.000
# 4                               NaN  2019-01-19 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2019-01-23 00:00:00.000
# 96                         0.054197  2019-01-23 00:00:00.000
# 97                              NaN  2019-01-23 00:00:00.000
# 98                              NaN  2019-01-23 00:00:00.000
# 99                         0.554489  2019-01-12 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_gross_position_style_green_buffalo',key='06', asof_date='2025-06-27', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20190122    AGR              USA                 06
# 1     20190122    AGR              USA                 06
# 2     20190122    AGR              USA                 06
# 3     20190122    AGR              USA                 06
# 4     20190122    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20190125    AGR              USA                 06
# 96    20190125    AGR              USA                 06
# 97    20190125    AGR              USA                 06
# 98    20190125    AGR              USA                 06
# 99    20190103    AGR              USA                 06
#
#                 product_name           xt_group position_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          small          1
# 1   CBOT SOYBEAN MEAL FUTURE      Fund Managers          large          1
# 2   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          small          1
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers         medium          1
# 4   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers          large          1
# ..                       ...                ...            ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE      Fund Managers         medium         -1
# 96  CBOT SOYBEAN MEAL FUTURE      Fund Managers          small         -1
# 97  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          large          1
# 98  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers         medium          1
# 99  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers          small          1
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0           1452530.0            319300.0         1133230.0
# 1                 NaN                 NaN               NaN
# 2           5151060.0            417480.0         4733580.0
# 3          16035070.0           3118570.0        12916500.0
# 4         303910440.0          53499010.0       250411430.0
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96                NaN                 NaN               NaN
# 97        248606240.0         203678000.0        44928240.0
# 98          4897000.0           1811080.0         3085920.0
# 99          2191500.0            129520.0         2061980.0
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0            1771830.0           54.0            18.0          36.0
# 1                  NaN            NaN             NaN           NaN
# 2            5568540.0          245.0            94.0         151.0
# 3           19153640.0         1128.0           712.0         416.0
# 4          357409450.0        20014.0         12053.0        7961.0
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96                 NaN            NaN             NaN           NaN
# 97         452284240.0         9973.0          8603.0        1370.0
# 98           6708080.0          195.0            96.0          99.0
# 99           2321020.0           74.0             9.0          65.0
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0             72.0                     0.066865                      0.422885
# 1              NaN                          NaN                           NaN
# 2            339.0                     0.020466                      0.315522
# 3           1840.0                     0.037859                      0.276699
# 4          32067.0                     0.082242                      0.109010
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96             NaN                          NaN                           NaN
# 97         18576.0                     0.630509                      0.732437
# 98           291.0                     0.136290                      0.196964
# 99            83.0                     0.159203                      0.598078
#
#     combined_position_concentration                asof_date
# 0                          0.058671  2019-01-23 00:00:00.000
# 1                               NaN  2019-01-23 00:00:00.000
# 2                          0.019286  2019-01-23 00:00:00.000
# 3                          0.033869  2019-01-23 00:00:00.000
# 4                          0.061906  2019-01-23 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2019-01-26 00:00:00.000
# 96                              NaN  2019-01-26 00:00:00.000
# 97                         0.339036  2019-01-26 00:00:00.000
# 98                         0.086989  2019-01-26 00:00:00.000
# 99                         0.143793  2019-01-04 00:00:00.000
#
# [100 rows x 20 columns]

# %% [markdown]
# ## Retrieve data for a specific date range with a specific ticker (key='06' to sort by reportable product) using the back_to and up_to parameters

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_aggregates_green_buffalo',key='06', back_to='2020-01-01 09:30:00', up_to='2025-01-01 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20200102    AGR              USA                 06
# 1     20200102    AGR              USA                 06
# 2     20200102    AGR              USA                 06
# 3     20200113    AGR              USA                 06
# 4     20200113    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20200306    AGR              USA                 06
# 96    20200306    AGR              USA                 06
# 97    20200306    AGR              USA                 06
# 98    20200310    AGR              USA                 06
# 99    20200310    AGR              USA                 06
#
#                 product_name           xt_group  direction  long_dollar_value  \
# 0   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0        477984400.0
# 1   CBOT SOYBEAN MEAL FUTURE     Broker-Dealers        1.0        369592270.0
# 2   CBOT SOYBEAN MEAL FUTURE      Fund Managers        1.0         47543950.0
# 3   CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0        510107300.0
# 4   CBOT SOYBEAN MEAL FUTURE              Other        NaN                NaN
# ..                       ...                ...        ...                ...
# 95  CBOT SOYBEAN MEAL FUTURE      Fund Managers        1.0         54050820.0
# 96  CBOT SOYBEAN MEAL FUTURE              Other        NaN                NaN
# 97  CBOT SOYBEAN MEAL FUTURE     Broker-Dealers        1.0        449361280.0
# 98  CBOT SOYBEAN MEAL FUTURE  Producers/Hedgers        1.0        505845420.0
# 99  CBOT SOYBEAN MEAL FUTURE      Fund Managers        1.0         52615990.0
#
#     short_dollar_value  net_dollar_value  gross_dollar_value  long_position  \
# 0          422471470.0        55512930.0         900455870.0        24124.0
# 1          136988970.0       232603300.0         506581240.0        12065.0
# 2           16933170.0        30610780.0          64477120.0         1962.0
# 3          414559680.0        95547620.0         924666980.0        21930.0
# 4                  NaN               NaN                 NaN            NaN
# ..                 ...               ...                 ...            ...
# 95          24760750.0        29290070.0          78811570.0         2572.0
# 96                 NaN               NaN                 NaN            NaN
# 97         107458570.0       341902710.0         556819850.0        14851.0
# 98         303052770.0       202792650.0         808898190.0        21518.0
# 99          23899200.0        28716790.0          76515190.0         2544.0
#
#     short_position  net_position  gross_position  long_position_concentration  \
# 0          22386.0        1738.0         46510.0                     0.019403
# 1           4610.0        7455.0         16675.0                     0.152646
# 2            973.0         989.0          2935.0                     0.058979
# 3          18890.0        3040.0         40820.0                     0.018101
# 4              NaN           NaN             NaN                          NaN
# ..             ...           ...             ...                          ...
# 95          1609.0         963.0          4181.0                     0.130240
# 96             NaN           NaN             NaN                          NaN
# 97          3754.0       11097.0         18605.0                     0.125978
# 98         14878.0        6640.0         36396.0                     0.020620
# 99          1590.0         954.0          4134.0                     0.139495
#
#     short_position_concentration  combined_position_concentration  \
# 0                       0.057717                         0.018172
# 1                       0.516237                         0.119002
# 2                       0.119039                         0.040279
# 3                       0.055172                         0.016598
# 4                            NaN                              NaN
# ..                           ...                              ...
# 95                      0.105863                         0.071709
# 96                           NaN                              NaN
# 97                      0.364339                         0.095615
# 98                      0.052154                         0.015384
# 99                      0.125360                         0.078193
#
#                   asof_date
# 0   2020-01-03 00:00:00.000
# 1   2020-01-03 00:00:00.000
# 2   2020-01-03 00:00:00.000
# 3   2020-01-14 00:00:00.000
# 4   2020-01-14 00:00:00.000
# ..                      ...
# 95  2020-03-07 00:00:00.000
# 96  2020-03-07 00:00:00.000
# 97  2020-03-07 00:00:00.000
# 98  2020-03-11 00:00:00.000
# 99  2020-03-11 00:00:00.000
#
# [100 rows x 19 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_trade_size_style_green_buffalo',key='06', back_to='2020-01-27 09:30:00', up_to='2025-01-27 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20200131    AGR              USA                 06
# 1     20200131    AGR              USA                 06
# 2     20200131    AGR              USA                 06
# 3     20200131    AGR              USA                 06
# 4     20200131    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20200203    AGR              USA                 06
# 96    20200214    AGR              USA                 06
# 97    20200214    AGR              USA                 06
# 98    20200214    AGR              USA                 06
# 99    20200214    AGR              USA                 06
#
#                 product_name        xt_group trade_size_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            small          1
# 1   CBOT SOYBEAN MEAL FUTURE   Fund Managers            large          0
# 2   CBOT SOYBEAN MEAL FUTURE           Other            small          0
# 3   CBOT SOYBEAN MEAL FUTURE           Other           medium          0
# 4   CBOT SOYBEAN MEAL FUTURE           Other            large          0
# ..                       ...             ...              ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            large         -1
# 96  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            small          1
# 97  CBOT SOYBEAN MEAL FUTURE   Fund Managers            large          0
# 98  CBOT SOYBEAN MEAL FUTURE           Other            small          0
# 99  CBOT SOYBEAN MEAL FUTURE           Other           medium          0
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0          47628530.0          38631250.0         8997280.0
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96         48682370.0          26759020.0        21923350.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0           86259780.0         1966.0          1683.0         283.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96          75441390.0         2042.0          1310.0         732.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0           3649.0                     0.168872                      0.197655
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96          3352.0                     0.181109                      0.127524
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.091128  2020-02-01 00:00:00.000
# 1                               NaN  2020-02-01 00:00:00.000
# 2                               NaN  2020-02-01 00:00:00.000
# 3                               NaN  2020-02-01 00:00:00.000
# 4                               NaN  2020-02-01 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2020-02-04 00:00:00.000
# 96                         0.091460  2020-02-15 00:00:00.000
# 97                              NaN  2020-02-15 00:00:00.000
# 98                              NaN  2020-02-15 00:00:00.000
# 99                              NaN  2020-02-15 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_turnover_style_green_buffalo',key='06', back_to='2020-01-01 09:30:00', up_to='2025-01-01 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20200102    AGR              USA                 06
# 1     20200102    AGR              USA                 06
# 2     20200102    AGR              USA                 06
# 3     20200102    AGR              USA                 06
# 4     20200102    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20200131    AGR              USA                 06
# 96    20200203    AGR              USA                 06
# 97    20200203    AGR              USA                 06
# 98    20200203    AGR              USA                 06
# 99    20200203    AGR              USA                 06
#
#                 product_name        xt_group turnover_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            low          1
# 1   CBOT SOYBEAN MEAL FUTURE   Fund Managers           high          0
# 2   CBOT SOYBEAN MEAL FUTURE           Other            low          0
# 3   CBOT SOYBEAN MEAL FUTURE           Other         medium          0
# 4   CBOT SOYBEAN MEAL FUTURE           Other           high          0
# ..                       ...             ...            ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers           high          0
# 96  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers            low          1
# 97  CBOT SOYBEAN MEAL FUTURE   Fund Managers           high          0
# 98  CBOT SOYBEAN MEAL FUTURE           Other            low          0
# 99  CBOT SOYBEAN MEAL FUTURE           Other         medium          0
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0         388357780.0          62342410.0       326015370.0
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95                NaN                 NaN               NaN
# 96        373182790.0          76967300.0       296215490.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0          450700190.0        13302.0          2786.0       10516.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95                 NaN            NaN             NaN           NaN
# 96         450150090.0        13938.0          4019.0        9919.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0          16088.0                     0.595159                      0.312556
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95             NaN                          NaN                           NaN
# 96         17957.0                     0.594953                      0.215078
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.447877  2020-01-03 00:00:00.000
# 1                               NaN  2020-01-03 00:00:00.000
# 2                               NaN  2020-01-03 00:00:00.000
# 3                               NaN  2020-01-03 00:00:00.000
# 4                               NaN  2020-01-03 00:00:00.000
# ..                              ...                      ...
# 95                              NaN  2020-02-01 00:00:00.000
# 96                         0.415182  2020-02-04 00:00:00.000
# 97                              NaN  2020-02-04 00:00:00.000
# 98                              NaN  2020-02-04 00:00:00.000
# 99                              NaN  2020-02-04 00:00:00.000
#
# [100 rows x 20 columns]

# %%
df = unifier.get_dataframe(name='lseg_apollo_group_style_aggregates_gross_position_style_green_buffalo',key='06', back_to='2020-01-01 09:30:00', up_to='2025-01-01 16:00:00', limit=100)
display(df)
# Out:
#     trade_date sector exchange_country reportable_product  \
# 0     20200102    AGR              USA                 06
# 1     20200102    AGR              USA                 06
# 2     20200102    AGR              USA                 06
# 3     20200102    AGR              USA                 06
# 4     20200102    AGR              USA                 06
# ..         ...    ...              ...                ...
# 95    20200120    AGR              USA                 06
# 96    20200117    AGR              USA                 06
# 97    20200117    AGR              USA                 06
# 98    20200117    AGR              USA                 06
# 99    20200117    AGR              USA                 06
#
#                 product_name        xt_group position_style  direction  \
# 0   CBOT SOYBEAN MEAL FUTURE  Broker-Dealers          small          1
# 1   CBOT SOYBEAN MEAL FUTURE   Fund Managers          large         -1
# 2   CBOT SOYBEAN MEAL FUTURE           Other          small          0
# 3   CBOT SOYBEAN MEAL FUTURE           Other         medium          0
# 4   CBOT SOYBEAN MEAL FUTURE           Other          large          0
# ..                       ...             ...            ...        ...
# 95  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers          large          1
# 96  CBOT SOYBEAN MEAL FUTURE  Broker-Dealers          small          1
# 97  CBOT SOYBEAN MEAL FUTURE   Fund Managers          large         -1
# 98  CBOT SOYBEAN MEAL FUTURE           Other          small          0
# 99  CBOT SOYBEAN MEAL FUTURE           Other         medium          0
#
#     long_dollar_value  short_dollar_value  net_dollar_value  \
# 0           3199220.0             30560.0         3168660.0
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                 NaN                 NaN               NaN
# ..                ...                 ...               ...
# 95        398099220.0         140956350.0       257142870.0
# 96          3180780.0             91420.0         3089360.0
# 97                NaN                 NaN               NaN
# 98                NaN                 NaN               NaN
# 99                NaN                 NaN               NaN
#
#     gross_dollar_value  long_position  short_position  net_position  \
# 0            3229780.0          105.0             2.0         103.0
# 1                  NaN            NaN             NaN           NaN
# 2                  NaN            NaN             NaN           NaN
# 3                  NaN            NaN             NaN           NaN
# 4                  NaN            NaN             NaN           NaN
# ..                 ...            ...             ...           ...
# 95         539055570.0        15212.0          6901.0        8311.0
# 96           3272200.0          107.0             5.0         102.0
# 97                 NaN            NaN             NaN           NaN
# 98                 NaN            NaN             NaN           NaN
# 99                 NaN            NaN             NaN           NaN
#
#     gross_position  long_position_concentration  short_position_concentration  \
# 0            107.0                     0.038029                      1.000000
# 1              NaN                          NaN                           NaN
# 2              NaN                          NaN                           NaN
# 3              NaN                          NaN                           NaN
# 4              NaN                          NaN                           NaN
# ..             ...                          ...                           ...
# 95         22113.0                     0.621453                      0.293734
# 96           112.0                     0.047223                      0.540771
# 97             NaN                          NaN                           NaN
# 98             NaN                          NaN                           NaN
# 99             NaN                          NaN                           NaN
#
#     combined_position_concentration                asof_date
# 0                          0.037403  2020-01-03 00:00:00.000
# 1                               NaN  2020-01-03 00:00:00.000
# 2                               NaN  2020-01-03 00:00:00.000
# 3                               NaN  2020-01-03 00:00:00.000
# 4                               NaN  2020-01-03 00:00:00.000
# ..                              ...                      ...
# 95                         0.359025  2020-01-21 00:00:00.000
# 96                         0.045043  2020-01-18 00:00:00.000
# 97                              NaN  2020-01-18 00:00:00.000
# 98                              NaN  2020-01-18 00:00:00.000
# 99                              NaN  2020-01-18 00:00:00.000
#
# [100 rows x 20 columns]

# %% [markdown]
# ### LSEG Apollo Flow Sample Query

# %%
import os
import time
import pandas as pd
from unifier import unifier


# ---- CONFIG ----
dataset_name = 'lseg_apollo_group_aggregates_green_buffalo'


# ---- USER INPUT ----
# Set exact date range (YYYY-MM-DD)
back_to_date = "2019-01-01"   # start date
up_to_date   = "2025-01-01"   # end date


base_directory = os.getcwd()
output_folder = os.path.join(base_directory, dataset_name)
os.makedirs(output_folder, exist_ok=True)


# ---- TIMER START ----
start_time = time.time()


print(f"Querying data from {back_to_date} to {up_to_date}")


try:
   df = unifier.get_dataframe(
       name=dataset_name,
       key=None,
       asof_date=None,
       back_to=back_to_date,
       up_to=up_to_date,
       limit=None
   )
  
   if df is None or df.empty:
       print("⚠ No data returned for the given date range")
   else:
       if "timestamp" in df.columns:
           df = df.sort_values("timestamp")
      
       # ---- SAVE AS CSV ----
       filename = f"{dataset_name}_{back_to_date}_to_{up_to_date}.csv"
       filepath = os.path.join(output_folder, filename)
      
       df.to_csv(filepath, index=False)
       print(f"✓ Saved {len(df)} rows to {filename}")
      
       # ---- OUTPUT LINK ----
       abs_path = os.path.abspath(filepath)
       file_url = f"file://{abs_path}"
       print(f"🔗 CSV file link: {file_url}")


except Exception as e:
   print(f"✗ Error querying data: {str(e)}")


# ---- TIMER END ----
elapsed = time.time() - start_time
print(f"\nAll files saved to: {output_folder}")
print(f"⏱ Total runtime: {elapsed:.2f} seconds ({elapsed/60:.2f} minutes)")
# Out:
# Querying data from 2019-01-01 to 2025-01-01
# ✓ Saved 1474788 rows to lseg_apollo_group_aggregates_green_buffalo_2019-01-01_to_2025-01-01.csv
# 🔗 CSV file link: file:///Users/wyattcanderson06/Desktop/Entitlements/lseg_apollo_group_aggregates_green_buffalo/lseg_apollo_group_aggregates_green_buffalo_2019-01-01_to_2025-01-01.csv
#
# All files saved to: /Users/wyattcanderson06/Desktop/Entitlements/lseg_apollo_group_aggregates_green_buffalo
# ⏱ Total runtime: 46.90 seconds (0.78 minutes)

# %% [markdown]
# ##### Data queries from apollo datasets from 2019 to the present. Replace the data_source_name in this sample query to query from each seperate dataset. A query can be run from 2019 to the present, saving all of the data to a csv file.
